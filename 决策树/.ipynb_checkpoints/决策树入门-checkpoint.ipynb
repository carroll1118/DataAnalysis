# %%
a = list('喜欢上一个人')
a
# Out:
# ['喜', '欢', '上', '一', '个', '人']

# %%
import numpy as np

# %%
np.random.shuffle(a)
a
# Out:
# ['人', '欢', '个', '一', '喜', '上']

# %%
# DecisionTree   决策树

# %%
info_D = -(0.3*np.log2(0.3) + 0.7*np.log2(0.7))
info_D
# Out:
# 0.8812908992306927

# %%
import numpy as np

from sklearn.tree import DecisionTreeClassifier

import sklearn.datasets as datasets

# %%
iris  =  datasets.load_iris()

X = iris['data']

y = iris['target']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
clf = DecisionTreeClassifier()

clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
clf.score(X_test,y_test)
# Out:
# 0.8666666666666667

# %%
#画图
import graphviz
from sklearn import tree

# %%
data = tree.export_graphviz(clf,out_file=None)

graph = graphviz.Source(data)
graph

# %%
data = tree.export_graphviz(clf,out_file=None,feature_names=iris.feature_names,class_names=iris.target_names,filled=True)

graph = graphviz.Source(data)
graph
#将运行结果的图片保存到本地
graph.render('./iris')

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
#交叉验证  cross_val_score
from sklearn.model_selection import cross_val_score

# %%
clf = AdaBoostClassifier()

scores = cross_val_score(clf,X,y,cv = 10)

scores.mean()
# Out:
# 0.9533333333333334

# %%
#learning_rate   学习率
ada = AdaBoostClassifier(n_estimators=12)

# %%
ada.fit(X_train,y_train)

ada.score(X_test,y_test)
# Out:
# 1.0

# %%
len(ada.estimators_)
# Out:
# 50

# %%
dot = tree.export_graphviz(ada.estimators_[0],out_file=None,feature_names=iris.feature_names,class_names=iris.target_names,filled=True)

graphviz.Source(dot)

# %%
dot = tree.export_graphviz(ada.estimators_[-1],out_file=None,feature_names=iris.feature_names,class_names=iris.target_names,filled=True)

graphviz.Source(dot)

# %% [markdown]
# # 使用决策树算法

# %%
#分类
from sklearn.ensemble import GradientBoostingClassifier

# %%
#回归
from sklearn.ensemble import GradientBoostingRegressor

# %%
from pandas import Series,DataFrame

# %%
X = DataFrame({'购物':[500,500,1500,1500],'是否百度问答':[0,1,0,1]})
y = np.array([14,16,24,26])

gbdt = GradientBoostingRegressor(n_estimators=10)

gbdt.fit(X,y)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=10, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
gbdt.estimators_
# Out:
# array([[DecisionTreeRegressor(criterion='friedman_mse', max_depth=3,
#            max_features=None, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort='auto',
#            random_state=<mtrand.RandomState object at 0x000001CD2BAC39D8>,
#            splitter='best')],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=3,
#            max_features=None, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort='auto',
#            random_state=<mtrand.RandomState object at 0x000001CD2BAC39D8>,
#            splitter='best')],
#        [DecisionTreeRegressor(criterion='friedman_mse', max_depth=3,
#            max_features=None, max_leaf_nodes=None,
# ...

# %%
gbdt.score(X,y)
# Out:
# 0.8784233454094307

# %%
tree.export_graphviz(gbdt.estimators_[0,0])
# Out:
# D:\anacondna\lib\site-packages\sklearn\tree\export.py:399: DeprecationWarning: out_file can be set to None starting from 0.18. This will be the default in 0.20.
#   DeprecationWarning)
