# %%
# 如果有截距，不能使用求导数，导数最小求解问题

# %%
# 如果有截距，求解时，需要梯度下降法求解w和b

# %%
# 什么是梯度？？？
# 梯度就是导数
# 梯度下降是求解最大值，最小值最快的速度
# 导数是函数变化率最快的方向

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f = lambda x : (x - 4.3)**2 + 7.5*x + 6

# %%
g = lambda x : 2*x - 1.1

# %%
x = np.linspace(-5,9,100)

plt.plot(x,f(x))

# %%
# 梯度爆炸

# %%
result = []
# 设起始值的数值
v_min = np.random.randint(-10,10,size = 1)[0]
result.append(v_min)
# 该值记录梯度下降过程中，上一步的值
v_min_last = v_min + 1
# 什么时候梯度下降结束，精度退出条件
precision = 0.00001
# 在一个退出条件，循环次数
max_time = 3000
# 步幅
step = 0.01
count = 0
print('-------------------------------随机生成的最小值： ',v_min)
while True:
    if np.abs(v_min - v_min_last) < precision:
        break
    if count > max_time:
        break   
    v_min_last = v_min
    v_min = v_min - g(v_min)*step
    result.append(v_min)
    print('-----------------------------梯度下降更新的最小值： ',v_min)
    count += 1
# Out:
# -------------------------------随机生成的最小值：  -8
# -----------------------------梯度下降更新的最小值：  -7.829
# -----------------------------梯度下降更新的最小值：  -7.66142
# -----------------------------梯度下降更新的最小值：  -7.4971916
# -----------------------------梯度下降更新的最小值：  -7.336247768
# -----------------------------梯度下降更新的最小值：  -7.17852281264
# -----------------------------梯度下降更新的最小值：  -7.0239523563872
# -----------------------------梯度下降更新的最小值：  -6.8724733092594565
# -----------------------------梯度下降更新的最小值：  -6.724023843074267
# -----------------------------梯度下降更新的最小值：  -6.578543366212782
# -----------------------------梯度下降更新的最小值：  -6.435972498888526
# -----------------------------梯度下降更新的最小值：  -6.2962530489107555
# -----------------------------梯度下降更新的最小值：  -6.15932798793254
# -----------------------------梯度下降更新的最小值：  -6.02514142817389
# -----------------------------梯度下降更新的最小值：  -5.893638599610412
# -----------------------------梯度下降更新的最小值：  -5.764765827618204
# -----------------------------梯度下降更新的最小值：  -5.63847051106584
# -----------------------------梯度下降更新的最小值：  -5.5147011008445235
# -----------------------------梯度下降更新的最小值：  -5.393407078827633
# -----------------------------梯度下降更新的最小值：  -5.274538937251081
# -----------------------------梯度下降更新的最小值：  -5.158048158506059
# -----------------------------梯度下降更新的最小值：  -5.043887195335937
# -----------------------------梯度下降更新的最小值：  -4.932009451429218
# -----------------------------梯度下降更新的最小值：  -4.822369262400634
# -----------------------------梯度下降更新的最小值：  -4.714921877152621
# -----------------------------梯度下降更新的最小值：  -4.609623439609568
# -----------------------------梯度下降更新的最小值：  -4.506430970817377
# -----------------------------梯度下降更新的最小值：  -4.405302351401029
# -----------------------------梯度下降更新的最小值：  -4.3061963043730085
# -----------------------------梯度下降更新的最小值：  -4.209072378285549
# -----------------------------梯度下降更新的最小值：  -4.113890930719838
# -----------------------------梯度下降更新的最小值：  -4.020613112105441
# -----------------------------梯度下降更新的最小值：  -3.9292008498633324
# -----------------------------梯度下降更新的最小值：  -3.839616832866066
# -----------------------------梯度下降更新的最小值：  -3.7518244962087444
# -----------------------------梯度下降更新的最小值：  -3.6657880062845694
# -----------------------------梯度下降更新的最小值：  -3.581472246158878
# -----------------------------梯度下降更新的最小值：  -3.4988428012357002
# -----------------------------梯度下降更新的最小值：  -3.4178659452109863
# -----------------------------梯度下降更新的最小值：  -3.3385086263067665
# -----------------------------梯度下降更新的最小值：  -3.260738453780631
# -----------------------------梯度下降更新的最小值：  -3.1845236847050185
# -----------------------------梯度下降更新的最小值：  -3.109833211010918
# -----------------------------梯度下降更新的最小值：  -3.0366365467907
# -----------------------------梯度下降更新的最小值：  -2.964903815854886
# -----------------------------梯度下降更新的最小值：  -2.894605739537788
# -----------------------------梯度下降更新的最小值：  -2.8257136247470322
# -----------------------------梯度下降更新的最小值：  -2.758199352252092
# -----------------------------梯度下降更新的最小值：  -2.69203536520705
# -----------------------------梯度下降更新的最小值：  -2.6271946579029093
# -----------------------------梯度下降更新的最小值：  -2.563650764744851
# -----------------------------梯度下降更新的最小值：  -2.501377749449954
# -----------------------------梯度下降更新的最小值：  -2.440350194460955
# -----------------------------梯度下降更新的最小值：  -2.380543190571736
# -----------------------------梯度下降更新的最小值：  -2.3219323267603014
# -----------------------------梯度下降更新的最小值：  -2.2644936802250952
# -----------------------------梯度下降更新的最小值：  -2.208203806620593
# -----------------------------梯度下降更新的最小值：  -2.153039730488181
# -----------------------------梯度下降更新的最小值：  -2.0989789358784177
# -----------------------------梯度下降更新的最小值：  -2.0459993571608495
# -----------------------------梯度下降更新的最小值：  -1.9940793700176325
# -----------------------------梯度下降更新的最小值：  -1.9431977826172797
# -----------------------------梯度下降更新的最小值：  -1.893333826964934
# -----------------------------梯度下降更新的最小值：  -1.8444671504256354
# -----------------------------梯度下降更新的最小值：  -1.7965778074171226
# -----------------------------梯度下降更新的最小值：  -1.74964625126878
# -----------------------------梯度下降更新的最小值：  -1.7036533262434044
# -----------------------------梯度下降更新的最小值：  -1.6585802597185362
# -----------------------------梯度下降更新的最小值：  -1.6144086545241654
# -----------------------------梯度下降更新的最小值：  -1.571120481433682
# -----------------------------梯度下降更新的最小值：  -1.5286980718050085
# -----------------------------梯度下降更新的最小值：  -1.4871241103689083
# -----------------------------梯度下降更新的最小值：  -1.4463816281615303
# -----------------------------梯度下降更新的最小值：  -1.4064539955982998
# -----------------------------梯度下降更新的最小值：  -1.3673249156863339
# -----------------------------梯度下降更新的最小值：  -1.3289784173726071
# -----------------------------梯度下降更新的最小值：  -1.291398849025155
# -----------------------------梯度下降更新的最小值：  -1.2545708720446518
# -----------------------------梯度下降更新的最小值：  -1.2184794546037587
# -----------------------------梯度下降更新的最小值：  -1.1831098655116836
# -----------------------------梯度下降更新的最小值：  -1.14844766820145
# -----------------------------梯度下降更新的最小值：  -1.114478714837421
# -----------------------------梯度下降更新的最小值：  -1.0811891405406724
# -----------------------------梯度下降更新的最小值：  -1.048565357729859
# -----------------------------梯度下降更新的最小值：  -1.0165940505752618
# -----------------------------梯度下降更新的最小值：  -0.9852621695637566
# -----------------------------梯度下降更新的最小值：  -0.9545569261724814
# -----------------------------梯度下降更新的最小值：  -0.9244657876490319
# -----------------------------梯度下降更新的最小值：  -0.8949764718960512
# -----------------------------梯度下降更新的最小值：  -0.8660769424581302
# -----------------------------梯度下降更新的最小值：  -0.8377554036089676
# -----------------------------梯度下降更新的最小值：  -0.8100002955367882
# -----------------------------梯度下降更新的最小值：  -0.7828002896260524
# -----------------------------梯度下降更新的最小值：  -0.7561442838335314
# -----------------------------梯度下降更新的最小值：  -0.7300213981568607
# -----------------------------梯度下降更新的最小值：  -0.7044209701937235
# -----------------------------梯度下降更新的最小值：  -0.679332550789849
# -----------------------------梯度下降更新的最小值：  -0.6547458997740521
# -----------------------------梯度下降更新的最小值：  -0.630650981778571
# -----------------------------梯度下降更新的最小值：  -0.6070379621429997
# -----------------------------梯度下降更新的最小值：  -0.5838972029001397
# -----------------------------梯度下降更新的最小值：  -0.5612192588421369
# -----------------------------梯度下降更新的最小值：  -0.5389948736652941
# -----------------------------梯度下降更新的最小值：  -0.5172149761919882
# -----------------------------梯度下降更新的最小值：  -0.49587067666814844
# -----------------------------梯度下降更新的最小值：  -0.4749532631347855
# -----------------------------梯度下降更新的最小值：  -0.45445419787208974
# -----------------------------梯度下降更新的最小值：  -0.43436511391464794
# -----------------------------梯度下降更新的最小值：  -0.414677811636355
# -----------------------------梯度下降更新的最小值：  -0.39538425540362787
# -----------------------------梯度下降更新的最小值：  -0.3764765702955553
# -----------------------------梯度下降更新的最小值：  -0.3579470388896442
# -----------------------------梯度下降更新的最小值：  -0.3397880981118513
# -----------------------------梯度下降更新的最小值：  -0.32199233614961426
# -----------------------------梯度下降更新的最小值：  -0.30455248942662194
# -----------------------------梯度下降更新的最小值：  -0.2874614396380895
# -----------------------------梯度下降更新的最小值：  -0.2707122108453277
# -----------------------------梯度下降更新的最小值：  -0.25429796662842113
# -----------------------------梯度下降更新的最小值：  -0.2382120072958527
# -----------------------------梯度下降更新的最小值：  -0.22244776714993564
# -----------------------------梯度下降更新的最小值：  -0.2069988118069369
# -----------------------------梯度下降更新的最小值：  -0.19185883557079816
# -----------------------------梯度下降更新的最小值：  -0.1770216588593822
# -----------------------------梯度下降更新的最小值：  -0.16248122568219456
# -----------------------------梯度下降更新的最小值：  -0.14823160116855066
# -----------------------------梯度下降更新的最小值：  -0.13426696914517966
# -----------------------------梯度下降更新的最小值：  -0.12058162976227607
# -----------------------------梯度下降更新的最小值：  -0.10716999716703055
# -----------------------------梯度下降更新的最小值：  -0.09402659722368993
# -----------------------------梯度下降更新的最小值：  -0.08114606527921614
# -----------------------------梯度下降更新的最小值：  -0.06852314397363181
# -----------------------------梯度下降更新的最小值：  -0.05615268109415917
# -----------------------------梯度下降更新的最小值：  -0.044029627472275984
# -----------------------------梯度下降更新的最小值：  -0.032149034922830465
# -----------------------------梯度下降更新的最小值：  -0.020506054224373856
# -----------------------------梯度下降更新的最小值：  -0.009095933139886376
# -----------------------------梯度下降更新的最小值：  0.0020859855229113516
# -----------------------------梯度下降更新的最小值：  0.013044265812453125
# -----------------------------梯度下降更新的最小值：  0.023783380496204064
# -----------------------------梯度下降更新的最小值：  0.034307712886279984
# -----------------------------梯度下降更新的最小值：  0.04462155862855439
# -----------------------------梯度下降更新的最小值：  0.0547291274559833
# -----------------------------梯度下降更新的最小值：  0.06463454490686364
# -----------------------------梯度下降更新的最小值：  0.07434185400872637
# -----------------------------梯度下降更新的最小值：  0.08385501692855184
# -----------------------------梯度下降更新的最小值：  0.0931779165899808
# -----------------------------梯度下降更新的最小值：  0.10231435825818118
# -----------------------------梯度下降更新的最小值：  0.11126807109301756
# -----------------------------梯度下降更新的最小值：  0.12004270967115721
# -----------------------------梯度下降更新的最小值：  0.12864185547773407
# -----------------------------梯度下降更新的最小值：  0.1370690183681794
# -----------------------------梯度下降更新的最小值：  0.1453276380008158
# -----------------------------梯度下降更新的最小值：  0.15342108524079948
# -----------------------------梯度下降更新的最小值：  0.1613526635359835
# -----------------------------梯度下降更新的最小值：  0.16912561026526382
# -----------------------------梯度下降更新的最小值：  0.17674309805995855
# -----------------------------梯度下降更新的最小值：  0.1842082360987594
# -----------------------------梯度下降更新的最小值：  0.1915240713767842
# -----------------------------梯度下降更新的最小值：  0.19869358994924852
# -----------------------------梯度下降更新的最小值：  0.20571971815026355
# -----------------------------梯度下降更新的最小值：  0.21260532378725827
# -----------------------------梯度下降更新的最小值：  0.2193532173115131
# -----------------------------梯度下降更新的最小值：  0.22596615296528286
# -----------------------------梯度下降更新的最小值：  0.2324468299059772
# -----------------------------梯度下降更新的最小值：  0.23879789330785767
# -----------------------------梯度下降更新的最小值：  0.2450219354417005
# -----------------------------梯度下降更新的最小值：  0.2511214967328665
# -----------------------------梯度下降更新的最小值：  0.25709906679820915
# -----------------------------梯度下降更新的最小值：  0.26295708546224494
# -----------------------------梯度下降更新的最小值：  0.26869794375300005
# -----------------------------梯度下降更新的最小值：  0.27432398487794
# -----------------------------梯度下降更新的最小值：  0.2798375051803812
# -----------------------------梯度下降更新的最小值：  0.2852407550767736
# -----------------------------梯度下降更新的最小值：  0.29053593997523813
# -----------------------------梯度下降更新的最小值：  0.29572522117573335
# -----------------------------梯度下降更新的最小值：  0.3008107167522187
# -----------------------------梯度下降更新的最小值：  0.3057945024171743
# -----------------------------梯度下降更新的最小值：  0.3106786123688308
# -----------------------------梯度下降更新的最小值：  0.3154650401214542
# -----------------------------梯度下降更新的最小值：  0.32015573931902513
# -----------------------------梯度下降更新的最小值：  0.32475262453264464
# -----------------------------梯度下降更新的最小值：  0.32925757204199174
# -----------------------------梯度下降更新的最小值：  0.33367242060115193
# -----------------------------梯度下降更新的最小值：  0.3379989721891289
# -----------------------------梯度下降更新的最小值：  0.3422389927453463
# -----------------------------梯度下降更新的最小值：  0.34639421289043937
# -----------------------------梯度下降更新的最小值：  0.3504663286326306
# -----------------------------梯度下降更新的最小值：  0.354457002059978
# -----------------------------梯度下降更新的最小值：  0.3583678620187784
# -----------------------------梯度下降更新的最小值：  0.3622005047784028
# -----------------------------梯度下降更新的最小值：  0.36595649468283475
# -----------------------------梯度下降更新的最小值：  0.3696373647891781
# -----------------------------梯度下降更新的最小值：  0.3732446174933945
# -----------------------------梯度下降更新的最小值：  0.3767797251435266
# -----------------------------梯度下降更新的最小值：  0.38024413064065604
# -----------------------------梯度下降更新的最小值：  0.38363924802784294
# -----------------------------梯度下降更新的最小值：  0.3869664630672861
# -----------------------------梯度下降更新的最小值：  0.3902271338059404
# -----------------------------梯度下降更新的最小值：  0.3934225911298216
# -----------------------------梯度下降更新的最小值：  0.39655413930722516
# -----------------------------梯度下降更新的最小值：  0.39962305652108066
# -----------------------------梯度下降更新的最小值：  0.40263059539065904
# -----------------------------梯度下降更新的最小值：  0.40557798348284585
# -----------------------------梯度下降更新的最小值：  0.40846642381318893
# -----------------------------梯度下降更新的最小值：  0.41129709533692516
# -----------------------------梯度下降更新的最小值：  0.41407115343018663
# -----------------------------梯度下降更新的最小值：  0.4167897303615829
# -----------------------------梯度下降更新的最小值：  0.41945393575435125
# -----------------------------梯度下降更新的最小值：  0.4220648570392642
# -----------------------------梯度下降更新的最小值：  0.42462355989847894
# -----------------------------梯度下降更新的最小值：  0.42713108870050936
# -----------------------------梯度下降更新的最小值：  0.42958846692649916
# -----------------------------梯度下降更新的最小值：  0.43199669758796916
# -----------------------------梯度下降更新的最小值：  0.4343567636362098
# -----------------------------梯度下降更新的最小值：  0.4366696283634856
# -----------------------------梯度下降更新的最小值：  0.4389362357962159
# -----------------------------梯度下降更新的最小值：  0.44115751108029155
# -----------------------------梯度下降更新的最小值：  0.4433343608586857
# -----------------------------梯度下降更新的最小值：  0.445467673641512
# -----------------------------梯度下降更新的最小值：  0.4475583201686818
# -----------------------------梯度下降更新的最小值：  0.4496071537653082
# -----------------------------梯度下降更新的最小值：  0.45161501069000204
# -----------------------------梯度下降更新的最小值：  0.453582710476202
# -----------------------------梯度下降更新的最小值：  0.455511056266678
# -----------------------------梯度下降更新的最小值：  0.45740083514134444
# -----------------------------梯度下降更新的最小值：  0.45925281843851756
# -----------------------------梯度下降更新的最小值：  0.4610677620697472
# -----------------------------梯度下降更新的最小值：  0.46284640682835226
# -----------------------------梯度下降更新的最小值：  0.46458947869178524
# -----------------------------梯度下降更新的最小值：  0.46629768911794955
# -----------------------------梯度下降更新的最小值：  0.46797173533559056
# -----------------------------梯度下降更新的最小值：  0.46961230062887876
# -----------------------------梯度下降更新的最小值：  0.4712200546163012
# -----------------------------梯度下降更新的最小值：  0.4727956535239752
# -----------------------------梯度下降更新的最小值：  0.4743397404534957
# -----------------------------梯度下降更新的最小值：  0.47585294564442576
# -----------------------------梯度下降更新的最小值：  0.47733588673153726
# -----------------------------梯度下降更新的最小值：  0.47878916899690654
# -----------------------------梯度下降更新的最小值：  0.4802133856169684
# -----------------------------梯度下降更新的最小值：  0.48160911790462907
# -----------------------------梯度下降更新的最小值：  0.4829769355465365
# -----------------------------梯度下降更新的最小值：  0.48431739683560576
# -----------------------------梯度下降更新的最小值：  0.48563104889889364
# -----------------------------梯度下降更新的最小值：  0.4869184279209158
# -----------------------------梯度下降更新的最小值：  0.4881800593624975
# -----------------------------梯度下降更新的最小值：  0.48941645817524754
# -----------------------------梯度下降更新的最小值：  0.4906281290117426
# -----------------------------梯度下降更新的最小值：  0.4918155664315077
# -----------------------------梯度下降更新的最小值：  0.49297925510287754
# -----------------------------梯度下降更新的最小值：  0.49411967000082
# -----------------------------梯度下降更新的最小值：  0.49523727660080363
# -----------------------------梯度下降更新的最小值：  0.49633253106878755
# -----------------------------梯度下降更新的最小值：  0.4974058804474118
# -----------------------------梯度下降更新的最小值：  0.49845776283846355
# -----------------------------梯度下降更新的最小值：  0.4994886075816943
# -----------------------------梯度下降更新的最小值：  0.5004988354300604
# -----------------------------梯度下降更新的最小值：  0.5014888587214591
# -----------------------------梯度下降更新的最小值：  0.5024590815470299
# -----------------------------梯度下降更新的最小值：  0.5034098999160893
# -----------------------------梯度下降更新的最小值：  0.5043417019177675
# -----------------------------梯度下降更新的最小值：  0.5052548678794122
# -----------------------------梯度下降更新的最小值：  0.506149770521824
# -----------------------------梯度下降更新的最小值：  0.5070267751113875
# -----------------------------梯度下降更新的最小值：  0.5078862396091598
# -----------------------------梯度下降更新的最小值：  0.5087285148169766
# -----------------------------梯度下降更新的最小值：  0.5095539445206371
# -----------------------------梯度下降更新的最小值：  0.5103628656302244
# -----------------------------梯度下降更新的最小值：  0.5111556083176199
# -----------------------------梯度下降更新的最小值：  0.5119324961512675
# -----------------------------梯度下降更新的最小值：  0.5126938462282421
# -----------------------------梯度下降更新的最小值：  0.5134399693036773
# -----------------------------梯度下降更新的最小值：  0.5141711699176038
# -----------------------------梯度下降更新的最小值：  0.5148877465192517
# -----------------------------梯度下降更新的最小值：  0.5155899915888666
# -----------------------------梯度下降更新的最小值：  0.5162781917570893
# -----------------------------梯度下降更新的最小值：  0.5169526279219475
# -----------------------------梯度下降更新的最小值：  0.5176135753635086
# -----------------------------梯度下降更新的最小值：  0.5182613038562385
# -----------------------------梯度下降更新的最小值：  0.5188960777791137
# -----------------------------梯度下降更新的最小值：  0.5195181562235315
# -----------------------------梯度下降更新的最小值：  0.5201277930990609
# -----------------------------梯度下降更新的最小值：  0.5207252372370796
# -----------------------------梯度下降更新的最小值：  0.5213107324923381
# -----------------------------梯度下降更新的最小值：  0.5218845178424913
# -----------------------------梯度下降更新的最小值：  0.5224468274856415
# -----------------------------梯度下降更新的最小值：  0.5229978909359287
# -----------------------------梯度下降更新的最小值：  0.5235379331172102
# -----------------------------梯度下降更新的最小值：  0.524067174454866
# -----------------------------梯度下降更新的最小值：  0.5245858309657686
# -----------------------------梯度下降更新的最小值：  0.5250941143464533
# -----------------------------梯度下降更新的最小值：  0.5255922320595242
# -----------------------------梯度下降更新的最小值：  0.5260803874183337
# -----------------------------梯度下降更新的最小值：  0.5265587796699671
# -----------------------------梯度下降更新的最小值：  0.5270276040765678
# -----------------------------梯度下降更新的最小值：  0.5274870519950364
# -----------------------------梯度下降更新的最小值：  0.5279373109551357
# -----------------------------梯度下降更新的最小值：  0.5283785647360331
# -----------------------------梯度下降更新的最小值：  0.5288109934413124
# -----------------------------梯度下降更新的最小值：  0.5292347735724862
# -----------------------------梯度下降更新的最小值：  0.5296500781010365
# -----------------------------梯度下降更新的最小值：  0.5300570765390158
# -----------------------------梯度下降更新的最小值：  0.5304559350082355
# -----------------------------梯度下降更新的最小值：  0.5308468163080708
# -----------------------------梯度下降更新的最小值：  0.5312298799819094
# -----------------------------梯度下降更新的最小值：  0.5316052823822712
# -----------------------------梯度下降更新的最小值：  0.5319731767346259
# -----------------------------梯度下降更新的最小值：  0.5323337131999334
# -----------------------------梯度下降更新的最小值：  0.5326870389359347
# -----------------------------梯度下降更新的最小值：  0.533033298157216
# -----------------------------梯度下降更新的最小值：  0.5333726321940717
# -----------------------------梯度下降更新的最小值：  0.5337051795501903
# -----------------------------梯度下降更新的最小值：  0.5340310759591864
# -----------------------------梯度下降更新的最小值：  0.5343504544400027
# -----------------------------梯度下降更新的最小值：  0.5346634453512027
# -----------------------------梯度下降更新的最小值：  0.5349701764441787
# -----------------------------梯度下降更新的最小值：  0.5352707729152951
# -----------------------------梯度下降更新的最小值：  0.5355653574569892
# -----------------------------梯度下降更新的最小值：  0.5358540503078494
# -----------------------------梯度下降更新的最小值：  0.5361369693016924
# -----------------------------梯度下降更新的最小值：  0.5364142299156586
# -----------------------------梯度下降更新的最小值：  0.5366859453173454
# -----------------------------梯度下降更新的最小值：  0.5369522264109985
# -----------------------------梯度下降更新的最小值：  0.5372131818827786
# -----------------------------梯度下降更新的最小值：  0.537468918245123
# -----------------------------梯度下降更新的最小值：  0.5377195398802206
# -----------------------------梯度下降更新的最小值：  0.5379651490826162
# -----------------------------梯度下降更新的最小值：  0.5382058461009639
# -----------------------------梯度下降更新的最小值：  0.5384417291789446
# -----------------------------梯度下降更新的最小值：  0.5386728945953657
# -----------------------------梯度下降更新的最小值：  0.5388994367034584
# -----------------------------梯度下降更新的最小值：  0.5391214479693892
# -----------------------------梯度下降更新的最小值：  0.5393390190100015
# -----------------------------梯度下降更新的最小值：  0.5395522386298014
# -----------------------------梯度下降更新的最小值：  0.5397611938572053
# -----------------------------梯度下降更新的最小值：  0.5399659699800612
# -----------------------------梯度下降更新的最小值：  0.54016665058046
# -----------------------------梯度下降更新的最小值：  0.5403633175688508
# -----------------------------梯度下降更新的最小值：  0.5405560512174737
# -----------------------------梯度下降更新的最小值：  0.5407449301931243
# -----------------------------梯度下降更新的最小值：  0.5409300315892618
# -----------------------------梯度下降更新的最小值：  0.5411114309574766
# -----------------------------梯度下降更新的最小值：  0.5412892023383271
# -----------------------------梯度下降更新的最小值：  0.5414634182915605
# -----------------------------梯度下降更新的最小值：  0.5416341499257293
# -----------------------------梯度下降更新的最小值：  0.5418014669272148
# -----------------------------梯度下降更新的最小值：  0.5419654375886704
# -----------------------------梯度下降更新的最小值：  0.542126128836897
# -----------------------------梯度下降更新的最小值：  0.5422836062601591
# -----------------------------梯度下降更新的最小值：  0.542437934134956
# -----------------------------梯度下降更新的最小值：  0.5425891754522569
# -----------------------------梯度下降更新的最小值：  0.5427373919432118
# -----------------------------梯度下降更新的最小值：  0.5428826441043476
# -----------------------------梯度下降更新的最小值：  0.5430249912222607
# -----------------------------梯度下降更新的最小值：  0.5431644913978154
# -----------------------------梯度下降更新的最小值：  0.5433012015698591
# -----------------------------梯度下降更新的最小值：  0.5434351775384619
# -----------------------------梯度下降更新的最小值：  0.5435664739876926
# -----------------------------梯度下降更新的最小值：  0.5436951445079388
# -----------------------------梯度下降更新的最小值：  0.54382124161778
# -----------------------------梯度下降更新的最小值：  0.5439448167854244
# -----------------------------梯度下降更新的最小值：  0.5440659204497159
# -----------------------------梯度下降更新的最小值：  0.5441846020407216
# -----------------------------梯度下降更新的最小值：  0.5443009099999072
# -----------------------------梯度下降更新的最小值：  0.5444148917999091
# -----------------------------梯度下降更新的最小值：  0.5445265939639109
# -----------------------------梯度下降更新的最小值：  0.5446360620846327
# -----------------------------梯度下降更新的最小值：  0.54474334084294
# -----------------------------梯度下降更新的最小值：  0.5448484740260812
# -----------------------------梯度下降更新的最小值：  0.5449515045455595
# -----------------------------梯度下降更新的最小值：  0.5450524744546483
# -----------------------------梯度下降更新的最小值：  0.5451514249655554
# -----------------------------梯度下降更新的最小值：  0.5452483964662442
# -----------------------------梯度下降更新的最小值：  0.5453434285369193
# -----------------------------梯度下降更新的最小值：  0.5454365599661809
# -----------------------------梯度下降更新的最小值：  0.5455278287668572
# -----------------------------梯度下降更新的最小值：  0.5456172721915201
# -----------------------------梯度下降更新的最小值：  0.5457049267476897
# -----------------------------梯度下降更新的最小值：  0.5457908282127358
# -----------------------------梯度下降更新的最小值：  0.5458750116484811
# -----------------------------梯度下降更新的最小值：  0.5459575114155114
# -----------------------------梯度下降更新的最小值：  0.5460383611872012
# -----------------------------梯度下降更新的最小值：  0.5461175939634572
# -----------------------------梯度下降更新的最小值：  0.546195242084188
# -----------------------------梯度下降更新的最小值：  0.5462713372425042
# -----------------------------梯度下降更新的最小值：  0.5463459104976541
# -----------------------------梯度下降更新的最小值：  0.5464189922877011
# -----------------------------梯度下降更新的最小值：  0.5464906124419471
# -----------------------------梯度下降更新的最小值：  0.5465608001931082
# -----------------------------梯度下降更新的最小值：  0.546629584189246
# -----------------------------梯度下降更新的最小值：  0.5466969925054611
# -----------------------------梯度下降更新的最小值：  0.5467630526553519
# -----------------------------梯度下降更新的最小值：  0.5468277916022448
# -----------------------------梯度下降更新的最小值：  0.5468912357701999
# -----------------------------梯度下降更新的最小值：  0.5469534110547959
# -----------------------------梯度下降更新的最小值：  0.5470143428337
# -----------------------------梯度下降更新的最小值：  0.547074055977026
# -----------------------------梯度下降更新的最小值：  0.5471325748574855
# -----------------------------梯度下降更新的最小值：  0.5471899233603358
# -----------------------------梯度下降更新的最小值：  0.5472461248931291
# -----------------------------梯度下降更新的最小值：  0.5473012023952665
# -----------------------------梯度下降更新的最小值：  0.5473551783473611
# -----------------------------梯度下降更新的最小值：  0.5474080747804139
# -----------------------------梯度下降更新的最小值：  0.5474599132848056
# -----------------------------梯度下降更新的最小值：  0.5475107150191095
# -----------------------------梯度下降更新的最小值：  0.5475605007187273
# -----------------------------梯度下降更新的最小值：  0.5476092907043527
# -----------------------------梯度下降更新的最小值：  0.5476571048902656
# -----------------------------梯度下降更新的最小值：  0.5477039627924604
# -----------------------------梯度下降更新的最小值：  0.5477498835366111
# -----------------------------梯度下降更新的最小值：  0.5477948858658789
# -----------------------------梯度下降更新的最小值：  0.5478389881485612
# -----------------------------梯度下降更新的最小值：  0.54788220838559
# -----------------------------梯度下降更新的最小值：  0.5479245642178782
# -----------------------------梯度下降更新的最小值：  0.5479660729335206
# -----------------------------梯度下降更新的最小值：  0.5480067514748502
# -----------------------------梯度下降更新的最小值：  0.5480466164453532
# -----------------------------梯度下降更新的最小值：  0.5480856841164462
# -----------------------------梯度下降更新的最小值：  0.5481239704341173
# -----------------------------梯度下降更新的最小值：  0.548161491025435
# -----------------------------梯度下降更新的最小值：  0.5481982612049263
# -----------------------------梯度下降更新的最小值：  0.5482342959808278
# -----------------------------梯度下降更新的最小值：  0.5482696100612113
# -----------------------------梯度下降更新的最小值：  0.5483042178599871
# -----------------------------梯度下降更新的最小值：  0.5483381335027874
# -----------------------------梯度下降更新的最小值：  0.5483713708327316
# -----------------------------梯度下降更新的最小值：  0.5484039434160769
# -----------------------------梯度下降更新的最小值：  0.5484358645477554
# -----------------------------梯度下降更新的最小值：  0.5484671472568002
# -----------------------------梯度下降更新的最小值：  0.5484978043116643
# -----------------------------梯度下降更新的最小值：  0.548527848225431
# -----------------------------梯度下降更新的最小值：  0.5485572912609223
# -----------------------------梯度下降更新的最小值：  0.5485861454357039
# -----------------------------梯度下降更新的最小值：  0.5486144225269899
# -----------------------------梯度下降更新的最小值：  0.5486421340764501
# -----------------------------梯度下降更新的最小值：  0.5486692913949212
# -----------------------------梯度下降更新的最小值：  0.5486959055670227
# -----------------------------梯度下降更新的最小值：  0.5487219874556823
# -----------------------------梯度下降更新的最小值：  0.5487475477065688
# -----------------------------梯度下降更新的最小值：  0.5487725967524374
# -----------------------------梯度下降更新的最小值：  0.5487971448173886
# -----------------------------梯度下降更新的最小值：  0.5488212019210409
# -----------------------------梯度下降更新的最小值：  0.5488447778826201
# -----------------------------梯度下降更新的最小值：  0.5488678823249677
# -----------------------------梯度下降更新的最小值：  0.5488905246784684
# -----------------------------梯度下降更新的最小值：  0.5489127141848991
# -----------------------------梯度下降更新的最小值：  0.548934459901201
# -----------------------------梯度下降更新的最小值：  0.548955770703177
# -----------------------------梯度下降更新的最小值：  0.5489766552891134
# -----------------------------梯度下降更新的最小值：  0.5489971221833312
# -----------------------------梯度下降更新的最小值：  0.5490171797396646
# -----------------------------梯度下降更新的最小值：  0.5490368361448713
# -----------------------------梯度下降更新的最小值：  0.5490560994219739
# -----------------------------梯度下降更新的最小值：  0.5490749774335344
# -----------------------------梯度下降更新的最小值：  0.5490934778848637
# -----------------------------梯度下降更新的最小值：  0.5491116083271664
# -----------------------------梯度下降更新的最小值：  0.5491293761606231
# -----------------------------梯度下降更新的最小值：  0.5491467886374106
# -----------------------------梯度下降更新的最小值：  0.5491638528646624
# -----------------------------梯度下降更新的最小值：  0.5491805758073691
# -----------------------------梯度下降更新的最小值：  0.5491969642912218
# -----------------------------梯度下降更新的最小值：  0.5492130250053974
# -----------------------------梯度下降更新的最小值：  0.5492287645052895
# -----------------------------梯度下降更新的最小值：  0.5492441892151837
# -----------------------------梯度下降更新的最小值：  0.54925930543088
# -----------------------------梯度下降更新的最小值：  0.5492741193222623
# -----------------------------梯度下降更新的最小值：  0.5492886369358171
# -----------------------------梯度下降更新的最小值：  0.5493028641971007
# -----------------------------梯度下降更新的最小值：  0.5493168069131588
# -----------------------------梯度下降更新的最小值：  0.5493304707748956
# -----------------------------梯度下降更新的最小值：  0.5493438613593977
# -----------------------------梯度下降更新的最小值：  0.5493569841322098
# -----------------------------梯度下降更新的最小值：  0.5493698444495656
# -----------------------------梯度下降更新的最小值：  0.5493824475605743
# -----------------------------梯度下降更新的最小值：  0.5493947986093628
# -----------------------------梯度下降更新的最小值：  0.5494069026371755
# -----------------------------梯度下降更新的最小值：  0.549418764584432
# -----------------------------梯度下降更新的最小值：  0.5494303892927433
# -----------------------------梯度下降更新的最小值：  0.5494417815068885
# -----------------------------梯度下降更新的最小值：  0.5494529458767508
# -----------------------------梯度下降更新的最小值：  0.5494638869592158
# -----------------------------梯度下降更新的最小值：  0.5494746092200314
# -----------------------------梯度下降更新的最小值：  0.5494851170356309
# -----------------------------梯度下降更新的最小值：  0.5494954146949182
# -----------------------------梯度下降更新的最小值：  0.5495055064010199
# -----------------------------梯度下降更新的最小值：  0.5495153962729995

# %%
plt.figure(figsize=(12,9))
x = np.linspace(-8,5,100)
plt.plot(x,f(x))

# 绘制最小值的点result

plt.scatter(result,f(np.array(result)),marker = '*',color= 'red')
