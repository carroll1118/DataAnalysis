# %%
# 如果有截距，不能使用求导数，导数最小求解问题

# %% [markdown]
# ![](1.png)

# %% [markdown]
# ![](2.png)

# %%
# 如果有截距，求解时，需要梯度下降法求解w和b

# %%
# 什么是梯度？？？
# 梯度就是导数
# 梯度下降是求解最大值，最小值最快的速度
# 导数是函数变化率最快的方向

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f = lambda x : (x - 4.3)**2 + 7.5*x + 6

# %%
# 导数知晓，最小值是0.55
g = lambda x: 2*x - 1.1

# %%
x = np.linspace(-5,9,100)

plt.plot(x,f(x))

# %%
# 梯度爆炸

# %%
result = []
# 设起始值的数值
v_min = np.random.randint(-10,10,size = 1)[0]
result.append(v_min)
# 该值记录梯度下降过程中，上一步的值
v_min_last = v_min + 1
# 什么时候梯度下降结束，精度退出条件
precision = 0.00001
# 在一个退出条件，循环次数
max_time = 3000
# 步幅
step = 10
count = 0
print('-------------------------------随机生成的最小值： ',v_min)
while True:
    if np.abs(v_min - v_min_last) < precision:
        break
    if count > max_time:
        break
    v_min_last = v_min
    v_min = v_min - g(v_min)*step
    result.append(v_min)
    print('-----------------------------梯度下降更新的最小值： ',v_min)
    count += 1
# Out:
# -------------------------------随机生成的最小值：  -1
# -----------------------------梯度下降更新的最小值：  30.0
# -----------------------------梯度下降更新的最小值：  -559.0
# -----------------------------梯度下降更新的最小值：  10632.0
# -----------------------------梯度下降更新的最小值：  -201997.0
# -----------------------------梯度下降更新的最小值：  3837954.0
# -----------------------------梯度下降更新的最小值：  -72921115.0
# -----------------------------梯度下降更新的最小值：  1385501196.0
# -----------------------------梯度下降更新的最小值：  -26324522713.0
# -----------------------------梯度下降更新的最小值：  500165931558.0
# -----------------------------梯度下降更新的最小值：  -9503152699591.0
# -----------------------------梯度下降更新的最小值：  180559901292240.0
# -----------------------------梯度下降更新的最小值：  -3430638124552549.0
# -----------------------------梯度下降更新的最小值：  6.518212436649844e+16
# -----------------------------梯度下降更新的最小值：  -1.2384603629634703e+18
# -----------------------------梯度下降更新的最小值：  2.353074689630594e+19
# -----------------------------梯度下降更新的最小值：  -4.4708419102981285e+20
# -----------------------------梯度下降更新的最小值：  8.494599629566444e+21
# -----------------------------梯度下降更新的最小值：  -1.6139739296176245e+23
# -----------------------------梯度下降更新的最小值：  3.066550466273487e+24
# -----------------------------梯度下降更新的最小值：  -5.826445885919625e+25
# -----------------------------梯度下降更新的最小值：  1.1070247183247288e+27
# -----------------------------梯度下降更新的最小值：  -2.103346964816985e+28
# -----------------------------梯度下降更新的最小值：  3.9963592331522714e+29
# -----------------------------梯度下降更新的最小值：  -7.593082542989316e+30
# -----------------------------梯度下降更新的最小值：  1.44268568316797e+32
# -----------------------------梯度下降更新的最小值：  -2.7411027980191427e+33
# -----------------------------梯度下降更新的最小值：  5.208095316236371e+34
# -----------------------------梯度下降更新的最小值：  -9.895381100849106e+35
# -----------------------------梯度下降更新的最小值：  1.88012240916133e+37
# -----------------------------梯度下降更新的最小值：  -3.572232577406527e+38
# -----------------------------梯度下降更新的最小值：  6.787241897072402e+39
# -----------------------------梯度下降更新的最小值：  -1.2895759604437564e+41
# -----------------------------梯度下降更新的最小值：  2.4501943248431375e+42
# -----------------------------梯度下降更新的最小值：  -4.655369217201962e+43
# -----------------------------梯度下降更新的最小值：  8.845201512683727e+44
# -----------------------------梯度下降更新的最小值：  -1.6805882874099083e+46
# -----------------------------梯度下降更新的最小值：  3.193117746078826e+47
# -----------------------------梯度下降更新的最小值：  -6.066923717549768e+48
# -----------------------------梯度下降更新的最小值：  1.152715506334456e+50
# -----------------------------梯度下降更新的最小值：  -2.1901594620354665e+51
# -----------------------------梯度下降更新的最小值：  4.161302977867387e+52
# -----------------------------梯度下降更新的最小值：  -7.906475657948035e+53
# -----------------------------梯度下降更新的最小值：  1.5022303750101266e+55
# -----------------------------梯度下降更新的最小值：  -2.8542377125192408e+56
# -----------------------------梯度下降更新的最小值：  5.4230516537865576e+57
# -----------------------------梯度下降更新的最小值：  -1.030379814219446e+59
# -----------------------------梯度下降更新的最小值：  1.9577216470169474e+60
# -----------------------------梯度下降更新的最小值：  -3.7196711293322e+61
# -----------------------------梯度下降更新的最小值：  7.06737514573118e+62
# -----------------------------梯度下降更新的最小值：  -1.342801277688924e+64
# -----------------------------梯度下降更新的最小值：  2.5513224276089562e+65
# -----------------------------梯度下降更新的最小值：  -4.8475126124570174e+66
# -----------------------------梯度下降更新的最小值：  9.210273963668333e+67
# -----------------------------梯度下降更新的最小值：  -1.749952053096983e+69
# -----------------------------梯度下降更新的最小值：  3.3249089008842684e+70
# -----------------------------梯度下降更新的最小值：  -6.31732691168011e+71
# -----------------------------梯度下降更新的最小值：  1.2002921132192208e+73
# -----------------------------梯度下降更新的最小值：  -2.28055501511652e+74
# -----------------------------梯度下降更新的最小值：  4.333054528721388e+75
# -----------------------------梯度下降更新的最小值：  -8.232803604570636e+76
# -----------------------------梯度下降更新的最小值：  1.5642326848684208e+78
# -----------------------------梯度下降更新的最小值：  -2.97204210125e+79
# -----------------------------梯度下降更新的最小值：  5.646879992374999e+80
# -----------------------------梯度下降更新的最小值：  -1.07290719855125e+82
# -----------------------------梯度下降更新的最小值：  2.038523677247375e+83
# -----------------------------梯度下降更新的最小值：  -3.873194986770012e+84
# -----------------------------梯度下降更新的最小值：  7.359070474863022e+85
# -----------------------------梯度下降更新的最小值：  -1.398223390223974e+87
# -----------------------------梯度下降更新的最小值：  2.6566244414255506e+88
# -----------------------------梯度下降更新的最小值：  -5.047586438708546e+89
# -----------------------------梯度下降更新的最小值：  9.590414233546237e+90
# -----------------------------梯度下降更新的最小值：  -1.822178704373785e+92
# -----------------------------梯度下降更新的最小值：  3.4621395383101917e+93
# -----------------------------梯度下降更新的最小值：  -6.578065122789364e+94
# -----------------------------梯度下降更新的最小值：  1.2498323733299792e+96
# -----------------------------梯度下降更新的最小值：  -2.3746815093269604e+97
# -----------------------------梯度下降更新的最小值：  4.511894867721225e+98
# -----------------------------梯度下降更新的最小值：  -8.572600248670327e+99
# -----------------------------梯度下降更新的最小值：  1.6287940472473623e+101
# -----------------------------梯度下降更新的最小值：  -3.0947086897699883e+102
# -----------------------------梯度下降更新的最小值：  5.879946510562978e+103
# -----------------------------梯度下降更新的最小值：  -1.117189837006966e+105
# -----------------------------梯度下降更新的最小值：  2.1226606903132356e+106
# -----------------------------梯度下降更新的最小值：  -4.0330553115951476e+107
# -----------------------------梯度下降更新的最小值：  7.66280509203078e+108
# -----------------------------梯度下降更新的最小值：  -1.4559329674858482e+110
# -----------------------------梯度下降更新的最小值：  2.766272638223111e+111
# -----------------------------梯度下降更新的最小值：  -5.25591801262391e+112
# -----------------------------梯度下降更新的最小值：  9.98624422398543e+113
# -----------------------------梯度下降更新的最小值：  -1.897386402557232e+115
# -----------------------------梯度下降更新的最小值：  3.605034164858741e+116
# -----------------------------梯度下降更新的最小值：  -6.849564913231607e+117
# -----------------------------梯度下降更新的最小值：  1.3014173335140053e+119
# -----------------------------梯度下降更新的最小值：  -2.4726929336766103e+120
# -----------------------------梯度下降更新的最小值：  4.69811657398556e+121
# -----------------------------梯度下降更新的最小值：  -8.926421490572563e+122
# -----------------------------梯度下降更新的最小值：  1.696020083208787e+124
# -----------------------------梯度下降更新的最小值：  -3.2224381580966953e+125
# -----------------------------梯度下降更新的最小值：  6.122632500383722e+126
# -----------------------------梯度下降更新的最小值：  -1.1633001750729072e+128
# -----------------------------梯度下降更新的最小值：  2.2102703326385237e+129
# -----------------------------梯度下降更新的最小值：  -4.199513632013195e+130
# -----------------------------梯度下降更新的最小值：  7.979075900825071e+131
# -----------------------------梯度下降更新的最小值：  -1.5160244211567634e+133
# -----------------------------梯度下降更新的最小值：  2.8804464001978507e+134
# -----------------------------梯度下降更新的最小值：  -5.472848160375916e+135
# -----------------------------梯度下降更新的最小值：  1.039841150471424e+137
# -----------------------------梯度下降更新的最小值：  -1.9756981858957055e+138
# -----------------------------梯度下降更新的最小值：  3.753826553201841e+139
# -----------------------------梯度下降更新的最小值：  -7.132270451083498e+140
# -----------------------------梯度下降更新的最小值：  1.3551313857058646e+142
# -----------------------------梯度下降更新的最小值：  -2.5747496328411427e+143
# -----------------------------梯度下降更新的最小值：  4.892024302398171e+144
# -----------------------------梯度下降更新的最小值：  -9.294846174556526e+145
# -----------------------------梯度下降更新的最小值：  1.7660207731657398e+147
# -----------------------------梯度下降更新的最小值：  -3.3554394690149056e+148
# -----------------------------梯度下降更新的最小值：  6.375334991128321e+149
# -----------------------------梯度下降更新的最小值：  -1.2113136483143809e+151
# -----------------------------梯度下降更新的最小值：  2.301495931797324e+152
# -----------------------------梯度下降更新的最小值：  -4.372842270414916e+153
# -----------------------------梯度下降更新的最小值：  8.30840031378834e+154
# -----------------------------梯度下降更新的最小值：  -1.5785960596197846e+156
# -----------------------------梯度下降更新的最小值：  2.999332513277591e+157
# -----------------------------梯度下降更新的最小值：  -5.698731775227423e+158
# -----------------------------梯度下降更新的最小值：  1.0827590372932104e+160
# -----------------------------梯度下降更新的最小值：  -2.0572421708570997e+161
# -----------------------------梯度下降更新的最小值：  3.9087601246284895e+162
# -----------------------------梯度下降更新的最小值：  -7.426644236794131e+163
# -----------------------------梯度下降更新的最小值：  1.4110624049908848e+165
# -----------------------------梯度下降更新的最小值：  -2.681018569482681e+166
# -----------------------------梯度下降更新的最小值：  5.093935282017094e+167
# -----------------------------梯度下降更新的最小值：  -9.67847703583248e+168
# -----------------------------梯度下降更新的最小值：  1.838910636808171e+170
# -----------------------------梯度下降更新的最小值：  -3.4939302099355253e+171
# -----------------------------梯度下降更新的最小值：  6.638467398877499e+172
# -----------------------------梯度下降更新的最小值：  -1.2613088057867247e+174
# -----------------------------梯度下降更新的最小值：  2.3964867309947768e+175
# -----------------------------梯度下降更新的最小值：  -4.553324788890076e+176
# -----------------------------梯度下降更新的最小值：  8.651317098891144e+177
# -----------------------------梯度下降更新的最小值：  -1.6437502487893172e+179
# -----------------------------梯度下降更新的最小值：  3.1231254726997027e+180
# -----------------------------梯度下降更新的最小值：  -5.933938398129435e+181
# -----------------------------梯度下降更新的最小值：  1.1274482956445925e+183
# -----------------------------梯度下降更新的最小值：  -2.142151761724726e+184
# -----------------------------梯度下降更新的最小值：  4.0700883472769794e+185
# -----------------------------梯度下降更新的最小值：  -7.7331678598262615e+186
# -----------------------------梯度下降更新的最小值：  1.4693018933669897e+188
# -----------------------------梯度下降更新的最小值：  -2.7916735973972806e+189
# -----------------------------梯度下降更新的最小值：  5.3041798350548326e+190
# -----------------------------梯度下降更新的最小值：  -1.0077941686604182e+192
# -----------------------------梯度下降更新的最小值：  1.9148089204547946e+193
# -----------------------------梯度下降更新的最小值：  -3.63813694886411e+194
# -----------------------------梯度下降更新的最小值：  6.912460202841808e+195
# -----------------------------梯度下降更新的最小值：  -1.3133674385399434e+197
# -----------------------------梯度下降更新的最小值：  2.4953981332258926e+198
# -----------------------------梯度下降更新的最小值：  -4.741256453129196e+199
# -----------------------------梯度下降更新的最小值：  9.008387260945472e+200
# -----------------------------梯度下降更新的最小值：  -1.7115935795796396e+202
# -----------------------------梯度下降更新的最小值：  3.252027801201315e+203
# -----------------------------梯度下降更新的最小值：  -6.178852822282499e+204
# -----------------------------梯度下降更新的最小值：  1.1739820362336748e+206
# -----------------------------梯度下降更新的最小值：  -2.2305658688439824e+207
# -----------------------------梯度下降更新的最小值：  4.238075150803566e+208
# -----------------------------梯度下降更新的最小值：  -8.052342786526776e+209
# -----------------------------梯度下降更新的最小值：  1.5299451294400876e+211
# -----------------------------梯度下降更新的最小值：  -2.9068957459361666e+212
# -----------------------------梯度下降更新的最小值：  5.523101917278717e+213
# -----------------------------梯度下降更新的最小值：  -1.049389364282956e+215
# -----------------------------梯度下降更新的最小值：  1.9938397921376164e+216
# -----------------------------梯度下降更新的最小值：  -3.7882956050614715e+217
# -----------------------------梯度下降更新的最小值：  7.197761649616797e+218
# -----------------------------梯度下降更新的最小值：  -1.3675747134271914e+220
# -----------------------------梯度下降更新的最小值：  2.5983919555116635e+221
# -----------------------------梯度下降更新的最小值：  -4.93694471547216e+222
# -----------------------------梯度下降更新的最小值：  9.380194959397106e+223
# -----------------------------梯度下降更新的最小值：  -1.78223704228545e+225
# -----------------------------梯度下降更新的最小值：  3.3862503803423553e+226
# -----------------------------梯度下降更新的最小值：  -6.433875722650475e+227
# -----------------------------梯度下降更新的最小值：  1.2224363873035902e+229
# -----------------------------梯度下降更新的最小值：  -2.3226291358768215e+230
# -----------------------------梯度下降更新的最小值：  4.4129953581659606e+231
# -----------------------------梯度下降更新的最小值：  -8.384691180515325e+232
# -----------------------------梯度下降更新的最小值：  1.593091324297912e+234
# -----------------------------梯度下降更新的最小值：  -3.0268735161660324e+235
# -----------------------------梯度下降更新的最小值：  5.751059680715461e+236
# -----------------------------梯度下降更新的最小值：  -1.0927013393359378e+238
# -----------------------------梯度下降更新的最小值：  2.0761325447382816e+239
# -----------------------------梯度下降更新的最小值：  -3.944651835002735e+240
# -----------------------------梯度下降更新的最小值：  7.494838486505197e+241
# -----------------------------梯度下降更新的最小值：  -1.4240193124359875e+243
# -----------------------------梯度下降更新的最小值：  2.7056366936283765e+244
# -----------------------------梯度下降更新的最小值：  -5.140709717893916e+245
# -----------------------------梯度下降更新的最小值：  9.767348463998441e+246
# -----------------------------梯度下降更新的最小值：  -1.8557962081597037e+248
# -----------------------------梯度下降更新的最小值：  3.526012795503437e+249
# -----------------------------梯度下降更新的最小值：  -6.699424311456529e+250
# -----------------------------梯度下降更新的最小值：  1.2728906191767405e+252
# -----------------------------梯度下降更新的最小值：  -2.418492176435807e+253
# -----------------------------梯度下降更新的最小值：  4.5951351352280333e+254
# -----------------------------梯度下降更新的最小值：  -8.730756756933264e+255
# -----------------------------梯度下降更新的最小值：  1.6588437838173203e+257
# -----------------------------梯度下降更新的最小值：  -3.1518031892529085e+258
# -----------------------------梯度下降更新的最小值：  5.988426059580527e+259
# -----------------------------梯度下降更新的最小值：  -1.1378009513203e+261
# -----------------------------梯度下降更新的最小值：  2.16182180750857e+262
# -----------------------------梯度下降更新的最小值：  -4.107461434266283e+263
# -----------------------------梯度下降更新的最小值：  7.804176725105937e+264
# -----------------------------梯度下降更新的最小值：  -1.4827935777701278e+266
# -----------------------------梯度下降更新的最小值：  2.817307797763243e+267
# -----------------------------梯度下降更新的最小值：  -5.352884815750162e+268
# -----------------------------梯度下降更新的最小值：  1.0170481149925308e+270
# -----------------------------梯度下降更新的最小值：  -1.9323914184858084e+271
# -----------------------------梯度下降更新的最小值：  3.671543695123036e+272
# -----------------------------梯度下降更新的最小值：  -6.975933020733768e+273
# -----------------------------梯度下降更新的最小值：  1.325427273939416e+275
# -----------------------------梯度下降更新的最小值：  -2.5183118204848905e+276
# -----------------------------梯度下降更新的最小值：  4.784792458921292e+277
# -----------------------------梯度下降更新的最小值：  -9.091105671950454e+278
# -----------------------------梯度下降更新的最小值：  1.7273100776705864e+280
# -----------------------------梯度下降更新的最小值：  -3.281889147574114e+281
# -----------------------------梯度下降更新的最小值：  6.235589380390817e+282
# -----------------------------梯度下降更新的最小值：  -1.184761982274255e+284
# -----------------------------梯度下降更新的最小值：  2.2510477663210848e+285
# -----------------------------梯度下降更新的最小值：  -4.276990756010062e+286
# -----------------------------梯度下降更新的最小值：  8.126282436419118e+287
# -----------------------------梯度下降更新的最小值：  -1.5439936629196326e+289
# -----------------------------梯度下降更新的最小值：  2.933587959547302e+290
# -----------------------------梯度下降更新的最小值：  -5.573817123139874e+291
# -----------------------------梯度下降更新的最小值：  1.059025253396576e+293
# -----------------------------梯度下降更新的最小值：  -2.0121479814534944e+294
# -----------------------------梯度下降更新的最小值：  3.8230811647616396e+295
# -----------------------------梯度下降更新的最小值：  -7.263854213047114e+296
# -----------------------------梯度下降更新的最小值：  1.3801323004789515e+298
# -----------------------------梯度下降更新的最小值：  -2.622251370910008e+299
# -----------------------------梯度下降更新的最小值：  4.9822776047290153e+300
# -----------------------------梯度下降更新的最小值：  -9.466327448985129e+301
# -----------------------------梯度下降更新的最小值：  1.7986022153071743e+303
# -----------------------------梯度下降更新的最小值：  -3.417344209083631e+304
# -----------------------------梯度下降更新的最小值：  6.492953997258899e+305
# -----------------------------梯度下降更新的最小值：  -1.233661259479191e+307
# -----------------------------梯度下降更新的最小值：  inf
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：
# D:\Anaconda3.5.2\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: overflow encountered in double_scalars
# D:\Anaconda3.5.2\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in double_scalars
#  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# ...
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan
# -----------------------------梯度下降更新的最小值：  nan

# %%
plt.figure(figsize=(12,9))
x = np.linspace(-8,5,100)
plt.plot(x,f(x))

# 绘制最小值的点result

plt.scatter(result,f(np.array(result)),marker = '*',color= 'red')
