# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
# Out:
# d:\python3.6.8\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# d:\python3.6.8\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# d:\python3.6.8\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
moon = plt.imread('./moonlanding.png')
moon.shape
# Out:
# (474, 630)

# %%
moon
# Out:
# array([[0.04705882, 0.        , 0.23921569, ..., 0.        , 0.00392157,
#         0.53333336],
#        [0.        , 0.        , 0.6784314 , ..., 0.10196079, 0.2901961 ,
#         0.        ],
#        [0.72156864, 0.10980392, 0.6039216 , ..., 0.        , 0.21568628,
#         1.        ],
#        ...,
#        [0.00392157, 0.        , 1.        , ..., 1.        , 1.        ,
#         0.95686275],
#        [0.        , 0.        , 0.15686275, ..., 0.        , 0.        ,
#         0.3529412 ],
#        [1.        , 0.52156866, 0.04705882, ..., 0.        , 0.        ,
#         1.        ]], dtype=float32)

# %%
plt.figure(figsize=(12,9))
plt.imshow(moon,cmap = plt.cm.gray)

# %%
filter_ = np.full(shape = [3,3],fill_value=1/9).astype(np.float32).reshape(3,3,1,1)


conv = tf.nn.conv2d(input = moon.reshape(1,474,630,1),filter=filter_,strides=[1,1,1,1],padding='SAME')

with tf.Session() as sess:
    ret = sess.run(conv)
    print(ret.shape)
    plt.figure(figsize=(12,9))
    plt.imshow(ret.reshape(474,630),cmap = 'gray')
# Out:
# (1, 474, 630, 1)

# %%
filter_ = np.array([[1/16,2/16,1/16],[2/16,4/16,2/16],[1/16,2/16,1/16]]).astype(np.float32).reshape(3,3,1,1)


conv = tf.nn.conv2d(input = moon.reshape(1,474,630,1),filter=filter_,strides=[1,1,1,1],padding='SAME')

with tf.Session() as sess:
    ret = sess.run(conv)
    print(ret.shape)
    plt.figure(figsize=(12,9))
    plt.imshow(ret.reshape(474,630),cmap = 'gray')
# Out:
# (1, 474, 630, 1)
