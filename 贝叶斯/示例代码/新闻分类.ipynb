# %%
import numpy as np

# %%
from sklearn.naive_bayes import MultinomialNB,BernoulliNB

# %%
import sklearn.datasets as datasets

# %%
data = datasets.fetch_20newsgroups(subset='all',remove=('headers', 'footers', 'quotes'))

# %%
data.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
len(data.data)
# Out:
# 18846

# %%
print(data.data[10])
# Out:
# I have a line on a Ducati 900GTS 1978 model with 17k on the clock.  Runs
# very well, paint is the bronze/brown/orange faded out, leaks a bit of oil
# and pops out of 1st with hard accel.  The shop will fix trans and oil
# leak.  They sold the bike to the 1 and only owner.  They want $3495, and
# I am thinking more like $3K.  Any opinions out there?  Please email me.
# Thanks.  It would be a nice stable mate to the Beemer.  Then I'll get
# a jap bike and call myself Axis Motors!
#
# --
# -----------------------------------------------------------------------
# "Tuba" (Irwin)      "I honk therefore I am"     CompuTrac-Richardson,Tx
# irwin@cmptrc.lonestar.org    DoD #0826          (R75/6)

# %%
# 文本类型的数据量化
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

# %%
X = data.data

y = data.target

# %%
cv = CountVectorizer(stop_words='english')

X2 = cv.fit_transform(X)
X2
# Out:
# <18846x134101 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1229435 stored elements in Compressed Sparse Row format>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X2,y,test_size = 0.2)

# %%
mNB = MultinomialNB()

mNB.fit(X_train,y_train)

mNB.score(X_test,y_test)
# Out:
# 0.66657824933687

# %%
bNB = BernoulliNB()

bNB.fit(X_train,y_train)

bNB.score(X_test,y_test)
# Out:
# 0.47400530503978777

# %%
tfidf = TfidfVectorizer(stop_words='english')

X3 = tfidf.fit_transform(X)
X3
# Out:
# <18846x134101 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1229435 stored elements in Compressed Sparse Row format>

# %%
X_train,X_test,y_train,y_test = train_test_split(X3,y,test_size = 0.2)

# %%
mNB = MultinomialNB()

mNB.fit(X_train,y_train)

mNB.score(X_test,y_test)
# Out:
# 0.7445623342175066

# %%
cv.vocabulary_
# Out:
# {'sure': 113931,
#  'bashers': 29416,
#  'pens': 93336,
#  'fans': 52286,
#  'pretty': 96571,
#  'confused': 38965,
#  'lack': 73308,
#  'kind': 71631,
#  'posts': 95813,
#  'recent': 101186,
#  'massacre': 79103,
#  'devils': 44206,
#  'actually': 22942,
#  'bit': 30989,
#  'puzzled': 98019,
#  'relieved': 102029,
#  'going': 57968,
#  'end': 49321,
#  'non': 87611,
#  'pittsburghers': 94627,
#  'relief': 102024,
#  'praise': 96097,
#  'man': 78556,
#  'killing': 71591,
#  'worse': 128055,
#  'thought': 116912,
#  'jagr': 68455,
#  'just': 69968,
#  'showed': 108636,
#  'better': 30409,
#  'regular': 101780,
#  'season': 107238,
#  'stats': 112195,
#  'lot': 75880,
#  'fo': 54152,
#  'fun': 55396,
#  'watch': 126234,
#  'playoffs': 94931,
#  'bowman': 32124,
#  'let': 74388,
#  'couple': 40109,
#  'games': 56290,
#  'beat': 29793,
#  'pulp': 97803,
#  'jersey': 68851,
#  'disappointed': 44922,
#  'islanders': 67564,
#  'lose': 75863,
#  'final': 53378,
#  'game': 56276,
#  'rule': 104898,
#  'brother': 32727,
#  'market': 78911,
#  'high': 61685,
#  'performance': 93450,
#  'video': 124167,
#  'card': 34670,
#  'supports': 113874,
#  'vesa': 123948,
#  'local': 75587,
#  'bus': 33311,
#  '2mb': 7501,
#  'ram': 100355,
#  'does': 45979,
#  'suggestions': 113478,
#  'ideas': 64304,
#  'diamond': 44448,
#  'stealth': 112253,
#  'pro': 96785,
#  'orchid': 90455,
#  'farenheit': 52331,
#  '1280': 3081,
#  'ati': 27391,
#  'graphics': 58458,
#  'ultra': 120600,
#  'vlb': 124568,
#  'post': 95761,
#  'email': 48929,
#  'thank': 116520,
#  'matt': 79251,
#  'finally': 53385,
#  'said': 105863,
#  'dream': 46539,
#  'mediterranean': 80224,
#  'new': 86701,
#  'area': 26437,
#  'greater': 58577,
#  'years': 131644,
#  'like': 74923,
#  'holocaust': 62285,
#  'numbers': 88294,
#  'july': 69891,
#  'usa': 122247,
#  'sweden': 114248,
#  'april': 26194,
#  'cold': 37865,
#  'changed': 35832,
#  'calendar': 34228,
#  'mentioned': 80513,
#  'true': 118955,
#  'say': 106361,
#  'shall': 108150,
#  'azeri': 28303,
#  'women': 127883,
#  'children': 36227,
#  'pay': 92865,
#  'price': 96624,
#  'raped': 100471,
#  'killed': 71580,
#  'tortured': 117982,
#  'armenians': 26612,
#  'hearded': 60941,
#  'called': 34278,
#  'geneva': 56870,
#  'convention': 39546,
#  'facist': 52037,
#  'ohhh': 89583,
#  'forgot': 54470,
#  'fight': 53237,
#  'killings': 71592,
#  'rapings': 100482,
#  'torture': 117981,
#  'kurds': 72722,
#  'turks': 119331,
#  'time': 117263,
#  'ohhhh': 89584,
#  'swedish': 114251,
#  'redcross': 101412,
#  'workers': 127997,
#  'lie': 74824,
#  'regional': 101733,
#  'killer': 71583,
#  'don': 46080,
#  'person': 93632,
#  'shoot': 108531,
#  'policy': 95398,
#  'search': 107222,
#  'turkish': 119321,
#  'planes': 94823,
#  'know': 72097,
#  'talking': 115367,
#  'turkey': 119316,
#  'government': 58204,
#  'announced': 25473,
#  'giving': 57464,
#  'weapons': 126523,
#  'azerbadjan': 28294,
#  'armenia': 26609,
#  'started': 112108,
#  'attack': 27478,
#  'self': 107503,
#  'karabag': 70724,
#  'province': 97387,
#  'plane': 94820,
#  'content': 39379,
#  'right': 103459,
#  'azeris': 28307,
#  'armenian': 26610,
#  'bread': 32398,
#  'butter': 33383,
#  'arms': 26650,
#  'personel': 93649,
#  'russian': 105006,
#  'army': 26655,
#  'think': 116811,
#  'scsi': 107044,
#  'doing': 46011,
#  'dma': 45765,
#  'transfers': 118421,
#  'disks': 45204,
#  'containing': 39340,
#  'data': 42392,
#  'devices': 44201,
#  'attached': 27472,
#  'wants': 126102,
#  'important': 65218,
#  'feature': 52705,
#  'ability': 22301,
#  'detach': 44031,
#  'device': 44199,
#  'frees': 54947,
#  'typically': 119640,
#  'used': 122273,
#  'multi': 84427,
#  'tasking': 115566,
#  'os': 90717,
#  'start': 112104,
#  'seeking': 107396,
#  'free': 54919,
#  'commands': 38187,
#  'ready': 100956,
#  'transfer': 118411,
#  'aquire': 26274,
#  'send': 107603,
#  'ide': 64290,
#  'busy': 33360,
#  'disk': 45191,
#  'seeked': 107392,
#  'transfered': 118413,
#  '10': 2036,
#  '20ms': 5916,
#  'second': 107288,
#  'lock': 75612,
#  'processes': 96857,
#  'wanting': 126098,
#  'irrespective': 67431,
#  'old': 89765,
#  'jasmine': 68575,
#  'drive': 46607,
#  'use': 122267,
#  'understanding': 121072,
#  'upsate': 122055,
#  'driver': 46614,
#  'modern': 82857,
#  'order': 90480,
#  'gain': 56180,
#  'compatability': 38415,
#  'inexpensive': 65833,
#  'program': 96970,
#  'seen': 107403,
#  'formatters': 54508,
#  '20': 5696,
#  'buit': 33082,
#  'idea': 64293,
#  'work': 127984,
#  'ancient': 25236,
#  'tape': 115475,
#  'utility': 122444,
#  'freezes': 54961,
#  'try': 119016,
#  'direct': 44839,
#  'bought': 32069,
#  '150': 3603,
#  'tapes': 115482,
#  'techmar': 115846,
#  'mechanism': 80127,
#  'essentially': 50319,
#  'question': 99454,
#  'beckup': 29846,
#  'school': 106709,
#  'worked': 127994,
#  'lab': 73259,
#  'assistant': 27134,
#  'bunch': 33169,
#  'experimental': 51281,
#  'psychologists': 97607,
#  'bell': 30093,
#  'labs': 73292,
#  'visual': 124433,
#  'perception': 93399,
#  'memory': 80449,
#  'experiments': 51291,
#  'vector': 123638,
#  'type': 119615,
#  'displays': 45326,
#  'millisecond': 81610,
#  'refresh': 101643,
#  'rates': 100555,
#  'common': 38276,
#  'case': 34872,
#  '200th': 5761,
#  'sec': 107272,
#  'quite': 99549,
#  'practical': 96066,
#  'experimenters': 51289,
#  'probably': 96800,
#  'milliseconds': 81611,
#  'steve': 112414,
#  'ae': 23412,
#  'dallas': 42173,
#  '214': 5999,
#  '241': 6323,
#  '6060': 13256,
#  '0055': 230,
#  'tech': 115835,
#  'support': 113866,
#  'line': 75026,
#  'stuff': 113015,
#  'deleted': 43346,
#  'ok': 89663,
#  'solution': 110497,
#  'problem': 96819,
#  'canada': 34406,
#  'yesterday': 131714,
#  'able': 22316,
#  'nj': 87280,
#  'pitt': 94615,
#  '00': 0,
#  'abc': 22233,
#  'la': 73242,
#  'cal': 34189,
#  'cbc': 35121,
#  'buff': 33012,
#  'bos': 31994,
#  'tsn': 119077,
#  'fox': 54667,
#  'mon': 83039,
#  'que': 99423,
#  '30': 8038,
#  'series': 107804,
#  'goes': 57950,
#  'max': 79338,
#  'watching': 126242,
#  'hockey': 62166,
#  '40': 9965,
#  'odd': 89324,
#  'consecutive': 39126,
#  'nights': 87132,
#  'haven': 60676,
#  'counted': 40052,
#  'pure': 97916,
#  'guess': 59111,
#  'tv': 119394,
#  'house': 62665,
#  'set': 107870,
#  'eye': 51561,
#  'did': 44520,
#  'afternoon': 23656,
#  'btw': 32917,
#  'commentaters': 38210,
#  'great': 58575,
#  'impressed': 65259,
#  'audience': 27611,
#  'wasn': 126215,
#  'likely': 74928,
#  'schooled': 106712,
#  'lore': 75834,
#  'excellent': 50978,
#  'job': 69330,
#  'impartial': 65100,
#  'imo': 65069,
#  'yeah': 131637,
#  'believe': 30071,
#  've': 123614,
#  'trying': 119022,
#  'good': 58058,
#  'look': 75771,
#  'bruin': 32766,
#  'sabre': 105724,
#  'telecasts': 115964,
#  'wow': 128110,
#  'paint': 92062,
#  'knew': 72055,
#  'given': 57458,
#  'fuhr': 55340,
#  'play': 94907,
#  'got': 58149,
#  'bet': 30379,
#  'bruins': 32767,
#  'wishing': 127533,
#  'didn': 44531,
#  'christian': 36463,
#  'means': 80075,
#  'believes': 30078,
#  'divinity': 45589,
#  'jesus': 68875,
#  'safe': 105813,
#  'day': 42522,
#  'christmas': 36479,
#  'truelove': 118959,
#  'served': 107828,
#  'leftover': 74153,
#  'casserole': 34903,
#  'days': 42542,
#  'flaming': 53733,
#  'wings': 127403,
#  'pizza': 94663,
#  'hut': 63260,
#  'commercial': 38220,
#  'tlu': 117540,
#  'gic': 57300,
#  'bait': 29001,
#  'blood': 31386,
#  'lamb': 73412,
#  'hard': 60386,
#  'task': 115562,
#  'cultures': 41203,
#  'animals': 25387,
#  'sacrifices': 105758,
#  'related': 101948,
#  'current': 41280,
#  'modernism': 82858,
#  'state': 112139,
#  'hmm': 62072,
#  'computers': 38644,
#  'cheers': 36064,
#  'kent': 71143,
#  'history': 61890,
#  'untrustworthy': 121846,
#  'behavoir': 29985,
#  'sic': 108807,
#  '930418': 18494,
#  'thou': 116910,
#  'wilt': 127301,
#  'law': 73770,
#  'honestly': 62406,
#  'word': 127958,
#  'sin': 109159,
#  'restriction': 102819,
#  'kid': 71538,
#  'words': 127972,
#  'encompass': 49272,
#  'majestic': 78369,
#  'vision': 124410,
#  'thousands': 116923,
#  'individuals': 65725,
#  'quoting': 99584,
#  'taken': 115325,
#  'context': 39394,
#  'interpreted': 66815,
#  'differently': 44608,
#  'applied': 26069,
#  'confines': 38907,
#  'original': 90594,
#  'expression': 51395,
#  'regarding': 101697,
#  'hymenaeus': 63433,
#  'beta': 30381,
#  'frater': 54877,
#  'superior': 113768,
#  'belong': 30120,
#  'included': 65466,
#  'merlinus': 80600,
#  'service': 107841,
#  'extremes': 51517,
#  'members': 80410,
#  'known': 72114,
#  'fervor': 52953,
#  'little': 75249,
#  'knowledge': 72108,
#  'reuss': 103000,
#  'background': 28835,
#  'surely': 113934,
#  'unusual': 121862,
#  'force': 54365,
#  'people': 93364,
#  'change': 35830,
#  'orders': 90488,
#  'carefully': 34705,
#  'dirty': 44880,
#  'laundry': 73736,
#  'remember': 102128,
#  'surface': 113941,
#  'skim': 109489,
#  'perspectives': 93665,
#  'encompassed': 49273,
#  'extend': 51422,
#  'individual': 65718,
#  'hope': 62470,
#  'room': 104325,
#  'difference': 44594,
#  'opinion': 90215,
#  'testing': 116331,
#  'limits': 74980,
#  'examine': 50930,
#  'issue': 67673,
#  'closely': 37419,
#  '1895': 4321,
#  'karl': 70760,
#  'kellner': 71093,
#  '1850': 4264,
#  '1905': 4369,
#  'wealthy': 126514,
#  'austrian': 27750,
#  'industrialist': 65767,
#  'paper': 92282,
#  'chemist': 36099,
#  'grade': 58338,
#  'mason': 79083,
#  'founded': 54635,
#  'ordo': 90501,
#  'templi': 116077,
#  'orientis': 90583,
#  'traveled': 118580,
#  'widely': 127155,
#  'east': 47781,
#  'met': 80678,
#  'adepts': 23115,
#  'instructed': 66488,
#  'specific': 111000,
#  'magical': 78168,
#  'practices': 96072,
#  'efforts': 48288,
#  'develop': 44173,
#  'later': 73681,
#  'assisted': 27137,
#  'franz': 54870,
#  'hartmann': 60542,
#  'heinrich': 61111,
#  'klein': 71944,
#  'theodore': 116637,
#  'prior': 96723,
#  'joining': 69407,
#  'proclaimed': 96868,
#  '1902': 4364,
#  'masonic': 79085,
#  'publication': 97711,
#  'oriflamme': 90586,
#  'death': 42759,
#  'succeeded': 113358,
#  'outer': 90987,
#  'head': 60874,
#  'jubilee': 69797,
#  'edition': 48109,
#  'published': 97721,
#  '1912': 4387,
#  'taught': 115609,
#  'secret': 107306,
#  'sexual': 107976,
#  'magic': 78166,
#  'interesting': 66696,
#  'character': 35888,
#  'born': 31968,
#  'june': 69915,
#  '28': 6819,
#  '1855': 4268,
#  'augsburg': 27666,
#  'entered': 49593,
#  'masonry': 79087,
#  '1876': 4294,
#  'singer': 109194,
#  'journalist': 69507,
#  'possibly': 95760,
#  'spy': 111489,
#  'prussian': 97445,
#  'political': 95416,
#  'police': 95391,
#  'infiltrating': 65907,
#  'socialist': 110303,
#  'league': 74010,
#  'marx': 79044,
#  'daughter': 42450,
#  'husband': 63233,
#  'associated': 27146,
#  'william': 127268,
#  'wynn': 128622,
#  'westcott': 126758,
#  'leader': 73993,
#  'golden': 57984,
#  'dawn': 42517,
#  'introduced': 66962,
#  'john': 69380,
#  'yarker': 131491,
#  'chartered': 35959,
#  'rites': 103599,
#  'memphis': 80452,
#  'mizraim': 82121,
#  'germany': 57043,
#  'attempts': 27503,
#  'concretize': 38769,
#  'various': 123379,
#  'settled': 107903,
#  'development': 44182,
#  'experienced': 51275,
#  'reasonably': 101057,
#  'steady': 112243,
#  'growth': 58859,
#  'leadership': 73995,
#  'example': 50940,
#  'papus': 92303,
#  'france': 54831,
#  'rudolph': 104861,
#  'steiner': 112306,
#  'berlin': 30301,
#  'spencer': 111114,
#  'lewis': 74474,
#  'historic': 61883,
#  'meeting': 80253,
#  'crowley': 40775,
#  'occurred': 89224,
#  'wrote': 128297,
#  'came': 34350,
#  'accused': 22712,
#  'revealing': 103018,
#  'secrets': 107319,
#  'looked': 75774,
#  'afresh': 23632,
#  'initiated': 66145,
#  'interpretation': 66809,
#  'magick': 78174,
#  'unfolded': 121227,
#  'appointed': 26081,
#  'supreme': 113909,
#  'holy': 62305,
#  'king': 71660,
#  'english': 49458,
#  'speaking': 110960,
#  'world': 128029,
#  'authorization': 27790,
#  'invoked': 67083,
#  'publishing': 97725,
#  'material': 79181,
#  'equinox': 49949,
#  'resigned': 102632,
#  '1922': 4406,
#  'suffering': 113437,
#  'stroke': 112919,
#  'named': 85810,
#  'successor': 113376,
#  '1925': 4409,
#  '_the': 21424,
#  'book': 31854,
#  'law_': 73771,
#  'translated': 118468,
#  'german': 57037,
#  'break': 32408,
#  'continuity': 39419,
#  'manyk': 78764,
#  'split': 111265,
#  'actively': 22915,
#  'promulgating': 97105,
#  'earlier': 47731,
#  'revise': 103071,
#  'dthe': 46833,
#  'rituals': 103610,
#  'request': 102503,
#  'deeply': 43070,
#  'infusing': 66023,
#  'doctrines': 45935,
#  'aeon': 23440,
#  'revelation': 103023,
#  '_an': 20262,
#  'introduction': 66965,
#  'ad': 22973,
#  'veritatem': 123868,
#  'ix': 67929,
#  '_equinox': 20552,
#  'iii': 64643,
#  '10_': 2487,
#  'edited': 48104,
#  'rex': 103140,
#  'summus': 113587,
#  'sanctissimus': 106069,
#  'caliph': 34266,
#  'united': 121403,
#  'states': 112149,
#  'america': 24900,
#  'samuel': 106042,
#  'weiser': 126653,
#  '1990': 4514,
#  'possible': 95756,
#  'reasons': 101065,
#  'real': 100968,
#  'point': 95328,
#  'wish': 127529,
#  'publish': 97718,
#  'things': 116808,
#  'organization': 90539,
#  'represent': 102421,
#  'dogmatic': 45996,
#  'threat': 116943,
#  'principle': 96693,
#  'thelema': 116614,
#  'exercising': 51111,
#  'putting': 98008,
#  'forth': 54568,
#  'complex': 38509,
#  'pictures': 94350,
#  'easy': 47795,
#  'answers': 25578,
#  'picture': 94348,
#  'leaves': 74069,
#  'interpretations': 66811,
#  'derived': 43795,
#  'dribble': 46577,
#  'faltering': 52232,
#  'purchased': 97906,
#  'clever': 37271,
#  'hucksters': 63047,
#  'ounce': 90945,
#  'courage': 40120,
#  'writing': 128270,
#  'aid': 23960,
#  'way': 126328,
#  'present': 96465,
#  'feeble': 52749,
#  'laughable': 73718,
#  'best': 30370,
#  'thrown': 117007,
#  'perspective': 93664,
#  'interjection': 66730,
#  'using': 122316,
#  'illustration': 64849,
#  'shows': 108652,
#  'express': 51391,
#  'larger': 73591,
#  'significance': 108958,
#  'difficult': 44620,
#  'apprehend': 26126,
#  'oto': 90887,
#  'qualified': 99325,
#  'assess': 27108,
#  'critical': 40636,
#  'pomposity': 95523,
#  'member': 80405,
#  'stand': 112002,
#  'allowed': 24606,
#  'continue': 39412,
#  'health': 60926,
#  'mean': 80064,
#  'gone': 58039,
#  'soft': 110372,
#  'abandoned': 22210,
#  'moral': 83260,
#  'principles': 96695,
#  'strong': 112933,
#  'universal': 121420,
#  'kinship': 71687,
#  'arise': 26536,
#  'shackled': 108094,
#  'requirement': 102515,
#  'resolve': 102678,
#  'possibilities': 95752,
#  'calibre': 34250,
#  'intelligent': 66590,
#  'versed': 123906,
#  'arcane': 26362,
#  'usual': 122374,
#  'information': 65983,
#  'artists': 26822,
#  'geniuses': 56884,
#  'having': 60686,
#  'longstanding': 75755,
#  'sf': 107989,
#  'bay': 29556,
#  'heavily': 61007,
#  'involved': 67094,
#  'vouch': 124875,
#  'integrity': 66569,
#  'stands': 112029,
#  'questioned': 99460,
#  'moments': 83030,
#  'followed': 54245,
#  'intuition': 66985,
#  'stop': 112640,
#  'requesting': 102506,
#  'initiation': 66148,
#  'different': 44599,
#  'body': 31676,
#  'happily': 60352,
#  'participating': 92550,
#  'social': 110299,
#  'groups': 58837,
#  'feasts': 52697,
#  'initiations': 66149,
#  'come': 38118,
#  'gnostic': 57846,
#  'mass': 79096,
#  'tastes': 115576,
#  'doesn': 45981,
#  'make': 78389,
#  'authority': 27789,
#  'politics': 95420,
#  'explanations': 51318,
#  'hypothesize': 63515,
#  'relay': 101977,
#  'understand': 121068,
#  'based': 29389,
#  'limited': 74974,
#  'contact': 39325,
#  'urge': 122169,
#  'far': 52312,
#  'ways': 126337,
#  'interpret': 66808,
#  'feel': 52763,
#  'strongly': 112939,
#  'sanctity': 106071,
#  'personal': 93639,
#  'freedom': 54925,
#  'preservation': 96478,
#  'welcome': 126673,
#  'comment': 38207,
#  'response': 102759,
#  'thread': 116938,
#  'invoke': 67082,
#  'stars': 112101,
#  'love': 75929,
#  'kirlian': 71715,
#  'imaging': 64924,
#  'faq': 52301,
#  'sci': 106765,
#  'skeptics': 109451,
#  'sp': 110798,
#  'nice': 87023,
#  'write': 128259,
#  'certainly': 35548,
#  'supportive': 113873,
#  'helping': 61200,
#  'build': 33059,
#  'connect': 39045,
#  '120kvolt': 2940,
#  'supply': 113863,
#  'aura': 27705,
#  'notion': 87905,
#  'heliocentric': 61142,
#  'galacticentric': 56196,
#  'following': 54251,
#  'report': 102396,
#  '_turkey': 21473,
#  'eyes': 51576,
#  'role_': 104243,
#  'ankara': 25417,
#  'ap': 25822,
#  '27': 6710,
#  '1993': 4523,
#  'paragraph': 92339,
#  'turanist': 119270,
#  'premier': 96378,
#  'suleyman': 113518,
#  'demirel': 43475,
#  'criticized': 40646,
#  'ozal': 91531,
#  'brash': 32357,
#  'calls': 34293,
#  'influence': 65949,
#  'spoken': 111292,
#  'swath': 114223,
#  'turkic': 119319,
#  'peoples': 93366,
#  'stretching': 112863,
#  'adriatic': 23291,
#  'sea': 107184,
#  'wall': 126020,
#  'china': 36257,
#  'fooling': 54301,
#  'ends': 49382,
#  'envisioned': 49729,
#  'pan': 92177,
#  'empire': 49133,
#  'balkans': 29061,
#  'caucasus': 35041,
#  'fascist': 52385,
#  'boasts': 31622,
#  'pre': 96139,
#  'empted': 49164,
#  'suggest': 113472,
#  'grey': 58671,
#  'wolf': 127852,
#  'teeth': 115927,
#  'attempt': 27500,
#  'stretch': 112857,
#  'cried': 40570,
#  'thanks': 116526,
#  'replied': 102380,
#  'appeal': 25991,
#  'info': 65957,
#  '600rpm': 13225,
#  'modify': 82884,
#  'bbc': 29602,
#  'computer': 38635,
#  'speed': 111070,
#  '600': 13199,
#  '300': 8039,
#  'rpm': 104583,
#  'tried': 118755,
#  'components': 38539,
#  'rec': 101140,
#  'section': 107326,
#  'allow': 24602,
#  'lower': 75953,
#  'rate': 100551,
#  '250kbit': 6489,
#  '500kbit': 11590,
#  'designed': 43901,
#  'recording': 101342,
#  'low': 75945,
#  'rev': 103003,
#  'hopefully': 62473,
#  'sort': 110659,
#  'bad': 28906,
#  'quid': 99502,
#  'normally': 87778,
#  '32': 8256,
#  'upwards': 122082,
#  'jvc': 70015,
#  'mdp': 79990,
#  'ago': 23783,
#  'victim': 124139,
#  'squirted': 111615,
#  'fair': 52132,
#  'model': 82821,
#  '15': 3602,
#  'teletype': 116013,
#  'acting': 22902,
#  'turned': 119339,
#  'eruption': 50139,
#  'motor': 83486,
#  'starting': 112112,
#  'contacts': 39330,
#  'broke': 32675,
#  'mighty': 81468,
#  'spectacular': 111029,
#  'eyebrows': 51566,
#  'singed': 109193,
#  'plastic': 94871,
#  'ones': 89997,
#  'safety': 105830,
#  'glass': 57611,
#  'cover': 40176,
#  'platen': 94879,
#  'flew': 53842,
#  'heart': 60953,
#  'attacks': 27484,
#  'beware': 30436,
#  'explosive': 51352,
#  'properties': 97169,
#  'wd40': 126445,
#  'vapor': 123339,
#  'court': 40136,
#  'disagree': 44899,
#  'stated': 112141,
#  'term': 116200,
#  'art': 26770,
#  'refering': 101575,
#  'explicitly': 51327,
#  'amendment': 24893,
#  'quote': 99577,
#  'employed': 49143,
#  'select': 107484,
#  'parts': 92591,
#  'constitution': 39261,
#  'preamble': 96149,
#  'declares': 42913,
#  'ordained': 90475,
#  'established': 50331,
#  'protects': 97310,
#  'bear': 29770,
#  'uerdugo': 120308,
#  'uriquidez': 122189,
#  'furthermore': 55492,
#  'miller': 81589,
#  'decision': 42891,
#  'permitted': 93547,
#  'prosecution': 97259,
#  'possession': 95745,
#  'sawed': 106349,
#  'shotgun': 108596,
#  'defense': 43132,
#  'presented': 96470,
#  'testimony': 116330,
#  'accepted': 22570,
#  'argument': 26498,
#  'military': 81562,
#  'value': 123260,
#  'held': 61127,
#  'protected': 97300,
#  'possess': 95741,
#  'unfortunately': 121251,
#  'successfully': 113372,
#  'gotten': 58162,
#  'appears': 26004,
#  'vis': 124382,
#  'conclusion': 38748,
#  'inescapable': 65812,
#  'concept': 38707,
#  'wording': 127964,
#  'major': 78374,
#  'commentator': 38212,
#  'half': 60076,
#  'century': 35507,
#  'ratifi': 100558,
#  'cation': 35025,
#  'indicates': 65674,
#  'private': 96743,
#  'citizen': 36878,
#  'carry': 34809,
#  'firearms': 53474,
#  'peaceful': 93091,
#  'manner': 78685,
#  'subcommittee': 113112,
#  'committee': 38261,
#  'judiciary': 69835,
#  'senate': 107597,
#  '97th': 18905,
#  'congress': 38996,
#  'session': 107866,
#  'february': 52713,
#  '1982': 4504,
#  'rightfully': 103466,
#  'ask': 26975,
#  'militias': 81569,
#  'militia': 81566,
#  'historical': 61884,
#  'basically': 29426,
#  'adult': 23311,
#  'males': 78463,
#  'country': 40097,
#  'code': 37731,
#  'defines': 43174,
#  'armed': 26603,
#  'men': 80457,
#  'age': 23704,
#  '17': 4046,
#  'comprised': 38584,
#  'physically': 94252,
#  'capable': 34536,
#  'concert': 38722,
#  'expected': 51230,
#  'appear': 25995,
#  'bearing': 29780,
#  ...}

# %%
# %%time
cv = CountVectorizer(stop_words='english',ngram_range=(1,2))

X4 = cv.fit_transform(X)
# Out:
# Wall time: 13.2 s

# %%
cv.vocabulary_
# Out:
# {'sure': 1200087,
#  'bashers': 207267,
#  'pens': 925196,
#  'fans': 500083,
#  'pretty': 972657,
#  'confused': 332713,
#  'lack': 717244,
#  'kind': 704180,
#  'posts': 962708,
#  'recent': 1030375,
#  'massacre': 790177,
#  'devils': 402334,
#  'actually': 130387,
#  'bit': 226003,
#  'puzzled': 1001755,
#  'relieved': 1042123,
#  'going': 564736,
#  'end': 461346,
#  'non': 866847,
#  'pittsburghers': 941878,
#  'relief': 1042014,
#  'praise': 966666,
#  'man': 782484,
#  'killing': 703733,
#  'worse': 1357575,
#  'thought': 1237082,
#  'jagr': 678960,
#  'just': 691339,
#  'showed': 1128369,
#  'better': 219525,
#  'regular': 1038377,
#  'season': 1103889,
#  'stats': 1175684,
#  'lot': 762075,
#  'fo': 523780,
#  'fun': 540135,
#  'watch': 1330106,
#  'playoffs': 948477,
#  'bowman': 239232,
#  'let': 732389,
#  'couple': 353794,
#  'games': 546614,
#  'beat': 211289,
#  'pulp': 999045,
#  'jersey': 681466,
#  'disappointed': 413189,
#  'islanders': 672564,
#  'lose': 761162,
#  'final': 515195,
#  'game': 545698,
#  'rule': 1077441,
#  'sure bashers': 1200196,
#  'bashers pens': 207272,
#  'pens fans': 925227,
#  'fans pretty': 500218,
#  'pretty confused': 972722,
#  'confused lack': 332760,
#  'lack kind': 717348,
#  'kind posts': 704622,
#  'posts recent': 962868,
#  'recent pens': 1030523,
#  'pens massacre': 925252,
#  'massacre devils': 790202,
#  'devils actually': 402346,
#  'actually bit': 130488,
#  'bit puzzled': 226625,
#  'puzzled bit': 1001758,
#  'bit relieved': 226654,
#  'relieved going': 1042131,
#  'going end': 565122,
#  'end non': 461828,
#  'non pittsburghers': 867220,
#  'pittsburghers relief': 941879,
#  'relief bit': 1042025,
#  'bit praise': 226598,
#  'praise pens': 966696,
#  'pens man': 925250,
#  'man killing': 782856,
#  'killing devils': 703785,
#  'devils worse': 402427,
#  'worse thought': 1357794,
#  'thought jagr': 1237415,
#  'jagr just': 678976,
#  'just showed': 693372,
#  'showed better': 1128394,
#  'better regular': 220337,
#  'regular season': 1038513,
#  'season stats': 1104253,
#  'stats lot': 1175762,
#  'lot fo': 762349,
#  'fo fun': 523790,
#  'fun watch': 540289,
#  'watch playoffs': 1330266,
#  'playoffs bowman': 948493,
#  'bowman let': 239245,
#  'let jagr': 732758,
#  'jagr lot': 678979,
#  'lot fun': 762361,
#  'fun couple': 540167,
#  'couple games': 353891,
#  'games pens': 547006,
#  'pens going': 925232,
#  'going beat': 564865,
#  'beat pulp': 211408,
#  'pulp jersey': 999049,
#  'jersey disappointed': 681489,
#  'disappointed islanders': 413201,
#  'islanders lose': 672610,
#  'lose final': 761218,
#  'final regular': 515352,
#  'season game': 1104032,
#  'game pens': 546271,
#  'pens rule': 925268,
#  'brother': 245438,
#  'market': 787779,
#  'high': 608754,
#  'performance': 928981,
#  'video': 1311719,
#  'card': 266778,
#  'supports': 1198919,
#  'vesa': 1310215,
#  'local': 754413,
#  'bus': 252058,
#  '2mb': 50270,
#  'ram': 1016657,
#  'does': 424812,
#  'suggestions': 1193560,
#  'ideas': 631675,
#  'diamond': 403742,
#  'stealth': 1176738,
#  'pro': 978053,
#  'orchid': 896349,
#  'farenheit': 501674,
#  '1280': 16980,
#  'ati': 185672,
#  'graphics': 574146,
#  'ultra': 1276597,
#  'vlb': 1316372,
#  'post': 960645,
#  'email': 457572,
#  'thank': 1228651,
#  'matt': 792030,
#  'brother market': 245510,
#  'market high': 787912,
#  'high performance': 609090,
#  'performance video': 929317,
#  'video card': 1311764,
#  'card supports': 267406,
#  'supports vesa': 1199137,
#  'vesa local': 1310246,
#  'local bus': 754486,
#  'bus 2mb': 252069,
#  '2mb ram': 50299,
#  'ram does': 1016790,
#  'does suggestions': 426198,
#  'suggestions ideas': 1193633,
#  'ideas diamond': 631748,
#  'diamond stealth': 403788,
#  'stealth pro': 1176763,
#  'pro local': 978170,
#  'bus orchid': 252280,
#  'orchid farenheit': 896361,
#  'farenheit 1280': 501675,
#  '1280 ati': 16987,
#  'ati graphics': 185696,
#  'graphics ultra': 574596,
#  'ultra pro': 1276626,
#  'pro high': 978145,
#  'performance vlb': 929319,
#  'vlb card': 1316391,
#  'card post': 267264,
#  'post email': 960861,
#  'email thank': 458010,
#  'thank matt': 1228758,
#  'finally': 515443,
#  'said': 1085348,
#  'dream': 435227,
#  'mediterranean': 801695,
#  'new': 858782,
#  'area': 170697,
#  'greater': 576131,
#  'years': 1377173,
#  'like': 739840,
#  'holocaust': 615497,
#  'numbers': 874930,
#  'july': 690264,
#  'usa': 1288521,
#  'sweden': 1204536,
#  'april': 168584,
#  'cold': 310195,
#  'changed': 282699,
#  'calendar': 259113,
#  'mentioned': 805404,
#  'true': 1263100,
#  'say': 1092072,
#  'shall': 1122095,
#  'azeri': 198208,
#  'women': 1349653,
#  'children': 288759,
#  'pay': 921347,
#  'price': 974067,
#  'raped': 1018523,
#  'killed': 703263,
#  'tortured': 1251951,
#  'armenians': 174749,
#  'hearded': 601195,
#  'called': 259712,
#  'geneva': 553090,
#  'convention': 344520,
#  'facist': 494479,
#  'ohhh': 886275,
#  'forgot': 529724,
#  'fight': 511386,
#  'killings': 703923,
#  'rapings': 1018681,
#  'torture': 1251888,
#  'kurds': 714462,
#  'turks': 1268736,
#  'time': 1241511,
#  'ohhhh': 886278,
#  'swedish': 1204636,
#  'redcross': 1033565,
#  'workers': 1354700,
#  'lie': 737496,
#  'regional': 1037824,
#  'killer': 703662,
#  'don': 428963,
#  'person': 931291,
#  'shoot': 1126229,
#  'policy': 954141,
#  'search': 1103489,
#  'turkish': 1268477,
#  'planes': 944995,
#  'know': 708029,
#  'talking': 1213061,
#  'turkey': 1268231,
#  'government': 570818,
#  'announced': 158291,
#  'giving': 559086,
#  'weapons': 1334930,
#  'azerbadjan': 197782,
#  'armenia': 174224,
#  'started': 1171334,
#  'attack': 186647,
#  'self': 1110064,
#  'karabag': 696793,
#  'province': 994920,
#  'plane': 944871,
#  'content': 340183,
#  'right': 1064946,
#  'azeris': 198286,
#  'armenian': 174417,
#  'bread': 242001,
#  'butter': 253350,
#  'arms': 175298,
#  'personel': 932659,
#  'russian': 1080903,
#  'army': 175520,
#  'finally said': 515690,
#  'said dream': 1085755,
#  'dream mediterranean': 435268,
#  'mediterranean new': 801703,
#  'new area': 858912,
#  'area greater': 170932,
#  'greater years': 576317,
#  'years like': 1377723,
#  'like holocaust': 741279,
#  'holocaust numbers': 615552,
#  'numbers july': 875143,
#  'july usa': 690353,
#  'usa sweden': 1288769,
#  'sweden april': 1204550,
#  'april cold': 168671,
#  'cold changed': 310218,
#  'changed calendar': 282736,
#  'calendar mentioned': 259131,
#  'mentioned true': 805752,
#  'true let': 1263552,
#  'let say': 732978,
#  'say true': 1093622,
#  'true shall': 1263841,
#  'shall azeri': 1122120,
#  'azeri women': 198277,
#  'women children': 1349717,
#  'children going': 289011,
#  'going pay': 565521,
#  'pay price': 921591,
#  'price raped': 974534,
#  'raped killed': 1018539,
#  'killed tortured': 703626,
#  'tortured armenians': 1251952,
#  'armenians hearded': 174918,
#  'hearded called': 601196,
#  'called geneva': 260085,
#  'geneva convention': 553096,
#  'convention facist': 344539,
#  'facist ohhh': 494482,
#  'ohhh forgot': 886276,
#  'forgot armenians': 529730,
#  'armenians fight': 174887,
#  'fight forgot': 511439,
#  'forgot killings': 529764,
#  'killings rapings': 703937,
#  'rapings torture': 1018682,
#  'torture kurds': 1251924,
#  'kurds turks': 714515,
#  'turks time': 1268881,
#  'time ohhhh': 1243005,
#  'ohhhh swedish': 886279,
#  'swedish redcross': 1204663,
#  'redcross workers': 1033566,
#  'workers lie': 1354761,
#  'lie say': 737603,
#  'say regional': 1093316,
#  'regional killer': 1037840,
#  'killer don': 703668,
#  'don like': 429678,
#  'like person': 742026,
#  'person shoot': 931954,
#  'shoot policy': 1126298,
#  'policy confused': 954211,
#  'confused search': 332798,
#  'search turkish': 1103696,
#  'turkish planes': 1268617,
#  'planes don': 945011,
#  'don know': 429648,
#  'know talking': 710260,
#  'talking turkey': 1213492,
#  'turkey government': 1268312,
#  'government announced': 570877,
#  'announced giving': 158336,
#  'giving weapons': 559323,
#  'weapons azerbadjan': 1334968,
#  'azerbadjan armenia': 197783,
#  'armenia started': 174383,
#  'started attack': 1171375,
#  'attack azerbadjan': 186685,
#  'azerbadjan self': 197787,
#  'self karabag': 1110213,
#  'karabag province': 696807,
#  'province search': 994940,
#  'search plane': 1103645,
#  'plane weapons': 944987,
#  'weapons content': 1335006,
#  'content announced': 340189,
#  'announced weapons': 158419,
#  'weapons confused': 1335004,
#  'confused right': 332794,
#  'right weapons': 1066350,
#  'weapons azeris': 1334970,
#  'azeris armenians': 198292,
#  'armenians started': 175079,
#  'started fight': 1171499,
#  'fight azerbadjan': 511396,
#  'azerbadjan shoot': 197788,
#  'shoot armenian': 1126236,
#  'armenian bread': 174461,
#  'bread butter': 242006,
#  'butter arms': 253351,
#  'arms personel': 175429,
#  'personel russian': 932667,
#  'russian army': 1080925,
#  'think': 1233617,
#  'scsi': 1102131,
#  'doing': 427468,
#  'dma': 422499,
#  'transfers': 1257061,
#  'disks': 417368,
#  'containing': 339541,
#  'data': 374502,
#  'devices': 402049,
#  'attached': 186512,
#  'wants': 1327149,
#  'important': 640828,
#  'feature': 505964,
#  'ability': 120290,
#  'detach': 398888,
#  'device': 401769,
#  'frees': 536106,
#  'typically': 1272638,
#  'used': 1291622,
#  'multi': 840344,
#  'tasking': 1215645,
#  'os': 900409,
#  'start': 1170642,
#  'seeking': 1108100,
#  'free': 535063,
#  'commands': 317460,
#  'ready': 1024308,
#  'transfer': 1256835,
#  'aquire': 169011,
#  'send': 1111787,
#  'ide': 630666,
#  'busy': 253114,
#  'disk': 416768,
#  'seeked': 1108089,
#  'transfered': 1256991,
#  '10': 8677,
#  '20ms': 39167,
#  'second': 1104911,
#  'lock': 755434,
#  'processes': 982774,
#  'wanting': 1327093,
#  'irrespective': 671489,
#  'think scsi': 1235516,
#  'scsi card': 1102178,
#  'card doing': 267001,
#  'doing dma': 427647,
#  'dma transfers': 422563,
#  'transfers disks': 1257077,
#  'disks scsi': 417533,
#  'card dma': 266998,
#  'transfers containing': 1257070,
#  'containing data': 339570,
#  'data scsi': 375256,
#  'scsi devices': 1102218,
#  'devices attached': 402070,
#  'attached wants': 186607,
#  'wants important': 1327298,
#  'important feature': 641005,
#  'feature scsi': 506066,
#  'scsi ability': 1102147,
#  'ability detach': 120347,
#  'detach device': 398889,
#  'device frees': 401870,
#  'frees scsi': 536110,
#  'scsi bus': 1102171,
#  'bus devices': 252158,
#  'devices typically': 402255,
#  'typically used': 1272735,
#  'used multi': 1292693,
#  'multi tasking': 840438,
#  'tasking os': 1215659,
#  'os start': 900681,
#  'start transfers': 1171256,
#  'transfers devices': 1257074,
#  'devices device': 402104,
#  'device seeking': 401989,
#  'seeking data': 1108112,
#  'data bus': 374628,
#  'bus free': 252188,
#  'free commands': 535178,
#  'commands data': 317486,
#  'data transfers': 375372,
#  'devices ready': 402213,
#  'ready transfer': 1024492,
#  'transfer data': 1256872,
#  'data aquire': 374574,
#  'aquire bus': 169012,
#  'bus send': 252309,
#  'send data': 1111892,
#  'data ide': 374912,
#  'ide bus': 630685,
#  'bus start': 252333,
#  'start transfer': 1171255,
#  'transfer bus': 1256856,
#  'bus busy': 252124,
#  'busy disk': 253133,
#  'disk seeked': 417169,
#  'seeked data': 1108090,
#  'data transfered': 375370,
#  'transfered typically': 1256996,
#  'typically 10': 1272639,
#  '10 20ms': 8779,
#  '20ms second': 39169,
#  'second lock': 1105243,
#  'lock processes': 755546,
#  'processes wanting': 982849,
#  'wanting bus': 1327099,
#  'bus irrespective': 252223,
#  'irrespective transfer': 671493,
#  'transfer time': 1256965,
#  'old': 887855,
#  'jasmine': 680019,
#  'drive': 435833,
#  'use': 1289052,
#  'understanding': 1279527,
#  'upsate': 1287636,
#  'driver': 436925,
#  'modern': 825966,
#  'order': 896461,
#  'gain': 544998,
#  'compatability': 322647,
#  'inexpensive': 650001,
#  'program': 985399,
#  'seen': 1108221,
#  'formatters': 531255,
#  '20': 37102,
#  'buit': 249869,
#  'idea': 630809,
#  'work': 1352905,
#  'ancient': 156259,
#  'tape': 1214411,
#  'utility': 1298315,
#  'freezes': 536226,
#  'try': 1265131,
#  'direct': 410966,
#  'bought': 238428,
#  '150': 21755,
#  'tapes': 1214687,
#  'techmar': 1219119,
#  'mechanism': 800348,
#  'essentially': 473039,
#  'question': 1008020,
#  'beckup': 211890,
#  'old jasmine': 888213,
#  'jasmine drive': 680021,
#  'drive use': 436716,
#  'use new': 1290565,
#  'new understanding': 860255,
#  'understanding upsate': 1279767,
#  'upsate driver': 1287637,
#  'driver modern': 437143,
#  'modern order': 826082,
#  'order gain': 896791,
#  'gain compatability': 545035,
#  'compatability does': 322649,
#  'does know': 425572,
#  'know inexpensive': 709183,
#  'inexpensive program': 650036,
#  'program seen': 986249,
#  'seen formatters': 1108494,
#  'formatters 20': 531256,
#  '20 buit': 37335,
#  'buit idea': 249870,
#  'idea work': 631532,
#  'work ancient': 1352999,
#  'ancient device': 156286,
#  'device tape': 402013,
#  'tape drive': 1214484,
#  'drive utility': 436722,
#  'utility freezes': 1298368,
#  'freezes try': 536233,
#  'try use': 1265965,
#  'use drive': 1289774,
#  'drive jasmine': 436282,
#  'jasmine direct': 680020,
#  'direct tape': 411157,
#  'tape bought': 1214433,
#  'bought used': 238715,
#  'used 150': 1291633,
#  '150 tapes': 21880,
#  'tapes techmar': 1214772,
#  'techmar mechanism': 1219120,
#  'mechanism essentially': 800396,
#  'essentially question': 473154,
#  'question know': 1008554,
#  'inexpensive beckup': 650011,
#  'beckup utility': 211891,
#  'utility use': 1298443,
#  'school': 1097635,
#  'worked': 1354420,
#  'lab': 716549,
#  'assistant': 182135,
#  'bunch': 250629,
#  'experimental': 487247,
#  'psychologists': 996258,
#  'bell': 216510,
#  'labs': 717141,
#  'visual': 1315579,
#  'perception': 928341,
#  'memory': 803869,
#  'experiments': 487379,
#  'vector': 1306706,
#  'type': 1271484,
#  'displays': 418769,
#  'millisecond': 815263,
#  'refresh': 1036213,
#  'rates': 1019609,
#  'common': 319477,
#  'case': 270764,
#  '200th': 38413,
#  'sec': 1104743,
#  'quite': 1010711,
#  'practical': 966003,
#  'experimenters': 487358,
#  'probably': 978397,
#  'milliseconds': 815268,
#  'steve': 1178228,
#  'high school': 609177,
#  'school worked': 1097985,
#  'worked lab': 1354540,
#  'lab assistant': 716570,
#  'assistant bunch': 182139,
#  'bunch experimental': 250684,
#  'experimental psychologists': 487293,
#  'psychologists bell': 996260,
#  'bell labs': 216574,
#  'labs doing': 717153,
#  'doing visual': 428107,
#  'visual perception': 1315645,
#  'perception memory': 928368,
#  'memory experiments': 804033,
#  'experiments used': 487446,
#  'used vector': 1293370,
#  'vector type': 1306746,
#  'type displays': 1271663,
#  'displays millisecond': 418830,
#  'millisecond refresh': 815266,
#  'refresh rates': 1036238,
#  'rates common': 1019665,
#  'common case': 319516,
#  'case 200th': 270773,
#  '200th sec': 38414,
#  'sec quite': 1104829,
#  'quite practical': 1011078,
#  'practical experimenters': 966037,
#  'experimenters probably': 487366,
#  'probably sure': 979204,
#  'sure milliseconds': 1200690,
#  'milliseconds steve': 815274,
#  'ae': 138681,
#  'dallas': 372363,
#  '214': 39977,
#  '241': 42842,
#  '6060': 81607,
#  '0055': 2066,
#  'tech': 1218992,
#  'support': 1197602,
#  'line': 744972,
#  'ae dallas': 138690,
#  'dallas try': 372414,
#  'try 214': 1265135,
#  '214 241': 39990,
#  '241 6060': 42855,
#  '6060 214': 81608,
#  '241 0055': 42843,
#  '0055 tech': 2067,
#  'tech support': 1219081,
#  'support line': 1198054,
#  'line started': 745744,
#  'stuff': 1187230,
#  'deleted': 389916,
#  'ok': 886907,
#  'solution': 1150253,
#  'problem': 979610,
#  'canada': 262957,
#  'yesterday': 1379426,
#  'able': 120562,
#  'nj': 865125,
#  'pitt': 941682,
#  '00': 0,
#  'abc': 119937,
#  'la': 716242,
#  'cal': 258668,
#  'cbc': 275345,
#  'buff': 247986,
#  'bos': 237364,
#  'tsn': 1266782,
#  'fox': 533160,
#  'mon': 827716,
#  'que': 1007607,
#  '30': 52438,
#  'series': 1115410,
#  'goes': 564245,
#  'max': 793212,
#  'watching': 1330478,
#  'hockey': 613896,
#  '40': 64091,
#  'odd': 882930,
#  'consecutive': 334882,
#  'nights': 864409,
#  'haven': 596521,
#  'counted': 352523,
#  'pure': 1000108,
#  'guess': 581780,
#  'tv': 1270087,
#  'house': 621240,
#  'set': 1118188,
#  'eye': 491763,
#  'did': 404298,
#  'afternoon': 140304,
#  'btw': 246934,
#  'commentaters': 317985,
#  'great': 575367,
#  'impressed': 641850,
#  'audience': 189273,
#  'wasn': 1329541,
#  'likely': 743240,
#  'schooled': 1098000,
#  'lore': 761059,
#  'excellent': 481138,
#  'job': 684986,
#  'impartial': 639446,
#  'imo': 639106,
#  'stuff deleted': 1187368,
#  'deleted ok': 390095,
#  'ok solution': 887251,
#  'solution problem': 1150418,
#  'problem canada': 979811,
#  'canada yesterday': 263257,
#  'yesterday able': 1379434,
#  'able watch': 121167,
#  'watch games': 1330187,
#  'games nj': 546989,
#  'nj pitt': 865252,
#  'pitt 00': 941683,
#  '00 abc': 209,
#  'abc la': 119973,
#  'la cal': 716307,
#  'cal 00': 258669,
#  '00 cbc': 293,
#  'cbc buff': 275350,
#  'buff bos': 247988,
#  'bos 00': 237365,
#  '00 tsn': 814,
#  'tsn fox': 1266784,
#  'fox mon': 533182,
#  'mon que': 827834,
#  'que 30': 1007622,
#  '30 cbc': 52631,
#  'cbc think': 275381,
#  'think series': 1235541,
#  'series goes': 1115619,
#  'goes max': 564496,
#  'max watching': 793403,
#  'watching hockey': 1330539,
#  'hockey playoffs': 614074,
#  'playoffs 40': 948482,
#  '40 odd': 64484,
#  'odd consecutive': 882944,
#  'consecutive nights': 334890,
#  'nights haven': 864428,
#  'haven counted': 596571,
#  'counted pure': 352551,
#  'pure guess': 1000137,
#  'guess tv': 582249,
#  'tv house': 1270208,
#  'house set': 621631,
#  'set watch': 1119151,
#  'watch mon': 1330242,
#  'que eye': 1007657,
#  'eye bos': 491785,
#  'bos buff': 237421,
#  'buff time': 247991,
#  'time did': 1242119,
#  'did afternoon': 404361,
#  'afternoon games': 140318,
#  'games btw': 546704,
#  'btw abc': 246938,
#  'abc commentaters': 119952,
#  'commentaters great': 317986,
#  'great quite': 575878,
#  'quite impressed': 1010968,
#  'impressed know': 641882,
#  'know audience': 708224,
#  'audience wasn': 189326,
#  'wasn likely': 1329729,
#  'likely schooled': 743630,
#  'schooled hockey': 1098002,
#  'hockey lore': 614034,
#  'lore did': 761061,
#  'did excellent': 404756,
#  'excellent job': 481253,
#  'job quite': 685280,
#  'quite impartial': 1010966,
#  'impartial imo': 639449,
#  'yeah': 1375820,
#  'believe': 214686,
#  've': 1305768,
#  'trying': 1266040,
#  'good': 566743,
#  'look': 758167,
#  'bruin': 246215,
#  'sabre': 1084021,
#  'telecasts': 1220811,
#  'wow': 1359186,
#  'paint': 910542,
#  'knew': 707361,
#  'given': 557998,
#  'fuhr': 539620,
#  'play': 946643,
#  'got': 569001,
#  'bet': 219175,
#  'bruins': 246226,
#  'wishing': 1347794,
#  'didn': 405743,
#  'yeah second': 1375954,
#  'second believe': 1104986,
#  'believe price': 215568,
#  'price ve': 974650,
#  've trying': 1306583,
#  'trying good': 1266281,
#  'good look': 567568,
#  'look bruin': 758292,
#  'bruin sabre': 246222,
#  'sabre telecasts': 1084034,
#  'telecasts wow': 1220817,
#  'wow does': 1359206,
#  'does look': 425621,
#  'look good': 758538,
#  'good did': 567152,
#  'did paint': 405187,
#  'paint job': 910591,
#  'job knew': 685181,
#  'knew doing': 707444,
#  'doing given': 427719,
#  'given fuhr': 558281,
#  'fuhr play': 539663,
#  'play got': 946844,
#  'got bet': 569129,
#  'bet bruins': 219199,
#  'bruins wishing': 246326,
#  'wishing didn': 1347798,
#  'christian': 292733,
#  'means': 798642,
#  'believes': 216262,
#  'divinity': 421423,
#  'jesus': 681724,
#  'safe': 1084698,
#  'day': 377366,
#  'christmas': 294030,
#  'truelove': 1264031,
#  'served': 1116323,
#  'leftover': 730270,
#  'casserole': 272477,
#  'days': 378370,
#  'flaming': 520296,
#  'wings': 1345647,
#  'pizza': 942287,
#  'hut': 626130,
#  'commercial': 318436,
#  'tlu': 1246492,
#  'gic': 556968,
#  'bait': 202488,
#  'christian means': 293024,
#  'means believes': 798729,
#  'believes divinity': 216296,
#  'divinity jesus': 421431,
#  'jesus safe': 682235,
#  'safe say': 1084836,
#  'say jesus': 1092893,
#  'jesus christian': 681822,
#  'christian day': 292863,
#  'day christmas': 377541,
#  'christmas truelove': 294052,
#  'truelove served': 1264033,
#  'served leftover': 1116376,
#  'leftover turkey': 730276,
#  'turkey second': 1268406,
#  'second day': 1105076,
#  'served turkey': 1116410,
#  'turkey casserole': 1268261,
#  'casserole leftover': 272478,
#  'turkey days': 1268278,
#  'days deleted': 378508,
#  'deleted flaming': 390004,
#  'flaming turkey': 520325,
#  'turkey wings': 1268453,
#  'wings pizza': 1345729,
#  'pizza hut': 942292,
#  'hut commercial': 626132,
#  'commercial tlu': 318617,
#  'tlu gic': 1246493,
#  'gic bait': 556969,
#  'blood': 230174,
#  'lamb': 718032,
#  'hard': 593364,
#  'task': 1215553,
#  'cultures': 365874,
#  'animals': 157624,
#  'sacrifices': 1084383,
#  'related': 1039758,
#  'current': 366519,
#  'modernism': 826155,
#  'state': 1172548,
#  'hmm': 613305,
#  'computers': 327499,
#  'cheers': 287139,
#  'kent': 698991,
#  'blood lamb': 230273,
#  'lamb hard': 718041,
#  'hard task': 593765,
#  'task cultures': 1215572,
#  'cultures used': 365901,
#  'used animals': 1291742,
#  'animals blood': 157634,
#  'blood sacrifices': 230332,
#  'sacrifices related': 1084394,
#  'related current': 1039814,
#  'current post': 366882,
#  'post modernism': 961066,
#  'modernism state': 826157,
#  'state hmm': 1172901,
#  'hmm used': 613363,
#  'used computers': 1291988,
#  'computers cheers': 327532,
#  'cheers kent': 287161,
#  'history': 611211,
#  'untrustworthy': 1286098,
#  'behavoir': 213723,
#  'sic': 1130271,
#  'say history': 1092793,
#  'history untrustworthy': 611672,
#  'untrustworthy behavoir': 1286099,
#  'behavoir sic': 213725,
#  '930418': 106867,
#  'thou': 1237033,
#  'wilt': 1343018,
#  'law': 723248,
#  'honestly': 617632,
#  'word': 1351608,
#  'sin': 1135475,
#  'restriction': 1057992,
#  'kid': 702514,
#  'words': 1352350,
#  'encompass': 460478,
#  'majestic': 778334,
#  'vision': 1315173,
#  'thousands': 1238043,
#  'individuals': 649098,
#  'quoting': 1011911,
#  'taken': 1211274,
#  'context': 340546,
#  'interpreted': 665762,
#  'differently': 408979,
#  'applied': 166187,
#  'confines': 332044,
#  'original': 899260,
#  'expression': 489756,
#  'regarding': 1037018,
#  'hymenaeus': 626684,
#  'beta': 219323,
#  'frater': 534826,
#  'superior': 1196612,
#  'belong': 216712,
#  'included': 644318,
#  'merlinus': 806794,
#  'service': 1117153,
#  'extremes': 491588,
#  'members': 803216,
#  'known': 711186,
#  'fervor': 509409,
#  'little': 749507,
#  'knowledge': 710782,
#  'reuss': 1060739,
#  'background': 200610,
#  'surely': 1201157,
#  'unusual': 1286163,
#  'force': 527784,
#  'people': 925416,
#  'change': 282024,
#  'orders': 897461,
#  'carefully': 268755,
#  'dirty': 412564,
#  'laundry': 723129,
#  'remember': 1044153,
#  'surface': 1201325,
#  'skim': 1140420,
#  'perspectives': 933006,
#  'encompassed': 460487,
#  'extend': 489930,
#  'individual': 648750,
#  'hope': 618223,
#  'room': 1073499,
#  'difference': 407371,
#  'opinion': 893050,
#  'testing': 1226910,
#  'limits': 744625,
#  'examine': 479643,
#  'issue': 674751,
#  'closely': 306174,
#  '1895': 27030,
#  'karl': 697126,
#  'kellner': 698656,
#  '1850': 26748,
#  '1905': 27666,
#  'wealthy': 1334692,
#  'austrian': 190246,
#  'industrialist': 649508,
#  'paper': 912294,
#  'chemist': 287435,
#  'grade': 572971,
#  'mason': 789814,
#  'founded': 532861,
#  'ordo': 897721,
#  'templi': 1223125,
#  'orientis': 899101,
#  'traveled': 1258872,
#  'widely': 1341132,
#  'east': 445812,
#  'met': 808053,
#  'adepts': 134797,
#  'instructed': 659491,
#  'specific': 1159363,
#  'magical': 775824,
#  'practices': 966446,
#  'efforts': 453420,
#  'develop': 400753,
#  'later': 721534,
#  'assisted': 182177,
#  'franz': 534806,
#  'hartmann': 595399,
#  'heinrich': 603153,
#  'klein': 706807,
#  'theodore': 1230191,
#  'prior': 976940,
#  'joining': 686713,
#  'proclaimed': 983273,
#  '1902': 27646,
#  ...}

# %%
X4
# Out:
# <18846x1388659 sparse matrix of type '<class 'numpy.int64'>'
# 	with 2926850 stored elements in Compressed Sparse Row format>

# %%
X_train,X_test,y_train,y_test = train_test_split(X4,y,test_size = 0.2)

# %%
mNB = MultinomialNB()

mNB.fit(X_train,y_train)

mNB.score(X_test,y_test)
# Out:
# 0.6944297082228117

# %%
# %%time
tf_idf = TfidfVectorizer(stop_words='english',ngram_range=(1,2))

X5 = tf_idf.fit_transform(X)
# Out:
# Wall time: 13.6 s

# %%
X_train,X_test,y_train,y_test = train_test_split(X5,y,test_size = 0.2)

# %%
mNB = MultinomialNB()

mNB.fit(X_train,y_train)

mNB.score(X_test,y_test)
# Out:
# 0.7278514588859416

# %%
# 20类
# 随机划分
# 5%

# %%
runing -----> run
