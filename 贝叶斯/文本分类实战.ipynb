# %%
import pandas as pd

from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB

# %%
data = pd.read_csv('./data/SMSSpamCollection',sep = '\t',header=None,names = ['target','message'])
data.shape
# Out:
# (5572, 2)

# %%
data.head()
# Out:
#   target                                            message
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
X = data['message']
y = data['target']

# %%
X.unique().size
# Out:
# 5169

# %%
#统计词频
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer()

# %%
X_cv = cv.fit_transform(X)

X_cv
# Out:
# <5572x8713 sparse matrix of type '<class 'numpy.int64'>'
# 	with 74169 stored elements in Compressed Sparse Row format>

# %%
cv.vocabulary_
# Out:
# {'go': 3571,
#  'until': 8084,
#  'jurong': 4374,
#  'point': 5958,
#  'crazy': 2338,
#  'available': 1316,
#  'only': 5571,
#  'in': 4114,
#  'bugis': 1767,
#  'great': 3655,
#  'world': 8548,
#  'la': 4501,
#  'buffet': 1765,
#  'cine': 2061,
#  'there': 7694,
#  'got': 3615,
#  'amore': 1082,
#  'wat': 8324,
#  'ok': 5538,
#  'lar': 4537,
#  'joking': 4342,
#  'wif': 8450,
#  'oni': 5567,
#  'free': 3373,
#  'entry': 2963,
#  'wkly': 8506,
#  'comp': 2178,
#  'to': 7806,
#  'win': 8463,
#  'fa': 3100,
#  'cup': 2398,
#  'final': 3221,
#  'tkts': 7793,
#  '21st': 412,
#  'may': 4959,
#  '2005': 403,
#  'text': 7644,
#  '87121': 794,
#  'receive': 6340,
#  'question': 6232,
#  'std': 7279,
#  'txt': 7986,
#  'rate': 6284,
#  'apply': 1169,
#  '08452810075over18': 77,
#  'dun': 2815,
#  'say': 6679,
#  'so': 7074,
#  'early': 2836,
#  'hor': 3952,
#  'already': 1054,
#  'then': 7688,
#  'nah': 5270,
#  'don': 2724,
#  'think': 7709,
#  'he': 3805,
#  'goes': 3579,
#  'usf': 8130,
#  'lives': 4692,
#  'around': 1220,
#  'here': 3856,
#  'though': 7729,
#  'freemsg': 3380,
#  'hey': 3866,
#  'darling': 2455,
#  'it': 4245,
#  'been': 1475,
#  'week': 8371,
#  'now': 5453,
#  'and': 1097,
#  'no': 5400,
#  'word': 8539,
#  'back': 1363,
#  'like': 4642,
#  'some': 7089,
#  'fun': 3438,
#  'you': 8668,
#  'up': 8086,
#  'for': 3323,
#  'still': 7302,
#  'tb': 7578,
#  'xxx': 8614,
#  'chgs': 2015,
#  'send': 6771,
#  '50': 616,
#  'rcv': 6297,
#  'even': 3012,
#  'my': 5254,
#  'brother': 1737,
#  'is': 4233,
#  'not': 5438,
#  'speak': 7161,
#  'with': 8492,
#  'me': 4968,
#  'they': 7702,
#  'treat': 7916,
#  'aids': 1004,
#  'patent': 5758,
#  'as': 1237,
#  'per': 5801,
#  'your': 8674,
#  'request': 6449,
#  'melle': 4998,
#  'oru': 5628,
#  'minnaminunginte': 5065,
#  'nurungu': 5473,
#  'vettam': 8188,
#  'has': 3779,
#  'set': 6798,
#  'callertune': 1838,
#  'all': 1041,
#  'callers': 1837,
#  'press': 6081,
#  'copy': 2279,
#  'friends': 3397,
#  'winner': 8474,
#  'valued': 8157,
#  'network': 5349,
#  'customer': 2411,
#  'have': 3794,
#  'selected': 6757,
#  'receivea': 6341,
#  '900': 826,
#  'prize': 6113,
#  'reward': 6504,
#  'claim': 2067,
#  'call': 1828,
#  '09061701461': 224,
#  'code': 2133,
#  'kl341': 4464,
#  'valid': 8153,
#  '12': 323,
#  'hours': 3972,
#  'had': 3721,
#  'mobile': 5119,
#  '11': 312,
#  'months': 5159,
#  'or': 5604,
#  'more': 5163,
#  'entitled': 2960,
#  'update': 8091,
#  'the': 7674,
#  'latest': 4551,
#  'colour': 2154,
#  'mobiles': 5120,
#  'camera': 1849,
#  'co': 2122,
#  'on': 5559,
#  '08002986030': 61,
#  'gonna': 3595,
#  'be': 1451,
#  'home': 3925,
#  'soon': 7116,
#  'want': 8303,
#  'talk': 7545,
#  'about': 870,
#  'this': 7718,
#  'stuff': 7369,
#  'anymore': 1136,
#  'tonight': 7844,
#  've': 8172,
#  'cried': 2355,
#  'enough': 2950,
#  'today': 7813,
#  'six': 6978,
#  'chances': 1956,
#  'cash': 1902,
#  'from': 3414,
#  '100': 298,
#  '20': 398,
#  '000': 1,
#  'pounds': 6021,
#  'csh11': 2374,
#  '87575': 799,
#  'cost': 2291,
#  '150p': 352,
#  'day': 2471,
#  '6days': 690,
#  '16': 364,
#  'tsandcs': 7950,
#  'reply': 6442,
#  'hl': 3897,
#  'info': 4149,
#  'urgent': 8109,
#  'won': 8523,
#  'membership': 5004,
#  'our': 5641,
#  'jackpot': 4270,
#  '81010': 747,
#  'www': 8596,
#  'dbuk': 2476,
#  'net': 5343,
#  'lccltd': 4569,
#  'pobox': 5937,
#  '4403ldnw1a7rw18': 565,
#  'searching': 6726,
#  'right': 6516,
#  'words': 8540,
#  'thank': 7661,
#  'breather': 1706,
#  'promise': 6146,
#  'wont': 8530,
#  'take': 7537,
#  'help': 3842,
#  'granted': 3644,
#  'will': 8460,
#  'fulfil': 3434,
#  'wonderful': 8527,
#  'blessing': 1582,
#  'at': 1273,
#  'times': 7771,
#  'date': 2463,
#  'sunday': 7437,
#  'xxxmobilemovieclub': 8615,
#  'use': 8124,
#  'credit': 2345,
#  'click': 2090,
#  'wap': 8308,
#  'link': 4664,
#  'next': 5367,
#  'message': 5022,
#  'http': 3994,
#  'com': 2157,
#  'qjkgighjjgcbl': 6224,
#  'oh': 5533,
#  'watching': 8329,
#  'eh': 2883,
#  'remember': 6409,
#  'how': 3978,
#  'spell': 7176,
#  'his': 3888,
#  'name': 5276,
#  'yes': 8651,
#  'did': 2606,
#  'naughty': 5303,
#  'make': 4878,
#  'wet': 8408,
#  'fine': 3229,
#  'if': 4067,
#  'that': 7670,
#  'way': 8341,
#  'feel': 3171,
#  'its': 4253,
#  'gota': 3616,
#  'england': 2941,
#  'macedonia': 4840,
#  'dont': 2728,
#  'miss': 5081,
#  'goals': 3575,
#  'team': 7590,
#  'news': 5363,
#  'ur': 8105,
#  'national': 5297,
#  '87077': 793,
#  'eg': 2878,
#  'try': 7946,
#  'wales': 8283,
#  'scotland': 6705,
#  '4txt': 608,
#  'ú1': 8711,
#  'poboxox36504w45wq': 5949,
#  'seriously': 6791,
#  'going': 3584,
#  'ha': 3717,
#  'pay': 5770,
#  'first': 3246,
#  'when': 8419,
#  'da': 2428,
#  'stock': 7305,
#  'comin': 2168,
#  'aft': 974,
#  'finish': 3232,
#  'lunch': 4806,
#  'str': 7330,
#  'down': 2750,
#  'lor': 4747,
#  'ard': 1195,
#  'smth': 7057,
#  'ffffffffff': 3191,
#  'alright': 1055,
#  'can': 1853,
#  'meet': 4987,
#  'sooner': 7117,
#  'just': 4376,
#  'forced': 3325,
#  'myself': 5260,
#  'eat': 2848,
#  'slice': 7009,
#  'really': 6322,
#  'hungry': 4014,
#  'tho': 7725,
#  'sucks': 7406,
#  'mark': 4915,
#  'getting': 3531,
#  'worried': 8551,
#  'knows': 4475,
#  'sick': 6927,
#  'turn': 7969,
#  'pizza': 5892,
#  'lol': 4724,
#  'always': 1064,
#  'convincing': 2267,
#  'catch': 1912,
#  'bus': 1787,
#  'are': 1196,
#  'frying': 3422,
#  'an': 1092,
#  'egg': 2880,
#  'tea': 7584,
#  'eating': 2851,
#  'mom': 5140,
#  'left': 4593,
#  'over': 5663,
#  'dinner': 2637,
#  'do': 2688,
#  'love': 4769,
#  'amp': 1084,
#  'we': 8346,
#  're': 6301,
#  'packing': 5689,
#  'car': 1874,
#  'll': 4696,
#  'let': 4614,
#  'know': 4472,
#  'room': 6557,
#  'ahhh': 999,
#  'work': 8541,
#  'vaguely': 8149,
#  'what': 8412,
#  'does': 2700,
#  'wait': 8277,
#  'clear': 2084,
#  'were': 8397,
#  'sure': 7463,
#  'being': 1493,
#  'sarcastic': 6657,
#  'why': 8443,
#  'doesn': 2702,
#  'live': 4688,
#  'us': 8120,
#  'yeah': 8639,
#  'was': 8317,
#  'apologetic': 1156,
#  'fallen': 3125,
#  'out': 5644,
#  'she': 6843,
#  'actin': 915,
#  'spoilt': 7203,
#  'child': 2023,
#  'caught': 1916,
#  'till': 7768,
#  'but': 1794,
#  'doing': 2714,
#  'too': 7849,
#  'badly': 1368,
#  'cheers': 1999,
#  'tell': 7608,
#  'anything': 1142,
#  'fear': 3163,
#  'of': 5511,
#  'fainting': 3117,
#  'housework': 3976,
#  'quick': 6235,
#  'cuppa': 2400,
#  'thanks': 7662,
#  'subscription': 7394,
#  'ringtone': 6525,
#  'uk': 8016,
#  'charged': 1968,
#  'month': 5156,
#  'please': 5917,
#  'confirm': 2222,
#  'by': 1811,
#  'replying': 6443,
#  'yup': 8695,
#  'look': 4735,
#  'timings': 7775,
#  'msg': 5199,
#  'again': 982,
#  'xuhui': 8610,
#  'learn': 4583,
#  '2nd': 466,
#  'her': 3855,
#  'lesson': 4612,
#  '8am': 819,
#  'oops': 5582,
#  'roommate': 6559,
#  'done': 2726,
#  'see': 6743,
#  'letter': 4616,
#  'decide': 2494,
#  'hello': 3839,
#  'saturday': 6670,
#  'texting': 7652,
#  'decided': 2495,
#  'tomo': 7833,
#  'trying': 7948,
#  'invite': 4207,
#  'pls': 5925,
#  'ahead': 998,
#  'watts': 8337,
#  'wanted': 8305,
#  'weekend': 8373,
#  'abiola': 866,
#  'forget': 3331,
#  'need': 5323,
#  'crave': 2335,
#  'most': 5172,
#  'sweet': 7494,
#  'arabian': 1192,
#  'steed': 7286,
#  'mmmmmm': 5109,
#  'yummy': 8690,
#  '07732584351': 30,
#  'rodger': 6547,
#  'burns': 1784,
#  'tried': 7925,
#  'sms': 7052,
#  'nokia': 5410,
#  'camcorder': 1847,
#  '08000930705': 57,
#  'delivery': 2534,
#  'tomorrow': 7835,
#  'who': 8435,
#  'seeing': 6745,
#  'hope': 3943,
#  'man': 4888,
#  'well': 8388,
#  'endowed': 2931,
#  'am': 1066,
#  'lt': 4793,
#  'gt': 3684,
#  'inches': 4118,
#  'calls': 1843,
#  'messages': 5024,
#  'missed': 5083,
#  'didn': 2608,
#  'get': 3523,
#  'hep': 3854,
#  'immunisation': 4097,
#  'nigeria': 5377,
#  'fair': 3118,
#  'hopefully': 3946,
#  'tyler': 7999,
#  'could': 2301,
#  'maybe': 4961,
#  'ask': 1247,
#  'bit': 1559,
#  'stubborn': 7358,
#  'hospital': 3959,
#  'kept': 4421,
#  'telling': 7609,
#  'weak': 8347,
#  'sucker': 7404,
#  'hospitals': 3960,
#  'suckers': 7405,
#  'thinked': 7710,
#  'time': 7770,
#  'saw': 6678,
#  'class': 2076,
#  'gram': 3636,
#  'usually': 8136,
#  'runs': 6600,
#  'half': 3733,
#  'eighth': 2886,
#  'smarter': 7032,
#  'gets': 3527,
#  'almost': 1050,
#  'whole': 8437,
#  'second': 6730,
#  'fyi': 3454,
#  'ride': 6515,
#  'morning': 5167,
#  'crashing': 2334,
#  'place': 5894,
#  'wow': 8567,
#  'never': 5354,
#  'realized': 6320,
#  'embarassed': 2911,
#  'accomodations': 897,
#  'thought': 7730,
#  'liked': 4643,
#  'since': 6952,
#  'best': 1513,
#  'seemed': 6749,
#  'happy': 3768,
#  'cave': 1920,
#  'sorry': 7126,
#  'give': 3552,
#  'offered': 5519,
#  'embarassing': 2912,
#  'ac': 883,
#  'sptv': 7225,
#  'new': 5358,
#  'jersey': 4312,
#  'devils': 2586,
#  'detroit': 2580,
#  'red': 6363,
#  'wings': 8472,
#  'play': 5908,
#  'ice': 4048,
#  'hockey': 3910,
#  'correct': 2284,
#  'incorrect': 4129,
#  'end': 2926,
#  'mallika': 4887,
#  'sherawat': 6850,
#  'yesterday': 8653,
#  'find': 3226,
#  'url': 8116,
#  'congrats': 2228,
#  'year': 8640,
#  'special': 7163,
#  'cinema': 2062,
#  'pass': 5747,
#  'yours': 8678,
#  '09061209465': 219,
#  'suprman': 7461,
#  'matrix3': 4948,
#  'starwars3': 7267,
#  'etc': 3000,
#  'bx420': 1809,
#  'ip4': 4216,
#  '5we': 651,
#  '150pm': 354,
#  'later': 4550,
#  'meeting': 4989,
#  'where': 8423,
#  'reached': 6304,
#  'gauti': 3488,
#  'sehwag': 6754,
#  'odi': 5510,
#  'series': 6789,
#  'pick': 5864,
#  'burger': 1779,
#  'yourself': 8679,
#  'move': 5185,
#  'pain': 5696,
#  'killing': 4446,
#  'good': 3597,
#  'joke': 4338,
#  'girls': 3549,
#  'situation': 6975,
#  'seekers': 6746,
#  'part': 5736,
#  'checking': 1993,
#  'iq': 4222,
#  'roommates': 6560,
#  'took': 7850,
#  'forever': 3328,
#  'come': 2163,
#  'double': 2743,
#  'check': 1989,
#  'hair': 3728,
#  'dresser': 2773,
#  'said': 6626,
#  'wun': 8595,
#  'cut': 2415,
#  'short': 6886,
#  'nice': 5371,
#  'pleased': 5918,
#  'advise': 957,
#  'following': 3305,
#  'recent': 6344,
#  'review': 6502,
#  'mob': 5117,
#  'awarded': 1333,
#  '1500': 351,
#  'bonus': 1623,
#  '09066364589': 267,
#  'song': 7111,
#  'dedicated': 2505,
#  'which': 8429,
#  'dedicate': 2504,
#  'valuable': 8155,
#  'frnds': 3406,
#  'rply': 6576,
#  'complimentary': 2197,
#  'trip': 7926,
#  'eurodisinc': 3006,
#  'trav': 7908,
#  'aco': 911,
#  'entry41': 2964,
#  '1000': 299,
#  'dis': 2649,
#  '18': 369,
#  'morefrmmob': 5164,
#  'shracomorsglsuplt': 6911,
#  '10': 297,
#  'ls1': 4789,
#  '3aj': 524,
#  'hear': 3817,
#  'divorce': 2678,
#  'barbie': 1399,
#  'comes': 2165,
#  'ken': 4419,
#  'plane': 5900,
#  'wah': 8270,
#  'lucky': 4800,
#  'save': 6674,
#  'money': 5147,
#  'hee': 3830,
#  'finished': 3234,
#  'hi': 3870,
#  'babe': 1354,
#  'im': 4085,
#  'wanna': 8301,
#  'something': 7099,
#  'xx': 8611,
#  'performed': 5808,
#  'waiting': 8280,
#  'machan': 4842,
#  'once': 5563,
#  'thats': 7673,
#  'cool': 2272,
#  'gentleman': 3514,
#  'dignity': 2627,
#  'respect': 6469,
#  'peoples': 5800,
#  'very': 8187,
#  'much': 5217,
#  'shy': 6922,
#  'pa': 5685,
#  'operate': 5589,
#  'after': 975,
#  'same': 6642,
#  'looking': 4739,
#  'job': 4327,
#  'ta': 7522,
#  'earn': 2837,
#  'ah': 996,
#  'stop': 7315,
#  'urgnt': 8112,
#  'real': 6313,
#  'yo': 8663,
#  'tickets': 7758,
#  'one': 5565,
#  'jacket': 4269,
#  'used': 8125,
#  'multis': 5226,
#  'started': 7262,
#  'requests': 6450,
#  'came': 1848,
#  'bed': 1468,
#  'coins': 2139,
#  'factory': 3107,
#  'gotta': 3621,
#  'nitros': 5395,
#  'ela': 2891,
#  'kano': 4400,
#  'il': 4079,
#  'download': 2751,
#  'wen': 8391,
#  'stand': 7250,
#  'close': 2097,
#  'another': 1119,
#  'night': 5379,
#  'spent': 7181,
#  'late': 4547,
#  'afternoon': 977,
#  'casualty': 1910,
#  'means': 4975,
#  'haven': 3796,
#  'any': 1133,
#  'stuff42moro': 7370,
#  'includes': 4122,
#  'sheets': 6845,
#  'smile': 7040,
#  'pleasure': 5920,
#  'trouble': 7933,
#  'pours': 6023,
#  'rain': 6258,
#  'sum1': 7428,
#  'hurts': 4024,
#  'becoz': 1466,
#  'someone': 7093,
#  'loves': 4777,
#  'smiling': 7044,
#  'service': 6794,
#  'representative': 6447,
#  '0800': 53,
#  '169': 367,
#  '6031': 657,
#  'between': 1522,
#  '10am': 307,
#  '9pm': 846,
#  'guaranteed': 3688,
#  '5000': 618,
#  'havent': 3797,
#  'planning': 5904,
#  'buy': 1799,
#  'lido': 4627,
#  '530': 637,
#  'show': 6902,
#  'collected': 2148,
#  'simply': 6949,
#  'password': 5754,
#  'mix': 5099,
#  '85069': 780,
#  'verify': 8183,
#  'usher': 8131,
#  'britney': 1727,
#  'fml': 3296,
#  'po': 5935,
#  'box': 1657,
#  '5249': 634,
#  'mk17': 5102,
#  '92h': 831,
#  '450ppw': 575,
#  'telugu': 7614,
#  'movie': 5188,
#  'abt': 878,
#  'loads': 4703,
#  'loans': 4705,
#  'wk': 8502,
#  'hols': 3923,
#  'run': 6598,
#  'forgot': 3336,
#  'hairdressers': 3730,
#  'appointment': 1172,
#  'four': 3354,
#  'shower': 6904,
#  'beforehand': 1482,
#  'cause': 1917,
#  'prob': 6118,
#  'coffee': 2134,
#  'animation': 1106,
#  'nothing': 5443,
#  'else': 2905,
#  'okay': 5539,
#  'price': 6094,
#  'long': 4731,
#  'legal': 4596,
#  'them': 7684,
#  'ave': 1320,
#  'ams': 1088,
#  'gone': 3593,
#  '4the': 606,
#  'driving': 2782,
#  'test': 7638,
#  'yet': 8654,
#  'mean': 4971,
#  'guess': 3694,
#  'gave': 3489,
#  'boston': 1644,
#  'men': 5008,
#  'changed': 1958,
#  'search': 6725,
#  'location': 4708,
#  'nyc': 5484,
#  'cuz': 2422,
#  'signin': 6937,
#  'page': 5692,
#  'says': 6683,
#  'umma': 8023,
#  'life': 4630,
#  'vava': 8169,
#  'lot': 4755,
#  'dear': 2484,
#  'wishes': 8486,
#  'birthday': 1557,
#  'making': 4882,
#  'truly': 7941,
#  'memorable': 5005,
#  'aight': 1006,
#  'hit': 3890,
#  'would': 8563,
#  'ip': 4215,
#  'address': 933,
#  'considering': 2240,
#  'computer': 2203,
#  'isn': 4240,
#  'minecraft': 5059,
#  'server': 6793,
#  'grumpy': 3681,
#  'old': 5551,
#  'people': 5799,
#  'better': 1519,
#  'lying': 4820,
#  'jokes': 4340,
#  'worry': 8553,
#  'busy': 1793,
#  'plural': 5929,
#  'noun': 5450,
#  'research': 6455,
#  'cos': 2289,
#  'things': 7708,
#  'scared': 6689,
#  'mah': 4865,
#  'loud': 4764,
#  'gent': 3512,
#  'contact': 2245,
#  'last': 4544,
#  'weekends': 8374,
#  'draw': 2765,
#  'shows': 6910,
#  '09064012160': 243,
#  'k52': 4383,
#  '12hrs': 334,
#  '150ppm': 356,
#  'wa': 8265,
#  'openin': 5586,
#  'sentence': 6782,
#  'formal': 3340,
#  'anyway': 1145,
#  'juz': 4382,
#  'tt': 7956,
#  'eatin': 2850,
#  'puttin': 6214,
#  'weight': 8379,
#  'haha': 3724,
#  'anythin': 1141,
#  'happened': 3760,
#  'entered': 2953,
#  'cabin': 1816,
#  'boss': 1643,
#  'felt': 3181,
#  'askd': 1248,
#  'invited': 4208,
#  'apartment': 1150,
#  'went': 8394,
#  'specially': 7167,
#  'holiday': 3920,
#  'flights': 3272,
#  'inc': 4116,
#  'operator': 5590,
#  '0871277810910p': 129,
#  'min': 5052,
#  'goodo': 3606,
#  'must': 5245,
#  'friday': 3392,
#  'potato': 6015,
#  'ratio': 6287,
#  'tortilla': 7867,
#  'needed': 5325,
#  'hmm': 3902,
#  'uncle': 8032,
#  'informed': 4152,
#  'paying': 5776,
#  'school': 6695,
#  'directly': 2643,
#  'food': 3313,
#  'private': 6110,
#  '2004': 402,
#  'account': 900,
#  'statement': 7270,
#  '07742676969': 32,
#  '786': 719,
#  'unredeemed': 8076,
#  'points': 5959,
#  '08719180248': 175,
#  'identifier': 4060,
#  '45239': 577,
#  'expires': 3079,
#  '2000': 400,
#  'caller': 1836,
#  '03': 15,
#  'landline': 4524,
#  '09064019788': 249,
#  'box42wr29c': 1669,
#  'apples': 1167,
#  'pairs': 5700,
#  'malarky': 4884,
#  'todays': 7814,
#  'voda': 8234,
#  'numbers': 5470,
#  'ending': 2928,
#  '7548': 711,
#  '350': 512,
#  'award': 1332,
#  'match': 4936,
#  '08712300220': 111,
#  'quoting': 6246,
#  '4041': 549,
#  'standard': 7251,
#  'rates': 6285,
#  'app': 1160,
#  'sao': 6651,
#  'mu': 5215,
#  'predict': 6055,
#  'buying': 1802,
#  'yetunde': 8656,
#  'hasn': 3781,
#  'sent': 6781,
#  'bother': 1647,
#  'sending': 6773,
#  'involve': 4212,
#  'shouldn': 6897,
#  'imposed': 4104,
#  'apologise': 1157,
#  'girl': 3546,
#  'del': 2524,
#  'bak': 1376,
#  'sum': 7427,
#  'lucyxx': 4803,
#  'tmorrow': 7799,
#  'accomodate': 896,
#  'answer': 1122,
#  'sunshine': 7444,
#  'quiz': 6242,
#  'top': 7858,
#  'sony': 7113,
#  'dvd': 2825,
#  'player': 5910,
#  'country': 2307,
#  'algarve': 1034,
#  'ansr': 1121,
#  '82277': 754,
#  'sp': 7148,
#  'tyrone': 8003,
#  'laid': 4516,
#  'dogging': 2708,
#  'locations': 4709,
#  'direct': 2642,
#  'join': 4335,
#  'largest': 4541,
#  'bt': 1753,
#  'txting': 7992,
#  'gravel': 3649,
#  '69888': 685,
#  'nt': 5460,
#  'ec2a': 2853,
#  '31p': 504,
#  'haf': 3723,
#  'msn': 5206,
#  'yijue': 8660,
#  'hotmail': 3967,
#  'him': 3881,
#  'rooms': 6561,
#  'befor': 1480,
#  'activities': 921,
#  'msgs': 5205,
#  'chat': 1979,
#  'svc': 7479,
#  'hardcore': 3770,
#  'services': 6795,
#  '69988': 689,
#  'age': 985,
#  'yr': 8685,
#  'lazy': 4568,
#  'type': 8000,
#  'lect': 4590,
#  'pouch': 6018,
#  'sir': 6964,
#  'mail': 4870,
#  'swt': 7508,
#  'nver': 5478,
#  'tired': 7779,
#  'little': 4687,
#  'lovable': 4768,
#  'persons': 5826,
#  'coz': 2320,
#  'somtimes': 7108,
#  'those': 7726,
#  'occupy': 5503,
#  'biggest': 1539,
#  'their': 7681,
#  'hearts': 3823,
#  'gud': 3690,
#  'ni8': 5369,
#  'open': 5583,
#  'ya': 8624,
#  'dot': 2742,
#  'whats': 8414,
#  'staff': 7242,
#  'taking': 7542,
#  'replied': 6440,
#  'randy': 6278,
#  'sexy': 6811,
#  'female': 3182,
#  'local': 4707,
#  'luv': 4811,
#  'netcollex': 5344,
#  'ltd': 4794,
#  '08700621170150p': 81,
#  'ummma': 8025,
#  'begin': 1486,
#  'qatar': 6219,
#  'pray': 6050,
#  'hard': 3769,
#  'deleted': 2528,
#  'sindu': 6954,
#  'birla': 1553,
#  'soft': 7079,
#  'wine': 8470,
#  'flowing': 3287,
#  'nevering': 5355,
#  'thk': 7719,
#  'plaza': 5915,
#  'typical': 8002,
#  'everywhere': 3030,
#  'dirt': 2646,
#  'floor': 3281,
#  'windows': 8467,
#  'shirt': 6865,
#  'sometimes': 7101,
#  'mouth': 5184,
#  'dream': 2768,
#  'without': 8496,
#  'chores': 2050,
#  ...}

# %%
print(X_cv)
# Out:
#   (0, 8324)	1
#   (0, 1082)	1
#   (0, 3615)	1
#   (0, 7694)	1
#   (0, 2061)	1
#   (0, 1765)	1
#   (0, 4501)	1
#   (0, 8548)	1
#   (0, 3655)	1
#   (0, 1767)	1
#   (0, 4114)	1
#   (0, 5571)	1
#   (0, 1316)	1
#   (0, 2338)	1
#   (0, 5958)	1
#   (0, 4374)	1
#   (0, 8084)	1
#   (0, 3571)	1
#   (1, 5567)	1
#   (1, 8450)	1
#   (1, 4342)	1
#   (1, 4537)	1
#   (1, 5538)	1
#   (2, 77)	1
#   (2, 1169)	1
#   :	:
#   (5570, 1802)	1
#   (5570, 3489)	1
#   (5570, 2905)	1
#   (5570, 7099)	1
#   (5570, 1794)	1
#   (5570, 8120)	1
#   (5570, 2606)	1
#   (5570, 5367)	1
#   (5570, 1451)	1
#   (5570, 7674)	1
#   (5570, 3323)	1
#   (5570, 7089)	1
#   (5570, 4642)	1
#   (5570, 1097)	1
#   (5570, 8371)	1
#   (5570, 4245)	1
#   (5570, 3805)	1
#   (5570, 7806)	1
#   (5570, 3373)	1
#   (5570, 4114)	1
#   (5571, 6548)	1
#   (5571, 7938)	1
#   (5571, 4253)	2
#   (5571, 5276)	1
#   (5571, 7806)	1

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X_cv,y,test_size =0.2 )

# %%
#高斯分布
# %%time
gNB = GaussianNB()

gNB.fit(X_train.toarray(),y_train)

s = gNB.score(X_test.toarray(),y_test)
print(s)
# Out:
# 0.9112107623318386
# Wall time: 1.21 s

# %%
#二分布
# %%time
mNB = MultinomialNB()

mNB.fit(X_train,y_train)

print(mNB.score(X_test,y_test))
# Out:
# 0.9901345291479821
# Wall time: 17 ms

# %%
#伯努利
bNB = BernoulliNB()

bNB.fit(X_train,y_train)

bNB.score(X_test,y_test)
# Out:
# 0.989237668161435

# %%
from sklearn.neighbors import KNeighborsClassifier

from sklearn.tree import DecisionTreeClassifier

# %%
#KNN
knn = KNeighborsClassifier()

knn.fit(X_train,y_train)

knn.score(X_test,y_test)
# Out:
# 0.9291479820627803

# %%
#决策树
clf = DecisionTreeClassifier()

clf.fit(X_train,y_train)

clf.score(X_test,y_test)
# Out:
# 0.979372197309417

# %%
cv = CountVectorizer(stop_words='english')

# %%
X_cv2 = cv.fit_transform(X)
X_cv2
# Out:
# <5572x8444 sparse matrix of type '<class 'numpy.int64'>'
# 	with 43578 stored elements in Compressed Sparse Row format>

# %%
# %%time

X_train,X_test,y_train,y_test = train_test_split(X_cv2,y,test_size = 0.2)

mNB = MultinomialNB()

mNB.fit(X_train,y_train)

print(mNB.score(X_test,y_test))
# Out:
# 0.9757847533632287
# Wall time: 15 ms

# %%
bNB = BernoulliNB()

bNB.fit(X_train,y_train)

bNB.score(X_test,y_test)
# Out:
# 0.9775784753363229

# %% [markdown]
# 导包
# 导入sklearn.feature_extraction.text.TfidfVectorizer用于转换字符串
# 读取短信数据

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Equivalent to CountVectorizer followed by TfidfTransformer.
# term frequency 词频，idf inverse documents frequency
# 相当于对词频，加了权重
# 的，了，你，我，他分类，作用不大，因为所有文章，都出现很多
# 作为分类的词，特点：一类文章中，出现次数很多，其他文章中出现很少
tf_idf = TfidfVectorizer()

X3 = tf_idf.fit_transform(X)
X3
# Out:
# <5572x8713 sparse matrix of type '<class 'numpy.float64'>'
# 	with 74169 stored elements in Compressed Sparse Row format>

# %%
X_train,X_test,y_train,y_test = train_test_split(X3,y,test_size = 0.2)

mNB = MultinomialNB()

mNB.fit(X_train,y_train)

print(mNB.score(X_test,y_test))
# Out:
# 0.9623318385650225

# %%
from sklearn.feature_extraction.text import HashingVectorizer

# %%
hv = HashingVectorizer()

X4 = hv.fit_transform(X)

X4
# Out:
# <5572x1048576 sparse matrix of type '<class 'numpy.float64'>'
# 	with 74169 stored elements in Compressed Sparse Row format>

# %%
import numpy as np
print(np.abs(X4))
# Out:
#   (0, 217534)	0.23570226039551587
#   (0, 298067)	0.23570226039551587
#   (0, 304864)	0.23570226039551587
#   (0, 307669)	0.23570226039551587
#   (0, 346524)	0.23570226039551587
#   (0, 396254)	0.23570226039551587
#   (0, 481047)	0.23570226039551587
#   (0, 528700)	0.23570226039551587
#   (0, 604544)	0.23570226039551587
#   (0, 630479)	0.23570226039551587
#   (0, 639749)	0.23570226039551587
#   (0, 653949)	0.23570226039551587
#   (0, 707424)	0.23570226039551587
#   (0, 787517)	0.23570226039551587
#   (0, 809054)	0.23570226039551587
#   (0, 828689)	0.23570226039551587
#   (0, 859130)	0.23570226039551587
#   (0, 992018)	0.23570226039551587
#   (1, 284109)	0.4472135954999579
#   (1, 338849)	0.4472135954999579
#   (1, 374789)	0.4472135954999579
#   (1, 536132)	0.4472135954999579
#   (1, 913144)	0.4472135954999579
#   (2, 32615)	0.1643989873053573
#   (2, 34389)	0.1643989873053573
#   :	:
#   (5570, 174974)	0.20412414523193154
#   (5570, 180525)	0.20412414523193154
#   (5570, 189643)	0.20412414523193154
#   (5570, 221403)	0.20412414523193154
#   (5570, 286674)	0.20412414523193154
#   (5570, 286878)	0.20412414523193154
#   (5570, 318077)	0.20412414523193154
#   (5570, 329790)	0.20412414523193154
#   (5570, 372702)	0.20412414523193154
#   (5570, 513296)	0.20412414523193154
#   (5570, 578498)	0.20412414523193154
#   (5570, 764163)	0.20412414523193154
#   (5570, 777676)	0.20412414523193154
#   (5570, 828689)	0.20412414523193154
#   (5570, 842629)	0.20412414523193154
#   (5570, 881772)	0.20412414523193154
#   (5570, 922985)	0.20412414523193154
#   (5570, 943214)	0.20412414523193154
#   (5570, 975831)	0.20412414523193154
#   (5570, 1008391)	0.20412414523193154
#   (5571, 48144)	0.35355339059327373
#   (5571, 174171)	0.35355339059327373
#   (5571, 232766)	0.35355339059327373
#   (5571, 435055)	0.7071067811865475
#   (5571, 905074)	0.35355339059327373

# %%
X_train,X_test,y_train,y_test = train_test_split(np.abs(X4),y,test_size = 0.2)

mNB = MultinomialNB()

mNB.fit(X_train,y_train)

print(mNB.score(X_test,y_test))
# Out:
# 0.895067264573991

# %%
hv.tokenizer

# %%
cv.vocabulary_
# Out:
# {'jurong': 4248,
#  'point': 5779,
#  'crazy': 2282,
#  'available': 1284,
#  'bugis': 1719,
#  'great': 3555,
#  'world': 8285,
#  'la': 4374,
#  'buffet': 1717,
#  'cine': 2007,
#  'got': 3515,
#  'amore': 1064,
#  'wat': 8083,
#  'ok': 5377,
#  'lar': 4410,
#  'joking': 4216,
#  'wif': 8191,
#  'oni': 5403,
#  'free': 3280,
#  'entry': 2889,
#  'wkly': 8243,
#  'comp': 2123,
#  'win': 8203,
#  'fa': 3018,
#  'cup': 2341,
#  'final': 3135,
#  'tkts': 7569,
#  '21st': 412,
#  '2005': 403,
#  'text': 7437,
#  '87121': 794,
#  'receive': 6158,
#  'question': 6052,
#  'std': 7077,
#  'txt': 7754,
#  'rate': 6104,
#  'apply': 1141,
#  '08452810075over18': 77,
#  'dun': 2751,
#  'say': 6496,
#  'early': 2770,
#  'hor': 3840,
#  'nah': 5124,
#  'don': 2663,
#  'think': 7492,
#  'goes': 3479,
#  'usf': 7892,
#  'lives': 4562,
#  'freemsg': 3287,
#  'hey': 3757,
#  'darling': 2398,
#  'week': 8129,
#  'word': 8276,
#  'like': 4512,
#  'fun': 3342,
#  'tb': 7372,
#  'xxx': 8350,
#  'chgs': 1961,
#  'send': 6584,
#  '50': 616,
#  'rcv': 6116,
#  'brother': 1689,
#  'speak': 6959,
#  'treat': 7687,
#  'aids': 997,
#  'patent': 5582,
#  'request': 6267,
#  'melle': 4862,
#  'oru': 5461,
#  'minnaminunginte': 4927,
#  'nurungu': 5315,
#  'vettam': 7949,
#  'set': 6610,
#  'callertune': 1787,
#  'callers': 1786,
#  'press': 5902,
#  'copy': 2224,
#  'friends': 3304,
#  'winner': 8214,
#  'valued': 7919,
#  'network': 5201,
#  'customer': 2354,
#  'selected': 6570,
#  'receivea': 6159,
#  '900': 826,
#  'prize': 5934,
#  'reward': 6322,
#  'claim': 2013,
#  '09061701461': 224,
#  'code': 2078,
#  'kl341': 4337,
#  'valid': 7915,
#  '12': 323,
#  'hours': 3860,
#  'mobile': 4981,
#  '11': 312,
#  'months': 5021,
#  'entitled': 2886,
#  'update': 7855,
#  'latest': 4423,
#  'colour': 2099,
#  'mobiles': 4982,
#  'camera': 1798,
#  '08002986030': 61,
#  'gonna': 3495,
#  'home': 3813,
#  'soon': 6914,
#  'want': 8063,
#  'talk': 7339,
#  'stuff': 7166,
#  'anymore': 1112,
#  'tonight': 7618,
#  've': 7934,
#  'cried': 2299,
#  'today': 7588,
#  'chances': 1902,
#  'cash': 1848,
#  '100': 298,
#  '20': 398,
#  '000': 1,
#  'pounds': 5842,
#  'csh11': 2317,
#  '87575': 799,
#  'cost': 2236,
#  '150p': 352,
#  'day': 2414,
#  '6days': 690,
#  '16': 364,
#  'tsandcs': 7721,
#  'reply': 6260,
#  'hl': 3785,
#  'info': 4029,
#  'urgent': 7872,
#  'won': 8260,
#  'membership': 4868,
#  'jackpot': 4144,
#  '81010': 747,
#  'www': 8332,
#  'dbuk': 2419,
#  'net': 5195,
#  'lccltd': 4441,
#  'pobox': 5758,
#  '4403ldnw1a7rw18': 565,
#  'searching': 6543,
#  'right': 6334,
#  'words': 8277,
#  'thank': 7453,
#  'breather': 1658,
#  'promise': 5967,
#  'wont': 8267,
#  'help': 3737,
#  'granted': 3544,
#  'fulfil': 3339,
#  'wonderful': 8264,
#  'blessing': 1536,
#  'times': 7547,
#  'date': 2406,
#  'sunday': 7233,
#  'xxxmobilemovieclub': 8351,
#  'use': 7886,
#  'credit': 2289,
#  'click': 2036,
#  'wap': 8068,
#  'link': 4534,
#  'message': 4886,
#  'http': 3880,
#  'com': 2102,
#  'qjkgighjjgcbl': 6044,
#  'oh': 5372,
#  'watching': 8088,
#  'eh': 2816,
#  'remember': 6227,
#  'spell': 6974,
#  'yes': 8387,
#  'did': 2546,
#  'naughty': 5156,
#  'make': 4746,
#  'wet': 8164,
#  'fine': 3142,
#  'way': 8100,
#  'feel': 3089,
#  'gota': 3516,
#  'england': 2868,
#  'macedonia': 4709,
#  'dont': 2666,
#  'miss': 4943,
#  'goals': 3475,
#  'team': 7384,
#  'news': 5214,
#  'ur': 7868,
#  'national': 5150,
#  '87077': 793,
#  'try': 7717,
#  'wales': 8043,
#  'scotland': 6522,
#  '4txt': 608,
#  'ú1': 8442,
#  'poboxox36504w45wq': 5770,
#  'seriously': 6603,
#  'going': 3484,
#  'ha': 3617,
#  'pay': 5594,
#  'da': 2371,
#  'stock': 7102,
#  'comin': 2113,
#  'aft': 971,
#  'finish': 3145,
#  'lunch': 4675,
#  'str': 7127,
#  'lor': 4617,
#  'ard': 1167,
#  'smth': 6862,
#  'ffffffffff': 3108,
#  'alright': 1043,
#  'meet': 4851,
#  'sooner': 6915,
#  'just': 4250,
#  'forced': 3234,
#  'eat': 2782,
#  'slice': 6814,
#  'really': 6140,
#  'hungry': 3899,
#  'tho': 7507,
#  'sucks': 7202,
#  'mark': 4782,
#  'getting': 3433,
#  'worried': 8288,
#  'knows': 4348,
#  'sick': 6735,
#  'turn': 7740,
#  'pizza': 5714,
#  'lol': 4594,
#  'convincing': 2212,
#  'catch': 1858,
#  'bus': 1739,
#  'frying': 3327,
#  'egg': 2813,
#  'tea': 7378,
#  'eating': 2785,
#  'mom': 5002,
#  'left': 4464,
#  'dinner': 2577,
#  'love': 4639,
#  'amp': 1065,
#  'packing': 5514,
#  'car': 1820,
#  'll': 4566,
#  'let': 4484,
#  'know': 4345,
#  'room': 6375,
#  'ahhh': 992,
#  'work': 8278,
#  'vaguely': 7911,
#  'does': 2639,
#  'wait': 8037,
#  'clear': 2030,
#  'sure': 7259,
#  'sarcastic': 6474,
#  'doesn': 2641,
#  'live': 4558,
#  'yeah': 8375,
#  'apologetic': 1128,
#  'fallen': 3043,
#  'actin': 912,
#  'spoilt': 7001,
#  'child': 1969,
#  'caught': 1862,
#  'till': 7544,
#  'doing': 2653,
#  'badly': 1335,
#  'cheers': 1945,
#  'tell': 7402,
#  'fear': 3081,
#  'fainting': 3035,
#  'housework': 3864,
#  'quick': 6055,
#  'cuppa': 2343,
#  'thanks': 7454,
#  'subscription': 7191,
#  'ringtone': 6343,
#  'uk': 7784,
#  'charged': 1914,
#  'month': 5018,
#  'confirm': 2167,
#  'replying': 6261,
#  'yup': 8426,
#  'look': 4605,
#  'timings': 7551,
#  'msg': 5057,
#  'xuhui': 8346,
#  'learn': 4455,
#  '2nd': 466,
#  'lesson': 4482,
#  '8am': 819,
#  'oops': 5416,
#  'roommate': 6377,
#  'letter': 4486,
#  'decide': 2436,
#  'hello': 3734,
#  'saturday': 6487,
#  'texting': 7445,
#  'decided': 2437,
#  'tomo': 7607,
#  'trying': 7719,
#  'invite': 4085,
#  'pls': 5746,
#  'ahead': 991,
#  'watts': 8096,
#  'wanted': 8065,
#  'weekend': 8131,
#  'abiola': 866,
#  'forget': 3240,
#  'need': 5176,
#  'crave': 2279,
#  'sweet': 7290,
#  'arabian': 1164,
#  'steed': 7084,
#  'mmmmmm': 4971,
#  'yummy': 8421,
#  '07732584351': 30,
#  'rodger': 6365,
#  'burns': 1736,
#  'tried': 7696,
#  'sms': 6857,
#  'nokia': 5258,
#  'camcorder': 1796,
#  '08000930705': 57,
#  'delivery': 2476,
#  'tomorrow': 7609,
#  'seeing': 6561,
#  'hope': 3831,
#  'man': 4756,
#  'endowed': 2858,
#  'lt': 4663,
#  'gt': 3584,
#  'inches': 3999,
#  'calls': 1792,
#  'messages': 4888,
#  'missed': 4945,
#  'didn': 2548,
#  'hep': 3748,
#  'immunisation': 3980,
#  'nigeria': 5227,
#  'fair': 3036,
#  'hopefully': 3834,
#  'tyler': 7767,
#  'maybe': 4827,
#  'ask': 1216,
#  'bit': 1513,
#  'stubborn': 7155,
#  'hospital': 3847,
#  'kept': 4294,
#  'telling': 7403,
#  'weak': 8105,
#  'sucker': 7200,
#  'hospitals': 3848,
#  'suckers': 7201,
#  'thinked': 7493,
#  'time': 7546,
#  'saw': 6495,
#  'class': 2022,
#  'gram': 3536,
#  'usually': 7898,
#  'runs': 6418,
#  'half': 3632,
#  'eighth': 2818,
#  'smarter': 6837,
#  'gets': 3429,
#  'second': 6547,
#  'fyi': 3357,
#  'ride': 6333,
#  'morning': 5028,
#  'crashing': 2278,
#  'place': 5716,
#  'wow': 8303,
#  'realized': 6138,
#  'embarassed': 2839,
#  'accomodations': 895,
#  'thought': 7510,
#  'liked': 4513,
#  'best': 1470,
#  'happy': 3667,
#  'cave': 1866,
#  'sorry': 6924,
#  'offered': 5359,
#  'embarassing': 2840,
#  'ac': 881,
#  'sptv': 7023,
#  'new': 5209,
#  'jersey': 4186,
#  'devils': 2526,
#  'detroit': 2520,
#  'red': 6181,
#  'wings': 8212,
#  'play': 5730,
#  'ice': 3933,
#  'hockey': 3798,
#  'correct': 2229,
#  'incorrect': 4010,
#  'end': 2853,
#  'mallika': 4755,
#  'sherawat': 6660,
#  'yesterday': 8389,
#  'url': 7879,
#  'congrats': 2173,
#  'year': 8376,
#  'special': 6961,
#  'cinema': 2008,
#  'pass': 5571,
#  '09061209465': 219,
#  'suprman': 7257,
#  'matrix3': 4815,
#  'starwars3': 7065,
#  'bx420': 1760,
#  'ip4': 4094,
#  '5we': 651,
#  '150pm': 354,
#  'later': 4422,
#  'meeting': 4853,
#  'reached': 6122,
#  'gauti': 3391,
#  'sehwag': 6567,
#  'odi': 5352,
#  'series': 6602,
#  'pick': 5686,
#  'burger': 1731,
#  'pain': 5521,
#  'killing': 4319,
#  'good': 3497,
#  'joke': 4212,
#  'girls': 3451,
#  'situation': 6781,
#  'seekers': 6562,
#  'checking': 1939,
#  'iq': 4100,
#  'roommates': 6378,
#  'took': 7623,
#  'forever': 3237,
#  'come': 2108,
#  'double': 2681,
#  'check': 1935,
#  'hair': 3627,
#  'dresser': 2710,
#  'said': 6444,
#  'wun': 8331,
#  'cut': 2358,
#  'short': 6696,
#  'nice': 5221,
#  'pleased': 5739,
#  'advise': 954,
#  'following': 3215,
#  'recent': 6162,
#  'review': 6320,
#  'mob': 4979,
#  'awarded': 1301,
#  '1500': 351,
#  'bonus': 1577,
#  '09066364589': 267,
#  'song': 6909,
#  'dedicated': 2447,
#  'dedicate': 2446,
#  'valuable': 7917,
#  'frnds': 3313,
#  'rply': 6394,
#  'complimentary': 2142,
#  'trip': 7697,
#  'eurodisinc': 2931,
#  'trav': 7679,
#  'aco': 909,
#  'entry41': 2890,
#  '1000': 299,
#  'dis': 2589,
#  '18': 369,
#  'morefrmmob': 5025,
#  'shracomorsglsuplt': 6719,
#  '10': 297,
#  'ls1': 4659,
#  '3aj': 524,
#  'hear': 3712,
#  'divorce': 2618,
#  'barbie': 1366,
#  'comes': 2110,
#  'ken': 4292,
#  'plane': 5722,
#  'wah': 8030,
#  'lucky': 4669,
#  'save': 6491,
#  'money': 5009,
#  'hee': 3725,
#  'finished': 3147,
#  'hi': 3761,
#  'babe': 1322,
#  'im': 3968,
#  'wanna': 8061,
#  'xx': 8347,
#  'performed': 5631,
#  'waiting': 8040,
#  'machan': 4711,
#  'thats': 7464,
#  'cool': 2217,
#  'gentleman': 3417,
#  'dignity': 2567,
#  'respect': 6287,
#  'peoples': 5624,
#  'shy': 6730,
#  'pa': 5510,
#  'operate': 5423,
#  'looking': 4609,
#  'job': 4201,
#  'ta': 7317,
#  'earn': 2771,
#  'ah': 989,
#  'stop': 7112,
#  'urgnt': 7875,
#  'real': 6131,
#  'yo': 8398,
#  'tickets': 7534,
#  'jacket': 4143,
#  'used': 7887,
#  'multis': 5083,
#  'started': 7060,
#  'requests': 6268,
#  'came': 1797,
#  'bed': 1431,
#  'coins': 2084,
#  'factory': 3025,
#  'gotta': 3521,
#  'nitros': 5245,
#  'ela': 2822,
#  'kano': 4274,
#  'il': 3962,
#  'download': 2688,
#  'wen': 8148,
#  'stand': 7048,
#  'close': 2043,
#  'night': 5229,
#  'spent': 6979,
#  'late': 4419,
#  'afternoon': 973,
#  'casualty': 1856,
#  'means': 4840,
#  'haven': 3692,
#  'stuff42moro': 7167,
#  'includes': 4003,
#  'sheets': 6655,
#  'smile': 6845,
#  'pleasure': 5741,
#  'trouble': 7704,
#  'pours': 5844,
#  'rain': 6078,
#  'sum1': 7224,
#  'hurts': 3909,
#  'becoz': 1429,
#  'loves': 4647,
#  'smiling': 6849,
#  'service': 6606,
#  'representative': 6265,
#  '0800': 53,
#  '169': 367,
#  '6031': 657,
#  '10am': 307,
#  '9pm': 846,
#  'guaranteed': 3588,
#  '5000': 618,
#  'havent': 3693,
#  'planning': 5726,
#  'buy': 1750,
#  'lido': 4497,
#  '530': 637,
#  'collected': 2093,
#  'simply': 6756,
#  'password': 5578,
#  'mix': 4961,
#  '85069': 780,
#  'verify': 7945,
#  'usher': 7893,
#  'britney': 1679,
#  'fml': 3206,
#  'po': 5756,
#  'box': 1609,
#  '5249': 634,
#  'mk17': 4964,
#  '92h': 831,
#  '450ppw': 575,
#  'telugu': 7408,
#  'movie': 5046,
#  'abt': 876,
#  'loads': 4573,
#  'loans': 4575,
#  'wk': 8239,
#  'hols': 3811,
#  'run': 6416,
#  'forgot': 3245,
#  'hairdressers': 3629,
#  'appointment': 1144,
#  'shower': 6712,
#  'cause': 1863,
#  'prob': 5939,
#  'coffee': 2079,
#  'animation': 1085,
#  'okay': 5378,
#  'price': 5915,
#  'long': 4601,
#  'legal': 4467,
#  'ave': 1288,
#  'ams': 1069,
#  'gone': 3493,
#  '4the': 606,
#  'driving': 2719,
#  'test': 7431,
#  'mean': 4836,
#  'guess': 3594,
#  'gave': 3392,
#  'boston': 1598,
#  'men': 4872,
#  'changed': 1904,
#  'search': 6542,
#  'location': 4578,
#  'nyc': 5326,
#  'cuz': 2365,
#  'signin': 6744,
#  'page': 5517,
#  'says': 6500,
#  'umma': 7791,
#  'life': 4500,
#  'vava': 7931,
#  'lot': 4625,
#  'dear': 2426,
#  'wishes': 8226,
#  'birthday': 1511,
#  'making': 4750,
#  'truly': 7712,
#  'memorable': 4869,
#  'aight': 999,
#  'hit': 3778,
#  'ip': 4093,
#  'address': 930,
#  'considering': 2185,
#  'computer': 2148,
#  'isn': 4117,
#  'minecraft': 4921,
#  'server': 6605,
#  'grumpy': 3581,
#  'old': 5390,
#  'people': 5623,
#  'better': 1476,
#  'lying': 4689,
#  'jokes': 4214,
#  'worry': 8290,
#  'busy': 1745,
#  'plural': 5750,
#  'noun': 5294,
#  'research': 6273,
#  'cos': 2234,
#  'things': 7491,
#  'scared': 6506,
#  'mah': 4733,
#  'loud': 4634,
#  'gent': 3415,
#  'contact': 2190,
#  'weekends': 8132,
#  'draw': 2702,
#  'shows': 6718,
#  '09064012160': 243,
#  'k52': 4257,
#  '12hrs': 334,
#  '150ppm': 356,
#  'wa': 8025,
#  'openin': 5420,
#  'sentence': 6595,
#  'formal': 3249,
#  'juz': 4256,
#  'tt': 7727,
#  'eatin': 2784,
#  'puttin': 6034,
#  'weight': 8137,
#  'haha': 3623,
#  'anythin': 1116,
#  'happened': 3659,
#  'entered': 2879,
#  'cabin': 1766,
#  'boss': 1597,
#  'felt': 3099,
#  'askd': 1217,
#  'invited': 4086,
#  'apartment': 1122,
#  'went': 8151,
#  'specially': 6965,
#  'holiday': 3808,
#  'flights': 3182,
#  'operator': 5424,
#  '0871277810910p': 129,
#  'min': 4915,
#  'goodo': 3506,
#  'friday': 3299,
#  'potato': 5836,
#  'ratio': 6106,
#  'tortilla': 7639,
#  'needed': 5178,
#  'hmm': 3790,
#  'uncle': 7799,
#  'informed': 4032,
#  'paying': 5600,
#  'school': 6512,
#  'directly': 2583,
#  'food': 3223,
#  'private': 5931,
#  '2004': 402,
#  'account': 898,
#  'statement': 7068,
#  '07742676969': 32,
#  '786': 719,
#  'unredeemed': 7842,
#  'points': 5780,
#  '08719180248': 175,
#  'identifier': 3945,
#  '45239': 577,
#  'expires': 2997,
#  '2000': 400,
#  'caller': 1785,
#  '03': 15,
#  'landline': 4397,
#  '09064019788': 249,
#  'box42wr29c': 1621,
#  'apples': 1139,
#  'pairs': 5525,
#  'malarky': 4752,
#  'todays': 7589,
#  'voda': 7994,
#  'numbers': 5312,
#  'ending': 2855,
#  '7548': 711,
#  '350': 512,
#  'award': 1300,
#  'match': 4803,
#  '08712300220': 111,
#  'quoting': 6066,
#  '4041': 549,
#  'standard': 7049,
#  'rates': 6105,
#  'app': 1132,
#  'sao': 6468,
#  'mu': 5073,
#  'predict': 5876,
#  'buying': 1753,
#  'yetunde': 8391,
#  'hasn': 3679,
#  'sent': 6594,
#  'bother': 1600,
#  'sending': 6586,
#  'involve': 4090,
#  'shouldn': 6706,
#  'imposed': 3987,
#  'apologise': 1129,
#  'girl': 3448,
#  'del': 2466,
#  'bak': 1343,
#  'sum': 7223,
#  'lucyxx': 4672,
#  'tmorrow': 7575,
#  'accomodate': 894,
#  'answer': 1100,
#  'sunshine': 7240,
#  'quiz': 6062,
#  'sony': 6911,
#  'dvd': 2760,
#  'player': 5732,
#  'country': 2251,
#  'algarve': 1027,
#  'ansr': 1099,
#  '82277': 754,
#  'sp': 6946,
#  'tyrone': 7771,
#  'laid': 4389,
#  'dogging': 2647,
#  'locations': 4579,
#  'direct': 2582,
#  'join': 4209,
#  'largest': 4414,
#  'bt': 1705,
#  'txting': 7760,
#  'gravel': 3549,
#  '69888': 685,
#  'nt': 5302,
#  'ec2a': 2787,
#  '31p': 504,
#  'haf': 3622,
#  'msn': 5064,
#  'yijue': 8395,
#  'hotmail': 3855,
#  'rooms': 6379,
#  'befor': 1442,
#  'activities': 918,
#  'msgs': 5063,
#  'chat': 1925,
#  'svc': 7275,
#  'hardcore': 3669,
#  'services': 6607,
#  '69988': 689,
#  'age': 978,
#  'yr': 8416,
#  'lazy': 4440,
#  'type': 7768,
#  'lect': 4461,
#  'pouch': 5839,
#  'sir': 6770,
#  'mail': 4738,
#  'swt': 7304,
#  'nver': 5320,
#  'tired': 7555,
#  'little': 4557,
#  'lovable': 4638,
#  'persons': 5648,
#  'coz': 2264,
#  'somtimes': 6906,
#  'occupy': 5345,
#  'biggest': 1494,
#  'hearts': 3718,
#  'gud': 3590,
#  'ni8': 5219,
#  'open': 5417,
#  'ya': 8360,
#  'dot': 2680,
#  'whats': 8168,
#  'staff': 7040,
#  'taking': 7336,
#  'replied': 6258,
#  'randy': 6098,
#  'sexy': 6622,
#  'female': 3100,
#  'local': 4577,
#  'luv': 4680,
#  'netcollex': 5196,
#  '08700621170150p': 81,
#  'ummma': 7793,
#  'begin': 1446,
#  'qatar': 6039,
#  'pray': 5871,
#  'hard': 3668,
#  'deleted': 2470,
#  'sindu': 6760,
#  'birla': 1507,
#  'soft': 6883,
#  'wine': 8210,
#  'flowing': 3197,
#  'nevering': 5206,
#  'thk': 7501,
#  'plaza': 5737,
#  'typical': 7770,
#  'dirt': 2586,
#  'floor': 3191,
#  'windows': 8207,
#  'shirt': 6675,
#  'mouth': 5043,
#  'dream': 2705,
#  'chores': 1996,
#  'joy': 4227,
#  'lots': 4627,
#  'tv': 7745,
#  'exist': 2982,
#  'hail': 3626,
#  'mist': 4953,
#  'aaooooright': 856,
#  'leaving': 4460,
#  'house': 3861,
#  'interview': 4073,
#  'boy': 1626,
#  'missing': 4947,
#  'annoncement': 1091,
#  'years': 8377,
#  '07046744435': 24,
#  'arrange': 1193,
#  '0871277810810': 128,
#  'safe': 6439,
#  'envy': 2895,
#  'parents': 5554,
#  'hand': 3641,
#  'excited': 2970,
#  'spend': 6977,
#  'bootydelious': 1590,
#  '32': 505,
#  'inviting': 4087,
#  'friend': 3303,
#  '434': 562,
#  'frnd': 3312,
#  '62468': 665,
#  'bangbabes': 1357,
#  'order': 5445,
#  'content': 2194,
#  'goto': 3520,
#  'bangb': 1356,
#  'internet': 4072,
#  'menu': 4879,
#  'cultures': 2337,
#  'module': 4995,
#  '09061701939': 226,
#  's89': 6429,
#  'avoid': 1294,
#  'missunderstding': 4951,
#  'wit': 8231,
#  'beloved': 1461,
#  'escape': 2916,
#  'fancy': 3054,
#  'bridge': 1664,
#  'needs': 5181,
#  'lager': 4388,
#  'completely': 2138,
#  'form': 3248,
#  'clark': 2019,
#  'utter': 7900,
#  'waste': 8080,
#  'axis': 1309,
#  'bank': 1359,
#  'hmmm': 3791,
#  'hop': 3830,
#  'muz': 5107,
#  'discuss': 2602,
#  'liao': 4491,
#  'coming': 2114,
#  'bloody': 1550,
#  'hell': 3732,
#  'believe': 1452,
#  'surname': 7265,
#  'mr': 5052,
#  'ill': 3964,
#  'clue': 2059,
#  'spanish': 6953,
#  'begins': 1447,
#  'bath': 1390,
#  'carlos': 1837,
#  'mall': 4754,
#  'turns': 7743,
#  'staying': 7075,
#  'til': 7543,
#  'smoke': 6851,
#  'worth': 8294,
#  'doesnt': 2642,
#  'log': 4585,
#  'spoke': 7002,
#  'maneesha': 4766,
#  'satisfied': 6483,
#  'experience': 2992,
#  'toll': 7602,
#  'lifted': 4506,
#  'hopes': 3836,
#  'offer': 5358,
#  'especially': 2920,
#  'approaches': 1148,
#  'studying': 7164,
#  'anyways': 1119,
#  'gr8': 3529,
#  'trust': 7714,
#  'guys': 3610,
#  'bye': 1763,
#  'handsome': 3647,
#  'finding': 3140,
#  'working': 8282,
#  'mummy': 5087,
#  'boytoy': 1631,
#  'awesome': 1303,
#  'minute': 4932,
#  'freephone': 3288,
#  '0808': 65,
#  '145': 344,
#  '4742': 581,
#  '9am': 844,
#  '11pm': 322,
#  'xmas': 8343,
#  'radio': 6071,
#  'jus': 4249,
#  'bathe': 1391,
#  'sis': 6772,
#  'using': 7894,
#  'finishes': 3148,
#  'unique': 7827,
#  '30th': 500,
#  'august': 1270,
#  'areyouunique': 1173,
#  'joined': 4210,
#  'league': 4453,
#  'touch': 7648,
#  'deal': 2422,
#  'personal': 5645,
#  'finally': 3137,
#  'completed': 2137,
#  'course': 2257,
#  'suggest': 7215,
#  'stays': 7076,
#  'able': 868,
#  'ors': 5459,
#  'stool': 7111,
#  'settled': 6614,
#  'wishin': 8227,
#  'mrng': 5054,
#  'hav': 3687,
#  'story': 7126,
#  'hamster': 3640,
#  'dead': 2421,
#  'tmr': 7576,
#  '1pm': 386,
#  ...}
