# %%
# opencv 人脸区域辨识
# SVC 算法，可以识别人脸，叫什么，是谁，训练
# 打卡机，人脸对比

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import sklearn.datasets as datasets

from sklearn.svm import SVC

# %%
faces = datasets.fetch_lfw_people(min_faces_per_person=70,resize=1)
faces
# Out:
# {'data': array([[253.66667 , 253.66667 , 254.66667 , ...,  86.666664,  86.333336,
#           86.333336],
#         [ 42.      ,  34.      ,  31.666666, ..., 121.666664, 148.      ,
#          185.33333 ],
#         [ 94.      ,  72.      ,  74.      , ..., 182.66667 , 183.      ,
#          182.33333 ],
#         ...,
#         [ 84.333336,  86.      ,  85.333336, ...,  44.      ,  35.666668,
#           30.333334],
#         [ 49.666668,  50.333332,  47.666668, ..., 178.66667 , 167.66667 ,
#          127.333336],
#         [ 31.333334,  33.333332,  26.666666, ...,  47.666668,  63.      ,
#           99.      ]], dtype=float32),
#  'images': array([[[253.66667 , 253.66667 , 254.66667 , ...,  42.333332,
#            37.666668,  39.      ],
#          [254.      , 254.      , 253.66667 , ...,  43.333332,
#            38.      ,  39.      ],
#          [254.66667 , 254.33333 , 253.33333 , ...,  44.      ,
#            38.666668,  38.      ],
#          ...,
#          [ 68.333336,  63.333332,  51.      , ...,  90.333336,
#            85.666664,  83.666664],
#          [ 64.      ,  61.333332,  51.666668, ...,  88.      ,
#            87.      ,  87.      ],
#          [ 58.666668,  58.      ,  53.      , ...,  86.666664,
#            86.333336,  86.333336]],
#
#         [[ 42.      ,  34.      ,  31.666666, ...,  41.333332,
#            34.      ,  29.666666],
#          [ 41.666668,  35.666668,  38.      , ...,  42.      ,
#            36.      ,  33.666668],
#          [ 41.      ,  43.      ,  47.333332, ...,  48.666668,
#            46.      ,  39.666668],
#          ...,
#          [ 77.333336,  77.666664,  75.666664, ..., 110.333336,
#           110.666664, 133.33333 ],
#          [ 77.666664,  78.666664,  78.333336, ..., 112.333336,
#           123.666664, 154.66667 ],
#          [ 77.      ,  76.666664,  76.666664, ..., 121.666664,
#           148.      , 185.33333 ]],
#
#         [[ 94.      ,  72.      ,  74.      , ..., 151.66667 ,
#           150.33333 , 150.      ],
#          [ 96.      ,  88.333336,  96.      , ..., 149.66667 ,
#           148.33333 , 148.      ],
#          [ 97.333336,  86.666664,  97.666664, ..., 147.66667 ,
#           145.33333 , 147.33333 ],
#          ...,
#          [ 77.      ,  72.666664,  67.      , ..., 184.33333 ,
#           183.      , 181.      ],
#          [ 83.      ,  80.666664,  72.333336, ..., 184.      ,
#           184.      , 182.      ],
#          [ 88.333336,  86.666664,  82.666664, ..., 182.66667 ,
#           183.      , 182.33333 ]],
#
#         ...,
#
#         [[ 84.333336,  86.      ,  85.333336, ...,  37.333332,
#            42.666668,  48.      ],
#          [ 86.      ,  87.      ,  84.666664, ...,  34.333332,
#            38.333332,  43.666668],
#          [ 89.      ,  90.      ,  85.333336, ...,  33.      ,
#            37.      ,  41.      ],
#          ...,
#          [ 80.666664,  86.666664,  85.666664, ...,  58.666668,
#            55.      ,  45.666668],
#          [ 72.666664,  79.333336,  81.666664, ...,  51.      ,
#            46.      ,  36.666668],
#          [ 66.666664,  69.666664,  74.      , ...,  44.      ,
#            35.666668,  30.333334]],
#
#         [[ 49.666668,  50.333332,  47.666668, ..., 157.      ,
#           150.33333 , 140.      ],
#          [ 46.333332,  49.      ,  50.666668, ..., 159.      ,
#           154.      , 145.33333 ],
#          [ 50.666668,  51.      ,  55.666668, ..., 156.33333 ,
#           156.      , 151.      ],
#          ...,
#          [ 61.333332,  60.333332,  63.      , ..., 168.33333 ,
#           173.33333 , 169.      ],
#          [ 61.333332,  60.333332,  63.      , ..., 179.      ,
#           176.      , 153.      ],
#          [ 62.      ,  60.      ,  61.666668, ..., 178.66667 ,
#           167.66667 , 127.333336]],
#
#         [[ 31.333334,  33.333332,  26.666666, ...,  48.333332,
#            48.      ,  51.333332],
#          [ 37.      ,  27.333334,  24.333334, ...,  47.333332,
#            45.      ,  51.333332],
#          [ 35.      ,  28.      ,  23.333334, ...,  40.666668,
#            39.      ,  43.333332],
#          ...,
#          [ 43.333332,  41.333332,  41.666668, ...,  37.666668,
#            49.666668,  61.      ],
#          [ 47.      ,  46.      ,  50.666668, ...,  44.      ,
#            61.333332,  84.333336],
#          [ 46.      ,  46.      ,  46.666668, ...,  47.666668,
#            63.      ,  99.      ]]], dtype=float32),
#  'target': array([5, 6, 3, ..., 5, 3, 5], dtype=int64),
#  'target_names': array(['Ariel Sharon', 'Colin Powell', 'Donald Rumsfeld', 'George W Bush',
#         'Gerhard Schroeder', 'Hugo Chavez', 'Tony Blair'], dtype='<U17'),
#  'DESCR': 'LFW faces dataset'}

# %%
X = faces['data']

y = faces['target']

names = faces.target_names

# %%
image = faces['images']

image.shape
# Out:
# (1288, 125, 94)

# %%
index = np.random.randint(1288,size = 1)[0]

plt.imshow(image[index],cmap = plt.cm.gray)

print(y[index])

names[y[index]]
# Out:
# 3
# 'George W Bush'

# %%
X.shape
# Out:
# (1288, 11750)

# %%
from sklearn.model_selection import train_test_split

# %%
# %%time
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

svc = SVC(kernel='rbf')

svc.fit(X_train,y_train)

print(svc.score(X_test,y_test))
# Out:
# 0.3875968992248062
# Wall time: 50.4 s

# %%
from sklearn.decomposition import PCA

# %%
# 主成分分析
# Principal component analysis (PCA)
# whiten = True 白化，归一化
pca = PCA(n_components=0.9,whiten = True)

# 代表原来的数据，经过矩阵运算，结果属性看不懂（属性，没有实际的物理意义），脱敏数据
X_pca = pca.fit_transform(X)

X_pca.shape
# Out:
# (1288, 116)

# %%
X_pca.std(axis = 0)
# Out:
# array([0.9996117 , 0.9996118 , 0.99961144, 0.9996118 , 0.99961126,
#        0.99961203, 0.9996116 , 0.9996118 , 0.99961144, 0.9996116 ,
#        0.99961156, 0.9996118 , 0.9996118 , 0.99961156, 0.99961156,
#        0.99961156, 0.9996119 , 0.99961174, 0.9996118 , 0.99961203,
#        0.99961174, 0.9996118 , 0.9996121 , 0.9996121 , 0.99961215,
#        0.9996118 , 0.99961203, 0.9996118 , 0.9996119 , 0.9996123 ,
#        0.99961203, 0.9996118 , 0.99961174, 0.99961174, 0.99961185,
#        0.9996118 , 0.99961174, 0.99961174, 0.99961174, 0.9996117 ,
#        0.9996118 , 0.9996118 , 0.9996118 , 0.9996123 , 0.9996118 ,
#        0.999612  , 0.99961203, 0.9996119 , 0.99961185, 0.99961174,
#        0.9996117 , 0.9996119 , 0.9996118 , 0.9996118 , 0.99961174,
#        0.9996117 , 0.9996119 , 0.99961174, 0.99961156, 0.9996116 ,
#        0.9996118 , 0.99961203, 0.99961174, 0.9996115 , 0.9996116 ,
#        0.9996116 , 0.9996116 , 0.9996118 , 0.99961174, 0.9996122 ,
#        0.99961156, 0.9996116 , 0.99961174, 0.9996115 , 0.99961174,
#        0.999612  , 0.99961174, 0.9996118 , 0.99961174, 0.99961174,
#        0.99961174, 0.9996116 , 0.9996117 , 0.9996116 , 0.99961174,
#        0.99961174, 0.9996117 , 0.9996116 , 0.9996118 , 0.9996116 ,
#        0.9996117 , 0.9996118 , 0.9996118 , 0.9996117 , 0.99961174,
#        0.99961174, 0.9996118 , 0.9996117 , 0.99961185, 0.99961185,
#        0.99961203, 0.99961174, 0.99961203, 0.9996118 , 0.9996118 ,
#        0.9996116 , 0.9996118 , 0.99961203, 0.9996119 , 0.9996118 ,
#        0.9996119 , 0.9996119 , 0.99961185, 0.9996119 , 0.999612  ,
#        0.999612  ], dtype=float32)

# %%
# %%time
X_train,X_test,y_train,y_test = train_test_split(X_pca,y,test_size = 0.2)

svc = SVC()

svc.fit(X_train,y_train)

print(svc.score(X_test,y_test))
# Out:
# 0.4573643410852713
# Wall time: 645 ms

# %%
# %%time
X_train,X_test,y_train,y_test = train_test_split(X_pca,y,test_size = 0.2)

svc = SVC()

svc.fit(X_train,y_train)

print(svc.score(X_test,y_test))
# Out:
# 0.8062015503875969
# Wall time: 425 ms

# %%
for i in range(7):
    print(names[i],(y == i).sum())
# Out:
# Ariel Sharon 77
# Colin Powell 236
# Donald Rumsfeld 121
# George W Bush 530
# Gerhard Schroeder 109
# Hugo Chavez 71
# Tony Blair 144

# %%
import imblearn

# %%
# 过采样
from imblearn.over_sampling import SMOTE

# %%
'''This object is an implementation of SMOTE - Synthetic Minority
Over-sampling Technique as presented in'''
smote = SMOTE()

# %%
X2,y2 = smote.fit_resample(X,y)

# %%
for i in range(7):
    print(names[i],(y2 == i).sum())
# Out:
# Ariel Sharon 530
# Colin Powell 530
# Donald Rumsfeld 530
# George W Bush 530
# Gerhard Schroeder 530
# Hugo Chavez 530
# Tony Blair 530

# %%
pca = PCA(n_components=0.9,whiten=True)

X2_pca = pca.fit_transform(X2)
X2_pca.shape
# Out:
# (3710, 99)

# %%
# %%time
X_train,X_test,y_train,y_test = train_test_split(X2_pca,y2,test_size = 0.2)

svc = SVC()

svc.fit(X_train,y_train)

print(svc.score(X_test,y_test))
# Out:
# 0.9851752021563343
# Wall time: 1.34 s

# %%
X2.shape
# Out:
# (3710, 11750)

# %%
image.shape
# Out:
# (1288, 125, 94)

# %%
125*94
# Out:
# 11750

# %%
# %%time
face_train,face_test,X_train,X_test,y_train,y_test = train_test_split(X2,X2_pca,y2,test_size = 0.2)

svc = SVC()

svc.fit(X_train,y_train)

print(svc.score(X_test,y_test))

y_ = svc.predict(X_test)
# Out:
# 0.9892183288409704
# Wall time: 1.73 s

# %%
plt.figure(figsize=(10*2,10*3))
for i in range(100):
    
    ax = plt.subplot(10,10,i + 1)
    
    face = face_test[i].reshape(125,94)
    
    ax.imshow(face,cmap = 'gray')
    ax.axis('off')
    t = names[y_test[i]].split(' ')[-1]
    
    p = names[y_[i]].split(' ')[-1]
    
    ax.set_title('True:%s\nPredict:%s'%(t,p))
