# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.svm import SVC

# %%
X = np.random.randn(300,2)

# %%
plt.scatter(X[:,0],X[:,1])

# %%
X.shape
# Out:
# (300, 2)

# %%
# 属性组合
# x3 = x1*x2
#  (x1 + x2 - x7)*x9/x2

x3 = X[:,0] * X[:,1]
y = x3 >=0

# %%
plt.scatter(X[:,0],X[:,1],c = y)

# %%
# rbf 径向基 高斯分布数据处理
svc = SVC(kernel='rbf')

svc.fit(X,y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
svc.coef_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-a8dadb2081e3> in <module>()
# ----> 1 svc.coef_
#
# D:\Anaconda3.5.2\lib\site-packages\sklearn\svm\base.py in coef_(self)
#     463     def coef_(self):
#     464         if self.kernel != 'linear':
# --> 465             raise AttributeError('coef_ is only available when using a '
#     466                                  'linear kernel')
#     467
#
# AttributeError: coef_ is only available when using a linear kernel

# %%
svc.intercept_
# Out:
# array([0.05792399])

# %%
x1 = np.linspace(-3,3,100)

y1 = np.linspace(-3,3,100)

X1,Y1 = np.meshgrid(x1,y1)

# %%
Y1.shape
# Out:
# (100, 100)

# %%
X_test = np.concatenate([X1.reshape(-1,1),Y1.reshape(-1,1)],axis=-1)
plt.scatter(X_test[:,0],X_test[:,1])

# %%
y_ = svc.predict(X_test)
y_

plt.figure(figsize=(5,5))

plt.scatter(X_test[:,0],X_test[:,1],c = y_)

# %%
d_ = svc.decision_function(X_test)
d_
# Out:
# array([0.1093417 , 0.11477454, 0.12075184, ..., 0.16816356, 0.16268286,
#        0.15759471])

# %%
d_.max()
# Out:
# 3.4879089102811194

# %%
d_.min()
# Out:
# -3.442962579277701

# %%
X_test

# %%
X1.shape
# Out:
# (100, 100)

# %%
d_.shape
# Out:
# (10000,)

# %%
plt.figure(figsize=(5,5))

plt.contourf(X1,Y1,d_.reshape(100,100),cmap = plt.cm.gray)
