# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# 无监督学习，只有分类
from sklearn.cluster import KMeans

# %%
import sklearn.datasets as datasets
# Out:
# d:\python3.6.8\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)

# %%
X,y = datasets.make_blobs()

plt.scatter(X[:,0],X[:,1],c = y)

# %%
X
# Out:
# array([[ -9.69776757,  -2.38507862],
#        [ -4.21303537,  -5.84512908],
#        [-10.12895633,   8.59175804],
#        [ -4.2674819 ,  -5.98639386],
#        [ -9.76135089,   7.65794037],
#        [ -2.78905952,  -6.32987215],
#        [ -4.2068703 ,  -4.4454553 ],
#        [ -8.74073471,  -1.08823414],
#        [ -3.89335635,  -4.70937944],
#        [ -7.58039521,   9.04365969],
#        [ -5.35990819,  -4.08326775],
#        [ -9.96552963,  -1.56840247],
#        [ -3.67907674,  -6.80772919],
#        [ -8.66357758,   6.28007881],
#        [ -8.66866175,  -2.66809044],
#        [-10.40466526,  -2.76743202],
#        [ -5.52770864,  -4.37281226],
#        [-10.06424936,  -2.65303152],
#        [ -3.57553997,  -4.88645365],
#        [-11.25555418,   6.98365456],
#        [ -9.99933763,  -4.14890335],
#        [ -4.13468693,  -3.86879478],
#        [-10.69037038,   8.55128571],
#        [ -3.86019209,  -4.53553355],
#        [ -4.3840991 ,  -5.51937444],
#        [ -9.79615883,   0.38604251],
#        [-10.22853854,  -2.44380095],
#        [ -9.03028719,  -2.18530731],
#        [ -8.2503584 ,  -0.93669192],
#        [ -3.52250888,  -7.60034004],
#        [ -7.85020912,   5.87388754],
#        [-11.16740889,  -2.97192486],
#        [ -9.73543975,   6.15727817],
#        [ -9.63540802,  -2.53417054],
#        [ -4.94386337,  -5.90085894],
#        [ -9.42841392,   7.0271782 ],
#        [ -9.5880298 ,  -2.77353868],
#        [ -8.47052236,   6.20339655],
#        [-10.57010461,  -2.58364951],
#        [ -8.54209401,   6.84358421],
#        [ -3.8360699 ,  -5.89728872],
#        [ -8.91652461,  -1.38583289],
#        [-11.50332683,  -1.52433855],
#        [-10.3126763 ,   6.05258845],
#        [-10.37401136,   6.77880277],
#        [ -4.94321053,  -5.376378  ],
#        [ -9.18784371,   8.75597218],
#        [-10.83250368,   6.96032713],
#        [ -8.23344871,   6.75593806],
#        [ -8.8323558 ,  -2.59235354],
#        [ -9.20003715,  -2.73036713],
#        [ -2.32808164,  -5.20190039],
#        [-10.46545206,  -0.72132945],
#        [ -8.20914418,   7.75914816],
#        [ -8.79333606,  -1.9243957 ],
#        [ -5.60807115,  -7.47689271],
#        [ -4.84406854,  -5.28979347],
#        [-10.15745385,  -0.37343903],
#        [ -9.13577539,   7.3694103 ],
#        [ -9.50808943,   7.36368463],
#        [ -5.48600471,  -4.50009003],
#        [ -3.03239897,  -3.71745055],
#        [ -3.3424665 ,  -5.50761421],
#        [ -8.34106425,   7.53316507],
#        [ -5.18096125,  -4.12560202],
#        [ -4.30763497,  -5.50549027],
#        [ -7.85495287,  -4.38265265],
#        [ -8.49482453,   6.70454501],
#        [ -9.1408474 ,  -1.81988672],
#        [ -9.42551014,   7.66646558],
#        [-10.32618446,   7.50021151],
#        [ -3.54161028,  -5.29173531],
#        [ -9.29288322,  -1.21290868],
#        [ -9.48031494,  -2.36947068],
#        [ -4.07396422,  -5.14560563],
#        [ -4.47920703,  -5.26628187],
#        [ -8.33074607,   9.07897694],
#        [ -5.28512639,  -3.33495208],
#        [ -8.87062849,  -2.52001375],
#        [ -8.92259712,  -0.38746323],
#        [ -3.36029946,  -4.4867097 ],
#        [-10.54575326,   6.75326084],
#        [ -9.22033599,   7.72579748],
#        [-11.13136067,   8.18418937],
#        [ -9.95205251,   8.86541866],
#        [ -5.72005133,  -4.60995177],
#        [ -3.89658032,  -7.50449286],
#        [ -8.49469691,  -1.78076393],
#        [ -4.61611179,  -3.52762411],
#        [ -8.5280367 ,   8.78459891],
#        [ -8.5209223 ,  -0.79440715],
#        [-10.13148557,  -2.12958059],
#        [-10.87999753,   7.29455537],
#        [ -8.77886843,   8.91470337],
#        [ -8.01733106,  -0.6143264 ],
#        [ -4.14597422,  -4.79724413],
#        [ -9.29728983,   6.76773548],
#        [-10.44334138,  -4.39810865],
#        [ -9.85975952,  -3.0075859 ],
#        [ -9.13625484,   7.04239871]])

# %%
kmeans = KMeans(5)

kmeans.fit(X)

y_ = kmeans.predict(X)

y_

plt.scatter(X[:,0],X[:,1],c = y_)

# %%
kmeans = KMeans(5)

kmeans.fit(X)

y_ = kmeans.predict(X)

y_

plt.scatter(X[:,0],X[:,1],c = y_)

# %%
kmeans = KMeans(5)

kmeans.fit(X)

y_ = kmeans.predict(X)

y_

plt.scatter(X[:,0],X[:,1],c = y_)

# %%
kmeans = KMeans(3)

kmeans.fit(X)

y_ = kmeans.predict(X)

y_

plt.scatter(X[:,0],X[:,1],c = y_)

# %%
# 轮廓系数
from sklearn.metrics import silhouette_score

# %%
kmeans = KMeans(2)

kmeans.fit(X)

y_ = kmeans.predict(X)

y_

plt.scatter(X[:,0],X[:,1],c = y_)
silhouette_score(X,y_)
# Out:
# 0.7063076104547901

# %%
kmeans = KMeans(3)

kmeans.fit(X)

y_ = kmeans.predict(X)

y_

plt.scatter(X[:,0],X[:,1],c = y_)
silhouette_score(X,y_)
# Out:
# 0.7467663910814376

# %%
kmeans = KMeans(4)

kmeans.fit(X)

y_ = kmeans.predict(X)

y_

plt.scatter(X[:,0],X[:,1],c = y_)
silhouette_score(X,y_)
# Out:
# 0.6243507925035989

# %%
kmeans = KMeans(5)

kmeans.fit(X)

y_ = kmeans.predict(X)

y_

plt.scatter(X[:,0],X[:,1],c = y_)
silhouette_score(X,y_)
# Out:
# 0.4977702890440074

# %%
kmeans = KMeans(6)

kmeans.fit(X)

y_ = kmeans.predict(X)

y_

plt.scatter(X[:,0],X[:,1],c = y_)
'''The Silhouette Coefficient is calculated using the mean intra-cluster(簇内的点)
distance (``a``) and the mean nearest-cluster distance (``b``) for each
sample.  The Silhouette Coefficient for a sample is ``(b - a) / max(a,
b)``.  To clarify, ``b`` is the distance between a sample and the nearest
cluster that the sample is not a part of.'''
silhouette_score(X,y_)
# Out:
# 0.3484525961815313
